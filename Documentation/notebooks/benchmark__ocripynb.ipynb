# %% [markdown]
# **(ground_truth=.txt)Claude**

# %% [markdown]
# **1.Doctr**

# %%
# !pip install python-doctr
# Out:
# Requirement already satisfied: python-doctr in /usr/local/lib/python3.10/dist-packages (0.10.0)
# Requirement already satisfied: numpy<3.0.0,>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from python-doctr) (1.26.4)
# Requirement already satisfied: scipy<2.0.0,>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from python-doctr) (1.13.1)
# Requirement already satisfied: h5py<4.0.0,>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from python-doctr) (3.11.0)
# Requirement already satisfied: opencv-python<5.0.0,>=4.5.0 in /usr/local/lib/python3.10/dist-packages (from python-doctr) (4.10.0.84)
# Requirement already satisfied: pypdfium2<5.0.0,>=4.11.0 in /usr/local/lib/python3.10/dist-packages (from python-doctr) (4.30.0)
# Requirement already satisfied: pyclipper<2.0.0,>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from python-doctr) (1.3.0.post6)
# Requirement already satisfied: shapely<3.0.0,>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from python-doctr) (2.0.6)
# Requirement already satisfied: langdetect<2.0.0,>=1.0.9 in /usr/local/lib/python3.10/dist-packages (from python-doctr) (1.0.9)
# Requirement already satisfied: rapidfuzz<4.0.0,>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from python-doctr) (3.10.1)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.20.0 in /usr/local/lib/python3.10/dist-packages (from python-doctr) (0.24.7)
# Requirement already satisfied: Pillow>=9.2.0 in /usr/local/lib/python3.10/dist-packages (from python-doctr) (10.4.0)
# Requirement already satisfied: defusedxml>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from python-doctr) (0.7.1)
# Requirement already satisfied: anyascii>=0.3.2 in /usr/local/lib/python3.10/dist-packages (from python-doctr) (0.3.2)
# Requirement already satisfied: tqdm>=4.30.0 in /usr/local/lib/python3.10/dist-packages (from python-doctr) (4.66.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0.0,>=0.20.0->python-doctr) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0.0,>=0.20.0->python-doctr) (2024.6.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0.0,>=0.20.0->python-doctr) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0.0,>=0.20.0->python-doctr) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0.0,>=0.20.0->python-doctr) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0.0,>=0.20.0->python-doctr) (4.12.2)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from langdetect<2.0.0,>=1.0.9->python-doctr) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub<1.0.0,>=0.20.0->python-doctr) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub<1.0.0,>=0.20.0->python-doctr) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub<1.0.0,>=0.20.0->python-doctr) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub<1.0.0,>=0.20.0->python-doctr) (2024.8.30)

# %%
# !pip install tf2onnx
# Out:
# Requirement already satisfied: tf2onnx in /usr/local/lib/python3.10/dist-packages (1.16.1)
# Requirement already satisfied: numpy>=1.14.1 in /usr/local/lib/python3.10/dist-packages (from tf2onnx) (1.26.4)
# Requirement already satisfied: onnx>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from tf2onnx) (1.17.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from tf2onnx) (2.32.3)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from tf2onnx) (1.16.0)
# Requirement already satisfied: flatbuffers>=1.12 in /usr/local/lib/python3.10/dist-packages (from tf2onnx) (24.3.25)
# Requirement already satisfied: protobuf~=3.20 in /usr/local/lib/python3.10/dist-packages (from tf2onnx) (3.20.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->tf2onnx) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->tf2onnx) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->tf2onnx) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->tf2onnx) (2024.8.30)

# %%
import os
import time
from doctr.models import ocr_predictor
from doctr.io import DocumentFile

# Initialize doctr OCR model
ocr_model = ocr_predictor(pretrained=True)

def extract_text_from_image(image_path):
    doc = DocumentFile.from_images(image_path)
    result = ocr_model(doc)
    extracted_text = []
    for page in result.pages:
        for block in page.blocks:
            for line in block.lines:
                for word in line.words:
                    extracted_text.append(word.value)
    return ' '.join(extracted_text)

def read_text_file(file_path):
    with open(file_path, 'r', encoding='utf-8') as file:
        return file.read()

def calculate_metrics(extracted_text, reference_text):
    extracted_words = extracted_text.split()
    reference_words = reference_text.split()

    # Count correct words
    correct_words = sum(1 for word in extracted_words if word in reference_words)

    # Calculate metrics
    total_extracted = len(extracted_words)
    total_reference = len(reference_words)

    precision = 0.0 if total_extracted == 0 else correct_words / total_extracted
    recall = 0.0 if total_reference == 0 else correct_words / total_reference
    f1 = 0.0 if precision + recall == 0 else 2 * (precision * recall) / (precision + recall)

    return {
        'precision': precision,
        'recall': recall,
        'f1': f1,
        'correct_words': correct_words,
        'extracted_words': total_extracted,
        'reference_words': total_reference
    }

# Directories containing the images and text files
image_dir = r'/content/images_analyse'
text_dir = r'/content/ground_truth'

# Variables to track metrics
total_precision = 0.0
total_recall = 0.0
total_f1 = 0.0
num_files = 0
total_execution_time = 0.0

# List of supported image extensions
image_extensions = ('.jpg', '.jpeg', '.png')

# Iterate over all files in the image directory
for image_filename in os.listdir(image_dir):
    # Check if file is a supported image type
    if image_filename.lower().endswith(image_extensions):
        # Get the base filename without extension
        base_filename = os.path.splitext(image_filename)[0]

        # Construct the full paths
        image_path = os.path.join(image_dir, image_filename)
        text_file_path = os.path.join(text_dir, f"{base_filename}.txt")

        # Check if the corresponding text file exists
        if os.path.exists(text_file_path):
            try:
                start_time = time.time()

                # Extract text from the image
                extracted_text = extract_text_from_image(image_path)

                # Read text from the pre-existing text file
                pre_existing_text = read_text_file(text_file_path)

                # Calculate metrics
                metrics = calculate_metrics(extracted_text, pre_existing_text)

                # Add to totals
                total_precision += metrics['precision']
                total_recall += metrics['recall']
                total_f1 += metrics['f1']
                num_files += 1

                # Calculate execution time
                execution_time = time.time() - start_time
                total_execution_time += execution_time

                # Print individual file results with word counts
                print(f"Processed {image_filename}:")
                print(f"Reference words: {metrics['reference_words']}")
                print(f"Extracted words: {metrics['extracted_words']}")
                print(f"Correct words: {metrics['correct_words']}")
                print(f"Precision: {metrics['precision']:.2f}")
                print(f"Recall: {metrics['recall']:.2f}")
                print(f"F1 Score: {metrics['f1']:.2f}")
                print(f"Execution Time: {execution_time:.2f} seconds\n")

            except Exception as e:
                print(f"Error processing {image_filename}: {str(e)}")
        else:
            print(f"Text file not found for image: {image_filename}")

# Calculate and output the averages
if num_files > 0:
    average_precision = total_precision / num_files
    average_recall = total_recall / num_files
    average_f1 = total_f1 / num_files
    average_execution_time = total_execution_time / num_files

    print("\nSummary Statistics:")
    print(f"Number of files processed: {num_files}")
    print(f"Average Precision: {average_precision:.2f}")
    print(f"Average Recall: {average_recall:.2f}")
    print(f"Average F1 Score: {average_f1:.2f}")
    print(f"Average Execution Time: {average_execution_time:.2f} seconds per file")
else:
    print("No matching text files found for any images.")
# Out:
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# Processed 8.jpeg:
# Reference words: 119
# Extracted words: 103
# Correct words: 77
# Precision: 0.75
# Recall: 0.65
# F1 Score: 0.69
# Execution Time: 14.98 seconds
#
# Processed 17.jpeg:
# Reference words: 149
# Extracted words: 140
# Correct words: 123
# Precision: 0.88
# Recall: 0.83
# F1 Score: 0.85
# Execution Time: 19.69 seconds
#
# Processed 7.jpeg:
# Reference words: 246
# Extracted words: 226
# Correct words: 196
# Precision: 0.87
# Recall: 0.80
# F1 Score: 0.83
# Execution Time: 25.49 seconds
#
# Processed 11.jpeg:
# Reference words: 193
# Extracted words: 173
# Correct words: 151
# Precision: 0.87
# Recall: 0.78
# F1 Score: 0.83
# Execution Time: 24.55 seconds
#
# Processed 10.jpeg:
# Reference words: 223
# Extracted words: 209
# Correct words: 187
# Precision: 0.89
# Recall: 0.84
# F1 Score: 0.87
# Execution Time: 24.94 seconds
#
# Processed 2.jpeg:
# Reference words: 385
# Extracted words: 342
# Correct words: 288
# Precision: 0.84
# Recall: 0.75
# F1 Score: 0.79
# Execution Time: 37.18 seconds
#
# Processed 13.jpeg:
# Reference words: 193
# Extracted words: 176
# Correct words: 148
# Precision: 0.84
# Recall: 0.77
# F1 Score: 0.80
# Execution Time: 22.00 seconds
#
# Processed 1.jpeg:
# Reference words: 222
# Extracted words: 193
# Correct words: 156
# Precision: 0.81
# Recall: 0.70
# F1 Score: 0.75
# Execution Time: 22.85 seconds
#
# Processed 20.jpeg:
# Reference words: 327
# Extracted words: 294
# Correct words: 258
# Precision: 0.88
# Recall: 0.79
# F1 Score: 0.83
# Execution Time: 32.64 seconds
#
# Processed 18.jpeg:
# Reference words: 207
# Extracted words: 180
# Correct words: 160
# Precision: 0.89
# Recall: 0.77
# F1 Score: 0.83
# Execution Time: 22.97 seconds
#
# Processed 19.jpeg:
# Reference words: 193
# Extracted words: 170
# Correct words: 146
# Precision: 0.86
# Recall: 0.76
# F1 Score: 0.80
# Execution Time: 21.01 seconds
#
# Processed 9.jpeg:
# Reference words: 341
# Extracted words: 310
# Correct words: 260
# Precision: 0.84
# Recall: 0.76
# F1 Score: 0.80
# Execution Time: 36.78 seconds
#
# Processed 12.jpeg:
# Reference words: 150
# Extracted words: 129
# Correct words: 116
# Precision: 0.90
# Recall: 0.77
# F1 Score: 0.83
# Execution Time: 17.56 seconds
#
# Processed 6.jpeg:
# Reference words: 230
# Extracted words: 207
# Correct words: 164
# Precision: 0.79
# Recall: 0.71
# F1 Score: 0.75
# Execution Time: 24.91 seconds
#
# Processed 3.jpeg:
# Reference words: 236
# Extracted words: 212
# Correct words: 191
# Precision: 0.90
# Recall: 0.81
# F1 Score: 0.85
# Execution Time: 25.66 seconds
#
# Processed 16.jpeg:
# Reference words: 219
# Extracted words: 198
# Correct words: 179
# Precision: 0.90
# Recall: 0.82
# F1 Score: 0.86
# Execution Time: 23.23 seconds
#
# Processed 14.jpeg:
# Reference words: 301
# Extracted words: 261
# Correct words: 192
# Precision: 0.74
# Recall: 0.64
# F1 Score: 0.68
# Execution Time: 30.05 seconds
#
# Processed 15.jpeg:
# Reference words: 197
# Extracted words: 172
# Correct words: 142
# Precision: 0.83
# Recall: 0.72
# F1 Score: 0.77
# Execution Time: 22.50 seconds
#
# Processed 5.jpeg:
# Reference words: 39
# Extracted words: 32
# Correct words: 21
# Precision: 0.66
# Recall: 0.54
# F1 Score: 0.59
# Execution Time: 7.77 seconds
#
# Processed 4.jpeg:
# Reference words: 385
# Extracted words: 347
# Correct words: 295
# Precision: 0.85
# Recall: 0.77
# F1 Score: 0.81
# Execution Time: 38.24 seconds
#
#
# Summary Statistics:
# Number of files processed: 20
# Average Precision: 0.84
# Average Recall: 0.75
# Average F1 Score: 0.79
# Average Execution Time: 24.75 seconds per file

# %% [markdown]
# **EasyOCR**

# %%
# !pip install easyocr
# Out:
# Collecting easyocr
#   Downloading easyocr-1.7.2-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from easyocr) (2.5.0+cu121)
# Requirement already satisfied: torchvision>=0.5 in /usr/local/lib/python3.10/dist-packages (from easyocr) (0.20.0+cu121)
# Requirement already satisfied: opencv-python-headless in /usr/local/lib/python3.10/dist-packages (from easyocr) (4.10.0.84)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from easyocr) (1.13.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from easyocr) (1.26.4)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from easyocr) (10.4.0)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.10/dist-packages (from easyocr) (0.24.0)
# Collecting python-bidi (from easyocr)
#   Downloading python_bidi-0.6.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from easyocr) (6.0.2)
# Requirement already satisfied: Shapely in /usr/local/lib/python3.10/dist-packages (from easyocr) (2.0.6)
# Requirement already satisfied: pyclipper in /usr/local/lib/python3.10/dist-packages (from easyocr) (1.3.0.post6)
# Collecting ninja (from easyocr)
#   Downloading ninja-1.11.1.1-py2.py3-none-manylinux1_x86_64.manylinux_2_5_x86_64.whl.metadata (5.3 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->easyocr) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch->easyocr) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->easyocr) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->easyocr) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->easyocr) (2024.6.1)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch->easyocr) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch->easyocr) (1.3.0)
# Requirement already satisfied: imageio>=2.33 in /usr/local/lib/python3.10/dist-packages (from scikit-image->easyocr) (2.35.1)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.10/dist-packages (from scikit-image->easyocr) (2024.9.20)
# Requirement already satisfied: packaging>=21 in /usr/local/lib/python3.10/dist-packages (from scikit-image->easyocr) (24.1)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.10/dist-packages (from scikit-image->easyocr) (0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->easyocr) (3.0.2)
# Downloading easyocr-1.7.2-py3-none-any.whl (2.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 63.9 MB/s eta 0:00:00
# Downloading ninja-1.11.1.1-py2.py3-none-manylinux1_x86_64.manylinux_2_5_x86_64.whl (307 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.2/307.2 kB 21.4 MB/s eta 0:00:00
# Downloading python_bidi-0.6.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (286 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 286.8/286.8 kB 21.5 MB/s eta 0:00:00
# Installing collected packages: python-bidi, ninja, easyocr
# Successfully installed easyocr-1.7.2 ninja-1.11.1.1 python-bidi-0.6.3

# %%
import os
import time
import easyocr

# Initialize easyocr Reader with French and English support
reader = easyocr.Reader(['en', 'fr'])

def extract_text_from_image(image_path):
    # Perform OCR
    result = reader.readtext(image_path)
    # Extract text
    extracted_text = ' '.join([item[1] for item in result])
    return extracted_text

def read_text_file(file_path):
    with open(file_path, 'r', encoding='utf-8') as file:
        return file.read()

def calculate_metrics(extracted_text, reference_text):
    extracted_words = extracted_text.split()
    reference_words = reference_text.split()
    extracted_words_set = set(extracted_words)
    reference_words_set = set(reference_words)

    correct_words = sum(1 for word in reference_words if word in extracted_words_set)

    # Calculate precision and recall
    precision = correct_words / len(extracted_words) if extracted_words else 0.0
    recall = correct_words / len(reference_words) if reference_words else 0.0
    f1_score = calculate_f1(precision, recall)

    return {
        'precision': precision,
        'recall': recall,
        'f1_score': f1_score,
        'reference_count': len(reference_words),
        'extracted_count': len(extracted_words),
        'correct_count': correct_words
    }

def calculate_f1(precision, recall):
    if precision + recall == 0:
        return 0.0
    return 2 * (precision * recall) / (precision + recall)

# Directories containing the images and text files
image_dir = r'/content/images_analyse'
text_dir = r'/content/ground_truth'

# Variables to track metrics
total_precision = 0.0
total_recall = 0.0
total_f1 = 0.0
num_files = 0
total_execution_time = 0.0

# List of supported image extensions
image_extensions = ('.jpg', '.jpeg', '.png')

# Store results for each file
results = []

# Store total word counts
total_reference_words = 0
total_extracted_words = 0
total_correct_words = 0

# Iterate over all files in the image directory
for image_filename in os.listdir(image_dir):
    # Check if file is a supported image type
    if image_filename.lower().endswith(image_extensions):
        # Get the base filename without extension
        base_filename = os.path.splitext(image_filename)[0]

        # Construct the full paths
        image_path = os.path.join(image_dir, image_filename)
        text_file_path = os.path.join(text_dir, f"{base_filename}.txt")

        # Check if the corresponding text file exists
        if os.path.exists(text_file_path):
            try:
                print(f"\nProcessing {image_filename}...")
                start_time = time.time()

                # Extract text from the image
                extracted_text = extract_text_from_image(image_path)

                # Read text from the pre-existing text file
                pre_existing_text = read_text_file(text_file_path)

                # Calculate metrics
                metrics = calculate_metrics(extracted_text, pre_existing_text)
                precision = metrics['precision']
                recall = metrics['recall']
                f1_score = metrics['f1_score']

                # Update totals
                total_precision += precision
                total_recall += recall
                total_f1 += f1_score
                total_reference_words += metrics['reference_count']
                total_extracted_words += metrics['extracted_count']
                total_correct_words += metrics['correct_count']
                num_files += 1

                # Calculate execution time
                execution_time = time.time() - start_time

                # Store results
                results.append({
                    'filename': image_filename,
                    'precision': precision,
                    'recall': recall,
                    'f1_score': f1_score,
                    'execution_time': execution_time,
                    'reference_count': metrics['reference_count'],
                    'extracted_count': metrics['extracted_count'],
                    'correct_count': metrics['correct_count']
                })

                # Print individual file results
                print(f"Results for {image_filename}:")
                print(f"Reference words: {metrics['reference_count']}")
                print(f"Extracted words: {metrics['extracted_count']}")
                print(f"Correct words: {metrics['correct_count']}")
                print(f"Precision: {precision:.2f}")
                print(f"Recall: {recall:.2f}")
                print(f"F1 Score: {f1_score:.2f}")
                print(f"Execution Time: {execution_time:.2f} seconds")

                # Print extracted text for verification
                print("\nExtracted text (first 100 characters):")
                print(extracted_text[:100] + "...")

            except Exception as e:
                print(f"Error processing {image_filename}: {str(e)}")
        else:
            print(f"Text file not found for image: {image_filename}")

# Calculate and output the averages
if num_files > 0:
    average_precision = total_precision / num_files
    average_recall = total_recall / num_files
    average_f1 = total_f1 / num_files
    average_execution_time = sum(r['execution_time'] for r in results) / num_files

    print("\n" + "="*50)
    print("SUMMARY STATISTICS:")
    print("="*50)
    print(f"Number of files processed: {num_files}")
    print("\nTotal Word Counts:")
    print(f"Total Reference Words: {total_reference_words}")
    print(f"Total Extracted Words: {total_extracted_words}")
    print(f"Total Correct Words: {total_correct_words}")
    print(f"\nAverage Precision: {average_precision:.2f}")
    print(f"Average Recall: {average_recall:.2f}")
    print(f"Average F1 Score: {average_f1:.2f}")
    print(f"Average Execution Time: {average_execution_time:.2f} seconds per file")

    # Find best and worst performing files
    best_f1 = max(results, key=lambda x: x['f1_score'])
    worst_f1 = min(results, key=lambda x: x['f1_score'])

    print("\nBest performing file:")
    print(f"Filename: {best_f1['filename']}")
    print(f"F1 Score: {best_f1['f1_score']:.2f}")
    print(f"Reference words: {best_f1['reference_count']}")
    print(f"Extracted words: {best_f1['extracted_count']}")
    print(f"Correct words: {best_f1['correct_count']}")

    print("\nWorst performing file:")
    print(f"Filename: {worst_f1['filename']}")
    print(f"F1 Score: {worst_f1['f1_score']:.2f}")
    print(f"Reference words: {worst_f1['reference_count']}")
    print(f"Extracted words: {worst_f1['extracted_count']}")
    print(f"Correct words: {worst_f1['correct_count']}")
else:
    print("No matching text files found for any images.")
# Out:
# WARNING:easyocr.easyocr:Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# Processing 8.jpeg...
# Results for 8.jpeg:
# Reference words: 119
# Extracted words: 106
# Correct words: 71
# Precision: 0.67
# Recall: 0.60
# F1 Score: 0.63
# Execution Time: 39.76 seconds
#
# Extracted text (first 100 characters):
# BIOCHIMIE SANGUINE analyse Resultat Unité Valeurs deréferense Résurarantérieyr 4 Sodium 137 mmoVl 13...
#
# Processing 17.jpeg...
# Results for 17.jpeg:
# Reference words: 149
# Extracted words: 138
# Correct words: 111
# Precision: 0.80
# Recall: 0.74
# F1 Score: 0.77
# Execution Time: 34.87 seconds
#
# Extracted text (first 100 characters):
# BIOCHIMIE SANGUINE (suite) Analyse Resultat Unlté Yaleurs_de_référence Besullatantarieur O DFG estim...
#
# Processing 7.jpeg...
# Results for 7.jpeg:
# Reference words: 246
# Extracted words: 223
# Correct words: 197
# Precision: 0.88
# Recall: 0.80
# F1 Score: 0.84
# Execution Time: 59.28 seconds
#
# Extracted text (first 100 characters):
# BIOCHIMIE SANGUINE Analyse Resultat Unite Valeurs_de_référence Résultat antérieur du: CRP 1,6 mg/l (...
#
# Processing 11.jpeg...
# Results for 11.jpeg:
# Reference words: 193
# Extracted words: 175
# Correct words: 157
# Precision: 0.90
# Recall: 0.81
# F1 Score: 0.85
# Execution Time: 61.34 seconds
#
# Extracted text (first 100 characters):
# BIOCHIMIE SANGUINE Analyse Résultat Unité Valeurs_de_référence Besultat antérieur du: Glucose Enzyma...
#
# Processing 10.jpeg...
# Results for 10.jpeg:
# Reference words: 223
# Extracted words: 201
# Correct words: 191
# Precision: 0.95
# Recall: 0.86
# F1 Score: 0.90
# Execution Time: 59.82 seconds
#
# Extracted text (first 100 characters):
# BIOCHIMIE SANGUINE Analyse Résultat Unité Valeurs_de référence Résultatantérieur du: CRP Turbidimetn...
#
# Processing 2.jpeg...
# Results for 2.jpeg:
# Reference words: 385
# Extracted words: 370
# Correct words: 319
# Precision: 0.86
# Recall: 0.83
# F1 Score: 0.85
# Execution Time: 54.08 seconds
#
# Extracted text (first 100 characters):
# Ju/ 10/24 10.11 BIOCHIMIE SANGUINE (suite) Analyse Classification de la maladie Résultat Unité rénal...
#
# Processing 13.jpeg...
# Results for 13.jpeg:
# Reference words: 193
# Extracted words: 173
# Correct words: 162
# Precision: 0.94
# Recall: 0.84
# F1 Score: 0.89
# Execution Time: 58.94 seconds
#
# Extracted text (first 100 characters):
# BIOCHIMIE SANGUINE Analyse Résultat Unité Valeurs_de référence Résultat antérieu du Glucose 2,05 Enz...
#
# Processing 1.jpeg...
# Results for 1.jpeg:
# Reference words: 222
# Extracted words: 202
# Correct words: 168
# Precision: 0.83
# Recall: 0.76
# F1 Score: 0.79
# Execution Time: 63.62 seconds
#
# Extracted text (first 100 characters):
# BIOCHIMIE SANGUINE Analyse Resultas Unlte Valeurs de_reférence Rasultat antérleur 4 CRP 3,7 mg/l ( <...
#
# Processing 20.jpeg...
# Results for 20.jpeg:
# Reference words: 327
# Extracted words: 300
# Correct words: 275
# Precision: 0.92
# Recall: 0.84
# F1 Score: 0.88
# Execution Time: 56.19 seconds
#
# Extracted text (first 100 characters):
# BIOCHIMIE SANGUINE (suite) Analyse Résultat Unlté Valeurs_de_référence Résultatantérieur du: Pré-dia...
#
# Processing 18.jpeg...
# Results for 18.jpeg:
# Reference words: 207
# Extracted words: 187
# Correct words: 167
# Precision: 0.89
# Recall: 0.81
# F1 Score: 0.85
# Execution Time: 52.88 seconds
#
# Extracted text (first 100 characters):
# BIOCHIMIE SANGUINE (suite) Analyse Classification de la maladie rénale Resultat Unité Valeurs_deréfé...
#
# Processing 19.jpeg...
# Results for 19.jpeg:
# Reference words: 193
# Extracted words: 171
# Correct words: 163
# Precision: 0.95
# Recall: 0.84
# F1 Score: 0.90
# Execution Time: 57.92 seconds
#
# Extracted text (first 100 characters):
# BIOCHIMIE SANGUINE Analyse Résultat Unité Valeurs_de référence Résultat antérieur du: Glucose Alinit...
#
# Processing 9.jpeg...
# Results for 9.jpeg:
# Reference words: 341
# Extracted words: 323
# Correct words: 277
# Precision: 0.86
# Recall: 0.81
# F1 Score: 0.83
# Execution Time: 54.54 seconds
#
# Extracted text (first 100 characters):
# BIOCHIMIE SANGUINE (suite) Analyse Résultat Unlté Classification de la maladie rénale chronique (MRC...
#
# Processing 12.jpeg...
# Results for 12.jpeg:
# Reference words: 150
# Extracted words: 138
# Correct words: 135
# Precision: 0.98
# Recall: 0.90
# F1 Score: 0.94
# Execution Time: 61.01 seconds
#
# Extracted text (first 100 characters):
# BIOCHIMIE SANGUINE Apalyse Résultat Unité Valeurs deréférence Résulatantérieu d: Sodium Potentiométr...
#
# Processing 6.jpeg...
# Results for 6.jpeg:
# Reference words: 230
# Extracted words: 210
# Correct words: 177
# Precision: 0.84
# Recall: 0.77
# F1 Score: 0.80
# Execution Time: 58.66 seconds
#
# Extracted text (first 100 characters):
# JUiiUi<4 U.3/ BIOCHIMIE SANGUINE Analyse Résultat Unité Valeurs_de_référence Résultat antérieur du: ...
#
# Processing 3.jpeg...
# Results for 3.jpeg:
# Reference words: 236
# Extracted words: 220
# Correct words: 201
# Precision: 0.91
# Recall: 0.85
# F1 Score: 0.88
# Execution Time: 65.46 seconds
#
# Extracted text (first 100 characters):
# BIOCHIMIE SANGUINE Analyse Résultat Unité Valeurs référence Résultatantérieu du: CRP Turbidimétrie( ...
#
# Processing 16.jpeg...
# Results for 16.jpeg:
# Reference words: 219
# Extracted words: 201
# Correct words: 192
# Precision: 0.96
# Recall: 0.88
# F1 Score: 0.91
# Execution Time: 58.94 seconds
#
# Extracted text (first 100 characters):
# BIOCHIMIE SANGUINE (suite) Analyse Résultat Unité Classification de la maladie rénale Valeurs de réf...
#
# Processing 14.jpeg...
# Results for 14.jpeg:
# Reference words: 301
# Extracted words: 280
# Correct words: 248
# Precision: 0.89
# Recall: 0.82
# F1 Score: 0.85
# Execution Time: 55.78 seconds
#
# Extracted text (first 100 characters):
# BILAN LIPIDIQUE (suite) Analyse Résultat Unité Valeurs_de_référence Résultatantéieu du: Aspect LIMPI...
#
# Processing 15.jpeg...
# Results for 15.jpeg:
# Reference words: 197
# Extracted words: 179
# Correct words: 164
# Precision: 0.92
# Recall: 0.83
# F1 Score: 0.87
# Execution Time: 60.85 seconds
#
# Extracted text (first 100 characters):
# BIOCHIMIE SANGUINE Analyse Résultat Unité Valours_de référence Rosultatanrerieu d Glucose Enzymatiqu...
#
# Processing 5.jpeg...
# Results for 5.jpeg:
# Reference words: 39
# Extracted words: 35
# Correct words: 20
# Precision: 0.57
# Recall: 0.51
# F1 Score: 0.54
# Execution Time: 14.81 seconds
#
# Extracted text (first 100 characters):
# BIOCHIMIE SANGUINE Analyee Resultas Unlte Valeurs de référense Resultatanferieur d ASAT (GoT) 23 UV/...
#
# Processing 4.jpeg...
# Results for 4.jpeg:
# Reference words: 385
# Extracted words: 367
# Correct words: 321
# Precision: 0.87
# Recall: 0.83
# F1 Score: 0.85
# Execution Time: 58.47 seconds
#
# Extracted text (first 100 characters):
# BIOCHIMIE SANGUINE (suite) Analyse Résultat Unité Classification de la maladie rénale chronique Vale...
#
# ==================================================
# SUMMARY STATISTICS:
# ==================================================
# Number of files processed: 20
#
# Total Word Counts:
# Total Reference Words: 4555
# Total Extracted Words: 4199
# Total Correct Words: 3716
#
# Average Precision: 0.87
# Average Recall: 0.80
# Average F1 Score: 0.83
# Average Execution Time: 54.36 seconds per file
#
# Best performing file:
# Filename: 12.jpeg
# F1 Score: 0.94
# Reference words: 150
# Extracted words: 138
# Correct words: 135
#
# Worst performing file:
# Filename: 5.jpeg
# F1 Score: 0.54
# Reference words: 39
# Extracted words: 35
# Correct words: 20

# %% [markdown]
# **Paddleocr**

# %%
# !pip install paddlepaddle
# Out:
# Collecting paddlepaddle
#   Downloading paddlepaddle-2.6.2-cp310-cp310-manylinux1_x86_64.whl.metadata (8.6 kB)
# Requirement already satisfied: httpx in /usr/local/lib/python3.10/dist-packages (from paddlepaddle) (0.27.2)
# Requirement already satisfied: numpy>=1.13 in /usr/local/lib/python3.10/dist-packages (from paddlepaddle) (1.26.4)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from paddlepaddle) (10.4.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from paddlepaddle) (4.4.2)
# Collecting astor (from paddlepaddle)
#   Downloading astor-0.8.1-py2.py3-none-any.whl.metadata (4.2 kB)
# Collecting opt-einsum==3.3.0 (from paddlepaddle)
#   Downloading opt_einsum-3.3.0-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: protobuf>=3.20.2 in /usr/local/lib/python3.10/dist-packages (from paddlepaddle) (3.20.3)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx->paddlepaddle) (3.7.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx->paddlepaddle) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx->paddlepaddle) (1.0.6)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from httpx->paddlepaddle) (3.10)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx->paddlepaddle) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx->paddlepaddle) (0.14.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx->paddlepaddle) (1.2.2)
# Downloading paddlepaddle-2.6.2-cp310-cp310-manylinux1_x86_64.whl (126.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.0/126.0 MB 6.6 MB/s eta 0:00:00
# Downloading opt_einsum-3.3.0-py3-none-any.whl (65 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.5/65.5 kB 4.5 MB/s eta 0:00:00
# Downloading astor-0.8.1-py2.py3-none-any.whl (27 kB)
# Installing collected packages: opt-einsum, astor, paddlepaddle
#   Attempting uninstall: opt-einsum
#     Found existing installation: opt_einsum 3.4.0
#     Uninstalling opt_einsum-3.4.0:
#       Successfully uninstalled opt_einsum-3.4.0
# Successfully installed astor-0.8.1 opt-einsum-3.3.0 paddlepaddle-2.6.2

# %%
# !pip install paddleocr
# Out:
# Collecting paddleocr
#   Downloading paddleocr-2.9.1-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: shapely in /usr/local/lib/python3.10/dist-packages (from paddleocr) (2.0.6)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.10/dist-packages (from paddleocr) (0.24.0)
# Requirement already satisfied: imgaug in /usr/local/lib/python3.10/dist-packages (from paddleocr) (0.4.0)
# Collecting pyclipper (from paddleocr)
#   Downloading pyclipper-1.3.0.post6-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (9.0 kB)
# Collecting lmdb (from paddleocr)
#   Downloading lmdb-1.5.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.1 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from paddleocr) (4.66.5)
# Requirement already satisfied: numpy<2.0 in /usr/local/lib/python3.10/dist-packages (from paddleocr) (1.26.4)
# Collecting rapidfuzz (from paddleocr)
#   Downloading rapidfuzz-3.10.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (from paddleocr) (4.10.0.84)
# Requirement already satisfied: opencv-contrib-python in /usr/local/lib/python3.10/dist-packages (from paddleocr) (4.10.0.84)
# Requirement already satisfied: cython in /usr/local/lib/python3.10/dist-packages (from paddleocr) (3.0.11)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from paddleocr) (10.4.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from paddleocr) (6.0.2)
# Collecting python-docx (from paddleocr)
#   Downloading python_docx-1.1.2-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from paddleocr) (4.12.3)
# Requirement already satisfied: fonttools>=4.24.0 in /usr/local/lib/python3.10/dist-packages (from paddleocr) (4.54.1)
# Collecting fire>=0.3.0 (from paddleocr)
#   Downloading fire-0.7.0.tar.gz (87 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.2/87.2 kB 3.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from paddleocr) (2.32.3)
# Collecting albumentations==1.4.10 (from paddleocr)
#   Downloading albumentations-1.4.10-py3-none-any.whl.metadata (38 kB)
# Collecting albucore==0.0.13 (from paddleocr)
#   Downloading albucore-0.0.13-py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: tomli>=2.0.1 in /usr/local/lib/python3.10/dist-packages (from albucore==0.0.13->paddleocr) (2.0.2)
# Requirement already satisfied: typing-extensions>=4.9.0 in /usr/local/lib/python3.10/dist-packages (from albucore==0.0.13->paddleocr) (4.12.2)
# Requirement already satisfied: opencv-python-headless>=4.9.0.80 in /usr/local/lib/python3.10/dist-packages (from albucore==0.0.13->paddleocr) (4.10.0.84)
# Requirement already satisfied: scipy>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from albumentations==1.4.10->paddleocr) (1.13.1)
# Requirement already satisfied: scikit-learn>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from albumentations==1.4.10->paddleocr) (1.5.2)
# Requirement already satisfied: pydantic>=2.7.0 in /usr/local/lib/python3.10/dist-packages (from albumentations==1.4.10->paddleocr) (2.9.2)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.10/dist-packages (from fire>=0.3.0->paddleocr) (2.5.0)
# Requirement already satisfied: networkx>=2.8 in /usr/local/lib/python3.10/dist-packages (from scikit-image->paddleocr) (3.4.2)
# Requirement already satisfied: imageio>=2.33 in /usr/local/lib/python3.10/dist-packages (from scikit-image->paddleocr) (2.35.1)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.10/dist-packages (from scikit-image->paddleocr) (2024.9.20)
# Requirement already satisfied: packaging>=21 in /usr/local/lib/python3.10/dist-packages (from scikit-image->paddleocr) (24.1)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.10/dist-packages (from scikit-image->paddleocr) (0.4)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->paddleocr) (2.6)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from imgaug->paddleocr) (1.16.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from imgaug->paddleocr) (3.7.1)
# Requirement already satisfied: lxml>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from python-docx->paddleocr) (4.9.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->paddleocr) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->paddleocr) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->paddleocr) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->paddleocr) (2024.8.30)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2.7.0->albumentations==1.4.10->paddleocr) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2.7.0->albumentations==1.4.10->paddleocr) (2.23.4)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.3.2->albumentations==1.4.10->paddleocr) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.3.2->albumentations==1.4.10->paddleocr) (3.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug->paddleocr) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug->paddleocr) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug->paddleocr) (1.4.7)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug->paddleocr) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug->paddleocr) (2.8.2)
# Downloading paddleocr-2.9.1-py3-none-any.whl (544 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 544.7/544.7 kB 13.9 MB/s eta 0:00:00
# Downloading albucore-0.0.13-py3-none-any.whl (8.5 kB)
# Downloading albumentations-1.4.10-py3-none-any.whl (161 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 161.9/161.9 kB 10.3 MB/s eta 0:00:00
# Downloading lmdb-1.5.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (294 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 14.3 MB/s eta 0:00:00
# Downloading pyclipper-1.3.0.post6-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (912 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 912.2/912.2 kB 35.6 MB/s eta 0:00:00
# Downloading python_docx-1.1.2-py3-none-any.whl (244 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.3/244.3 kB 16.7 MB/s eta 0:00:00
# Downloading rapidfuzz-3.10.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 50.5 MB/s eta 0:00:00
# Building wheels for collected packages: fire
#   Building wheel for fire (setup.py) ... done
#   Created wheel for fire: filename=fire-0.7.0-py3-none-any.whl size=114249 sha256=c41dfc126848ddebb19e988441e9e785a4e6fd5ec40c5b14820066815100fbe2
#   Stored in directory: /root/.cache/pip/wheels/19/39/2f/2d3cadc408a8804103f1c34ddd4b9f6a93497b11fa96fe738e
# Successfully built fire
# Installing collected packages: pyclipper, lmdb, rapidfuzz, python-docx, fire, albucore, albumentations, paddleocr
#   Attempting uninstall: albucore
#     Found existing installation: albucore 0.0.19
#     Uninstalling albucore-0.0.19:
#       Successfully uninstalled albucore-0.0.19
#   Attempting uninstall: albumentations
#     Found existing installation: albumentations 1.4.20
#     Uninstalling albumentations-1.4.20:
#       Successfully uninstalled albumentations-1.4.20
# Successfully installed albucore-0.0.13 albumentations-1.4.10 fire-0.7.0 lmdb-1.5.1 paddleocr-2.9.1 pyclipper-1.3.0.post6 python-docx-1.1.2 rapidfuzz-3.10.1

# %%
import os
import time
from paddleocr import PaddleOCR

# Initialize PaddleOCR with both English and French support
print("Initializing PaddleOCR...")
ocr = PaddleOCR(use_angle_cls=True, lang='french', use_gpu=False)
print("PaddleOCR initialized.")

def extract_text_from_image(image_path):
    try:
        result = ocr.ocr(image_path, cls=True)
        if result is None or len(result) == 0:
            return ""

        extracted_text = []
        for line in result:
            line_text = ' '.join([word_info[1][0] for word_info in line])
            extracted_text.append(line_text)
        return ' '.join(extracted_text)
    except Exception as e:
        print(f"Error in OCR processing: {str(e)}")
        return ""

def read_text_file(file_path):
    try:
        with open(file_path, 'r', encoding='utf-8') as file:
            return file.read()
    except UnicodeDecodeError:
        try:
            with open(file_path, 'r', encoding='latin-1') as file:
                return file.read()
        except Exception as e:
            print(f"Error reading file: {str(e)}")
            return ""

def calculate_metrics(extracted_text, reference_text):
    extracted_words = extracted_text.lower().split()
    reference_words = reference_text.lower().split()
    extracted_words_set = set(extracted_words)
    reference_words_set = set(reference_words)

    correct_words = len(extracted_words_set.intersection(reference_words_set))

    precision = correct_words / len(extracted_words) if extracted_words else 0.0
    recall = correct_words / len(reference_words) if reference_words else 0.0
    f1_score = calculate_f1(precision, recall)

    return {
        'precision': precision,
        'recall': recall,
        'f1_score': f1_score,
        'reference_count': len(reference_words),
        'extracted_count': len(extracted_words),
        'correct_count': correct_words
    }

def calculate_f1(precision, recall):
    if precision + recall == 0:
        return 0.0
    return 2 * (precision * recall) / (precision + recall)

# Directories containing the images and text files
image_dir = r'/content/images_analyse'
text_dir = r'/content/ground_truth'

# Variables to track metrics
total_precision = 0.0
total_recall = 0.0
total_f1 = 0.0
num_files = 0
total_execution_time = 0.0

# List of supported image extensions
image_extensions = ('.jpg', '.jpeg', '.png')

# Store results for each file
results = []

# Store total word counts
total_reference_words = 0
total_extracted_words = 0
total_correct_words = 0

print("\nStarting OCR evaluation...")
print("="*50)

# Iterate over all files in the image directory
for image_filename in os.listdir(image_dir):
    if image_filename.lower().endswith(image_extensions):
        base_filename = os.path.splitext(image_filename)[0]
        image_path = os.path.join(image_dir, image_filename)
        text_file_path = os.path.join(text_dir, f"{base_filename}.txt")

        if os.path.exists(text_file_path):
            try:
                print(f"\nProcessing {image_filename}...")
                start_time = time.time()

                extracted_text = extract_text_from_image(image_path)
                pre_existing_text = read_text_file(text_file_path)

                # Calculate metrics
                metrics = calculate_metrics(extracted_text, pre_existing_text)

                # Update totals
                total_precision += metrics['precision']
                total_recall += metrics['recall']
                total_f1 += metrics['f1_score']
                total_reference_words += metrics['reference_count']
                total_extracted_words += metrics['extracted_count']
                total_correct_words += metrics['correct_count']
                num_files += 1

                execution_time = time.time() - start_time

                # Store results
                results.append({
                    'filename': image_filename,
                    'metrics': metrics,
                    'execution_time': execution_time
                })

                # Print individual file results
                print(f"Results for {image_filename}:")
                print(f"Reference words: {metrics['reference_count']}")
                print(f"Extracted words: {metrics['extracted_count']}")
                print(f"Correct words: {metrics['correct_count']}")
                print(f"Precision: {metrics['precision']:.2f}")
                print(f"Recall: {metrics['recall']:.2f}")
                print(f"F1 Score: {metrics['f1_score']:.2f}")
                print(f"Execution Time: {execution_time:.2f} seconds")

                print("\nExtracted text sample (first 100 characters):")
                print(extracted_text[:100] + "..." if len(extracted_text) > 100 else extracted_text)

            except Exception as e:
                print(f"Error processing {image_filename}: {str(e)}")
        else:
            print(f"Text file not found for image: {image_filename}")

# Calculate and output the averages
if num_files > 0:
    average_precision = total_precision / num_files
    average_recall = total_recall / num_files
    average_f1 = total_f1 / num_files
    average_execution_time = sum(r['execution_time'] for r in results) / num_files

    print("\n" + "="*50)
    print("SUMMARY STATISTICS:")
    print("="*50)
    print(f"Number of files processed: {num_files}")

    print("\nTotal Word Counts:")
    print(f"Total Reference Words: {total_reference_words}")
    print(f"Total Extracted Words: {total_extracted_words}")
    print(f"Total Correct Words: {total_correct_words}")

    print(f"\nAverage Metrics:")
    print(f"Average Precision: {average_precision:.2f}")
    print(f"Average Recall: {average_recall:.2f}")
    print(f"Average F1 Score: {average_f1:.2f}")
    print(f"Average Execution Time: {average_execution_time:.2f} seconds per file")

    # Find best and worst performing files
    best_f1 = max(results, key=lambda x: x['metrics']['f1_score'])
    worst_f1 = min(results, key=lambda x: x['metrics']['f1_score'])

    print("\nBest performing file:")
    print(f"Filename: {best_f1['filename']}")
    print(f"F1 Score: {best_f1['metrics']['f1_score']:.2f}")
    print(f"Reference words: {best_f1['metrics']['reference_count']}")
    print(f"Extracted words: {best_f1['metrics']['extracted_count']}")
    print(f"Correct words: {best_f1['metrics']['correct_count']}")

    print("\nWorst performing file:")
    print(f"Filename: {worst_f1['filename']}")
    print(f"F1 Score: {worst_f1['metrics']['f1_score']:.2f}")
    print(f"Reference words: {worst_f1['metrics']['reference_count']}")
    print(f"Extracted words: {worst_f1['metrics']['extracted_count']}")
    print(f"Correct words: {worst_f1['metrics']['correct_count']}")
else:
    print("No matching text files found for any images.")
# Out:
# Initializing PaddleOCR...
# download https://paddleocr.bj.bcebos.com/PP-OCRv3/english/en_PP-OCRv3_det_infer.tar to /root/.paddleocr/whl/det/en/en_PP-OCRv3_det_infer/en_PP-OCRv3_det_infer.tar
# 100%|██████████| 3910/3910 [00:00<00:00, 9571.34it/s]
# download https://paddleocr.bj.bcebos.com/PP-OCRv3/multilingual/latin_PP-OCRv3_rec_infer.tar to /root/.paddleocr/whl/rec/latin/latin_PP-OCRv3_rec_infer/latin_PP-OCRv3_rec_infer.tar
# 100%|██████████| 9930/9930 [00:00<00:00, 18182.14it/s]
# download https://paddleocr.bj.bcebos.com/dygraph_v2.0/ch/ch_ppocr_mobile_v2.0_cls_infer.tar to /root/.paddleocr/whl/cls/ch_ppocr_mobile_v2.0_cls_infer/ch_ppocr_mobile_v2.0_cls_infer.tar
# 100%|██████████| 2138/2138 [00:00<00:00, 5574.27it/s]
# [2024/10/31 05:58:04] ppocr DEBUG: Namespace(help='==SUPPRESS==', use_gpu=False, use_xpu=False, use_npu=False, use_mlu=False, ir_optim=True, use_tensorrt=False, min_subgraph_size=15, precision='fp32', gpu_mem=500, gpu_id=0, image_dir=None, page_num=0, det_algorithm='DB', det_model_dir='/root/.paddleocr/whl/det/en/en_PP-OCRv3_det_infer', det_limit_side_len=960, det_limit_type='max', det_box_type='quad', det_db_thresh=0.3, det_db_box_thresh=0.6, det_db_unclip_ratio=1.5, max_batch_size=10, use_dilation=False, det_db_score_mode='fast', det_east_score_thresh=0.8, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_sast_score_thresh=0.5, det_sast_nms_thresh=0.2, det_pse_thresh=0, det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, scales=[8, 16, 32], alpha=1.0, beta=1.0, fourier_degree=5, rec_algorithm='SVTR_LCNet', rec_model_dir='/root/.paddleocr/whl/rec/latin/latin_PP-OCRv3_rec_infer', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_batch_num=6, max_text_length=25, rec_char_dict_path='/usr/local/lib/python3.10/dist-packages/paddleocr/ppocr/utils/dict/latin_dict.txt', use_space_char=True, vis_font_path='./doc/fonts/simfang.ttf', drop_score=0.5, e2e_algorithm='PGNet', e2e_model_dir=None, e2e_limit_side_len=768, e2e_limit_type='max', e2e_pgnet_score_thresh=0.5, e2e_char_dict_path='./ppocr/utils/ic15_dict.txt', e2e_pgnet_valid_set='totaltext', e2e_pgnet_mode='fast', use_angle_cls=True, cls_model_dir='/root/.paddleocr/whl/cls/ch_ppocr_mobile_v2.0_cls_infer', cls_image_shape='3, 48, 192', label_list=['0', '180'], cls_batch_num=6, cls_thresh=0.9, enable_mkldnn=False, cpu_threads=10, use_pdserving=False, warmup=False, sr_model_dir=None, sr_image_shape='3, 32, 128', sr_batch_num=1, draw_img_save_dir='./inference_results', save_crop_res=False, crop_res_save_dir='./output', use_mp=False, total_process_num=1, process_id=0, benchmark=False, save_log_path='./log_output/', show_log=True, use_onnx=False, return_word_box=False, output='./output', table_max_len=488, table_algorithm='TableAttn', table_model_dir=None, merge_no_span_structure=True, table_char_dict_path=None, formula_algorithm='LaTeXOCR', formula_model_dir=None, formula_char_dict_path=None, formula_batch_num=1, layout_model_dir=None, layout_dict_path=None, layout_score_threshold=0.5, layout_nms_threshold=0.5, kie_algorithm='LayoutXLM', ser_model_dir=None, re_model_dir=None, use_visual_backbone=True, ser_dict_path='../train_data/XFUND/class_list_xfun.txt', ocr_order_method=None, mode='structure', image_orientation=False, layout=True, table=True, formula=False, ocr=True, recovery=False, recovery_to_markdown=False, use_pdf2docx_api=False, invert=False, binarize=False, alphacolor=(255, 255, 255), lang='french', det=True, rec=True, type='ocr', savefile=False, ocr_version='PP-OCRv4', structure_version='PP-StructureV2')
# PaddleOCR initialized.
#
# Starting OCR evaluation...
# ==================================================
#
# Processing 8.jpeg...
# [2024/10/31 05:58:06] ppocr DEBUG: dt_boxes num : 53, elapsed : 0.4596884250640869
# [2024/10/31 05:58:06] ppocr DEBUG: cls num  : 53, elapsed : 0.18625402450561523
# [2024/10/31 05:58:09] ppocr DEBUG: rec_res num  : 53, elapsed : 2.6016993522644043
# Results for 8.jpeg:
# Reference words: 119
# Extracted words: 65
# Correct words: 31
# Precision: 0.48
# Recall: 0.26
# F1 Score: 0.34
# Execution Time: 3.42 seconds
#
# Extracted text sample (first 100 characters):
# BIOCHIMIE SANGUINE Anaiyse Résultat Unite Va eference du: Sodium 137 mmol/l 135-145 133 26/10/24 Ali...
#
# Processing 17.jpeg...
# [2024/10/31 05:58:09] ppocr DEBUG: dt_boxes num : 50, elapsed : 0.19984173774719238
# [2024/10/31 05:58:10] ppocr DEBUG: cls num  : 50, elapsed : 0.1641373634338379
# [2024/10/31 05:58:13] ppocr DEBUG: rec_res num  : 50, elapsed : 2.9998340606689453
# Results for 17.jpeg:
# Reference words: 149
# Extracted words: 103
# Correct words: 62
# Precision: 0.60
# Recall: 0.42
# F1 Score: 0.49
# Execution Time: 3.43 seconds
#
# Extracted text sample (first 100 characters):
# BIOCHIMIE SANGUINE(suite Analyse Resultat Unité Valeurs_de référence Resultat.anterieur du: DFG esti...
#
# Processing 7.jpeg...
# [2024/10/31 05:58:13] ppocr DEBUG: dt_boxes num : 66, elapsed : 0.48748302459716797
# [2024/10/31 05:58:13] ppocr DEBUG: cls num  : 66, elapsed : 0.17363286018371582
# [2024/10/31 05:58:17] ppocr DEBUG: rec_res num  : 66, elapsed : 3.5060858726501465
# Results for 7.jpeg:
# Reference words: 246
# Extracted words: 120
# Correct words: 51
# Precision: 0.42
# Recall: 0.21
# F1 Score: 0.28
# Execution Time: 4.26 seconds
#
# Extracted text sample (first 100 characters):
# BIOCHIMIESANGUINE Analyse Résultat Unité Valeurs de référence Résultat antérieur du: CRP 1,6mg/l <5,...
#
# Processing 11.jpeg...
# [2024/10/31 05:58:17] ppocr DEBUG: dt_boxes num : 68, elapsed : 0.271914005279541
# [2024/10/31 05:58:17] ppocr DEBUG: cls num  : 68, elapsed : 0.2677457332611084
# [2024/10/31 05:58:22] ppocr DEBUG: rec_res num  : 68, elapsed : 4.119510650634766
# Results for 11.jpeg:
# Reference words: 193
# Extracted words: 122
# Correct words: 52
# Precision: 0.43
# Recall: 0.27
# F1 Score: 0.33
# Execution Time: 4.76 seconds
#
# Extracted text sample (first 100 characters):
# BIOCHIMIESANGUINE Analyse Résultat Unite Valeurs de référence Résultatanterieur du: Glucose 2,14g/l ...
#
# Processing 10.jpeg...
# [2024/10/31 05:58:22] ppocr DEBUG: dt_boxes num : 69, elapsed : 0.1876966953277588
# [2024/10/31 05:58:22] ppocr DEBUG: cls num  : 69, elapsed : 0.22092533111572266
# [2024/10/31 05:58:25] ppocr DEBUG: rec_res num  : 69, elapsed : 3.1840457916259766
# Results for 10.jpeg:
# Reference words: 223
# Extracted words: 134
# Correct words: 55
# Precision: 0.41
# Recall: 0.25
# F1 Score: 0.31
# Execution Time: 3.67 seconds
#
# Extracted text sample (first 100 characters):
# BIOCHIMIESANGUINE Analyse Résultat Unite Valeurs de référence Résultatantérieur du: CRP 32,4mg/l Tur...
#
# Processing 2.jpeg...
# [2024/10/31 05:58:26] ppocr DEBUG: dt_boxes num : 109, elapsed : 0.5240142345428467
# [2024/10/31 05:58:26] ppocr DEBUG: cls num  : 109, elapsed : 0.3244295120239258
# [2024/10/31 05:58:30] ppocr DEBUG: rec_res num  : 109, elapsed : 4.215501070022583
# Results for 2.jpeg:
# Reference words: 385
# Extracted words: 206
# Correct words: 85
# Precision: 0.41
# Recall: 0.22
# F1 Score: 0.29
# Execution Time: 5.13 seconds
#
# Extracted text sample (first 100 characters):
# 30/10/2410:11 BIOCHIMIE SANGUINE(suite Analyse Classification de la maladie rénale chronique (MRC en...
#
# Processing 13.jpeg...
# [2024/10/31 05:58:31] ppocr DEBUG: dt_boxes num : 68, elapsed : 0.5020961761474609
# [2024/10/31 05:58:31] ppocr DEBUG: cls num  : 68, elapsed : 0.31295156478881836
# [2024/10/31 05:58:35] ppocr DEBUG: rec_res num  : 68, elapsed : 3.7821199893951416
# Results for 13.jpeg:
# Reference words: 193
# Extracted words: 108
# Correct words: 47
# Precision: 0.44
# Recall: 0.24
# F1 Score: 0.31
# Execution Time: 4.70 seconds
#
# Extracted text sample (first 100 characters):
# BIOCHIMIE SANGUINE Analyse Résultat Unite Valeurs de référence Résultat antérieur due Glucose 2,05g/...
#
# Processing 1.jpeg...
# [2024/10/31 05:58:35] ppocr DEBUG: dt_boxes num : 71, elapsed : 0.3005223274230957
# [2024/10/31 05:58:36] ppocr DEBUG: cls num  : 71, elapsed : 0.20826935768127441
# [2024/10/31 05:58:39] ppocr DEBUG: rec_res num  : 71, elapsed : 3.2883479595184326
# Results for 1.jpeg:
# Reference words: 222
# Extracted words: 120
# Correct words: 35
# Precision: 0.29
# Recall: 0.16
# F1 Score: 0.20
# Execution Time: 3.87 seconds
#
# Extracted text sample (first 100 characters):
# BIOCHIMIE SANGUINE Analyse Resultat Unite Valeurs de reference Resultat.antérieur du: CRP 3,7mg/l <5...
#
# Processing 20.jpeg...
# [2024/10/31 05:58:40] ppocr DEBUG: dt_boxes num : 103, elapsed : 0.6829469203948975
# [2024/10/31 05:58:40] ppocr DEBUG: cls num  : 103, elapsed : 0.30522918701171875
# [2024/10/31 05:58:44] ppocr DEBUG: rec_res num  : 103, elapsed : 4.121529817581177
# Results for 20.jpeg:
# Reference words: 327
# Extracted words: 193
# Correct words: 90
# Precision: 0.47
# Recall: 0.28
# F1 Score: 0.35
# Execution Time: 5.18 seconds
#
# Extracted text sample (first 100 characters):
# BIOCHIMIE SANGUINE(suite Analyse Résultat Unite Valeurs de référence Résultat antérieur du: -Pré-dia...
#
# Processing 18.jpeg...
# [2024/10/31 05:58:45] ppocr DEBUG: dt_boxes num : 67, elapsed : 0.4392414093017578
# [2024/10/31 05:58:45] ppocr DEBUG: cls num  : 67, elapsed : 0.27585291862487793
# [2024/10/31 05:58:49] ppocr DEBUG: rec_res num  : 67, elapsed : 4.260927200317383
# Results for 18.jpeg:
# Reference words: 207
# Extracted words: 128
# Correct words: 60
# Precision: 0.47
# Recall: 0.29
# F1 Score: 0.36
# Execution Time: 5.08 seconds
#
# Extracted text sample (first 100 characters):
# BlOCHIMIE SANGUINE (suite) Analvse Resultat Unite Valeu de référence Resultat anterieur du: go sans ...
#
# Processing 19.jpeg...
# [2024/10/31 05:58:50] ppocr DEBUG: dt_boxes num : 69, elapsed : 0.32686805725097656
# [2024/10/31 05:58:50] ppocr DEBUG: cls num  : 69, elapsed : 0.2148425579071045
# [2024/10/31 05:58:53] ppocr DEBUG: rec_res num  : 69, elapsed : 2.826209783554077
# Results for 19.jpeg:
# Reference words: 193
# Extracted words: 122
# Correct words: 50
# Precision: 0.41
# Recall: 0.26
# F1 Score: 0.32
# Execution Time: 3.43 seconds
#
# Extracted text sample (first 100 characters):
# BIOCHIMIE SANGUINE Analyse Resultat Unite Valeurs de référence Résultatantérieur du: Glucose 1,16g/l...
#
# Processing 9.jpeg...
# [2024/10/31 05:58:53] ppocr DEBUG: dt_boxes num : 74, elapsed : 0.45854949951171875
# [2024/10/31 05:58:53] ppocr DEBUG: cls num  : 74, elapsed : 0.25662922859191895
# [2024/10/31 05:58:56] ppocr DEBUG: rec_res num  : 74, elapsed : 2.8320577144622803
# Results for 9.jpeg:
# Reference words: 341
# Extracted words: 150
# Correct words: 64
# Precision: 0.43
# Recall: 0.19
# F1 Score: 0.26
# Execution Time: 3.61 seconds
#
# Extracted text sample (first 100 characters):
# BIOCHIMIE SANGUINE(suite) Analyse Résultat Classification de la maladie rénale chronique (MRC) en fo...
#
# Processing 12.jpeg...
# [2024/10/31 05:58:57] ppocr DEBUG: dt_boxes num : 70, elapsed : 0.30351805686950684
# [2024/10/31 05:58:57] ppocr DEBUG: cls num  : 70, elapsed : 0.2316908836364746
# [2024/10/31 05:59:00] ppocr DEBUG: rec_res num  : 70, elapsed : 3.1554136276245117
# Results for 12.jpeg:
# Reference words: 150
# Extracted words: 100
# Correct words: 45
# Precision: 0.45
# Recall: 0.30
# F1 Score: 0.36
# Execution Time: 3.77 seconds
#
# Extracted text sample (first 100 characters):
# BIOCHIMIE SANGUINE Analyse Resultat Unite Valeurs de référence Résultat antérieur Sodium du: 142 mmo...
#
# Processing 6.jpeg...
# [2024/10/31 05:59:01] ppocr DEBUG: dt_boxes num : 69, elapsed : 0.5190565586090088
# [2024/10/31 05:59:01] ppocr DEBUG: cls num  : 69, elapsed : 0.2997896671295166
# [2024/10/31 05:59:04] ppocr DEBUG: rec_res num  : 69, elapsed : 3.4259793758392334
# Results for 6.jpeg:
# Reference words: 230
# Extracted words: 114
# Correct words: 44
# Precision: 0.39
# Recall: 0.19
# F1 Score: 0.26
# Execution Time: 4.35 seconds
#
# Extracted text sample (first 100 characters):
# 3071012406.37 BIOCHIMIE SANGUINE Analyse Résultat Unité Valeurs de référence Résultat antérieur du: ...
#
# Processing 3.jpeg...
# [2024/10/31 05:59:05] ppocr DEBUG: dt_boxes num : 83, elapsed : 0.32709527015686035
# [2024/10/31 05:59:05] ppocr DEBUG: cls num  : 83, elapsed : 0.252246618270874
# [2024/10/31 05:59:10] ppocr DEBUG: rec_res num  : 83, elapsed : 5.09316349029541
# Results for 3.jpeg:
# Reference words: 236
# Extracted words: 162
# Correct words: 79
# Precision: 0.49
# Recall: 0.33
# F1 Score: 0.40
# Execution Time: 5.75 seconds
#
# Extracted text sample (first 100 characters):
# BIOCHIMIE SANGUINE Analyse Resultat Unité Valeurs de référence Resultat antérieur du: CRP 1,9mg/l Tu...
#
# Processing 16.jpeg...
# [2024/10/31 05:59:10] ppocr DEBUG: dt_boxes num : 80, elapsed : 0.30150341987609863
# [2024/10/31 05:59:11] ppocr DEBUG: cls num  : 80, elapsed : 0.26090073585510254
# [2024/10/31 05:59:15] ppocr DEBUG: rec_res num  : 80, elapsed : 4.387126445770264
# Results for 16.jpeg:
# Reference words: 219
# Extracted words: 160
# Correct words: 77
# Precision: 0.48
# Recall: 0.35
# F1 Score: 0.41
# Execution Time: 5.03 seconds
#
# Extracted text sample (first 100 characters):
# BIOCHIMIE SANGUINE(suite Analyse Résultat Unité Valeurs de référence Classification de la maladie ré...
#
# Processing 14.jpeg...
# [2024/10/31 05:59:16] ppocr DEBUG: dt_boxes num : 110, elapsed : 0.7343642711639404
# [2024/10/31 05:59:16] ppocr DEBUG: cls num  : 110, elapsed : 0.45256614685058594
# [2024/10/31 05:59:21] ppocr DEBUG: rec_res num  : 110, elapsed : 4.1288487911224365
# Results for 14.jpeg:
# Reference words: 301
# Extracted words: 156
# Correct words: 52
# Precision: 0.33
# Recall: 0.17
# F1 Score: 0.23
# Execution Time: 5.42 seconds
#
# Extracted text sample (first 100 characters):
# BILAN LIPIDIQUE(suite Analyse Résultat Unité Valeurs de référence Résultat antérieur du: Aspect LIMP...
#
# Processing 15.jpeg...
# [2024/10/31 05:59:22] ppocr DEBUG: dt_boxes num : 50, elapsed : 0.8848791122436523
# [2024/10/31 05:59:22] ppocr DEBUG: cls num  : 50, elapsed : 0.23981833457946777
# [2024/10/31 05:59:25] ppocr DEBUG: rec_res num  : 50, elapsed : 3.0612566471099854
# Results for 15.jpeg:
# Reference words: 197
# Extracted words: 99
# Correct words: 38
# Precision: 0.38
# Recall: 0.19
# F1 Score: 0.26
# Execution Time: 4.31 seconds
#
# Extracted text sample (first 100 characters):
# BIOCHIMIESANGUINE Analyse Resultat Unite Valeurs.de.reférence Resultatanterieur du: Glucose 1.04g/l ...
#
# Processing 5.jpeg...
# [2024/10/31 05:59:25] ppocr DEBUG: dt_boxes num : 19, elapsed : 0.16905665397644043
# [2024/10/31 05:59:25] ppocr DEBUG: cls num  : 19, elapsed : 0.09122490882873535
# [2024/10/31 05:59:26] ppocr DEBUG: rec_res num  : 19, elapsed : 0.754227876663208
# Results for 5.jpeg:
# Reference words: 39
# Extracted words: 26
# Correct words: 11
# Precision: 0.42
# Recall: 0.28
# F1 Score: 0.34
# Execution Time: 1.04 seconds
#
# Extracted text sample (first 100 characters):
# BIOCHIMIE SANGUINE Analyse Resultat Unite Valeurs de reférence Resultat.anterieur du: ASAT(GOT) 23UI...
#
# Processing 4.jpeg...
# [2024/10/31 05:59:27] ppocr DEBUG: dt_boxes num : 113, elapsed : 0.6060781478881836
# [2024/10/31 05:59:27] ppocr DEBUG: cls num  : 113, elapsed : 0.47894906997680664
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-5faceb18ef6f> in <cell line: 89>()
#      98                 start_time = time.time()
#      99
# --> 100                 extracted_text = extract_text_from_image(image_path)
#     101                 pre_existing_text = read_text_file(text_file_path)
#     102
#
# <ipython-input-4-5faceb18ef6f> in extract_text_from_image(image_path)
#      10 def extract_text_from_image(image_path):
#      11     try:
# ---> 12         result = ocr.ocr(image_path, cls=True)
#      13         if result is None or len(result) == 0:
#      14             return ""
#
# /usr/local/lib/python3.10/dist-packages/paddleocr/paddleocr.py in ocr(self, img, det, rec, cls, bin, inv, alpha_color, slice)
#     758             for img in imgs:
#     759                 img = preprocess_image(img)
# --> 760                 dt_boxes, rec_res, _ = self.__call__(img, cls, slice)
#     761                 if not dt_boxes and not rec_res:
#     762                     ocr_res.append(None)
#
# /usr/local/lib/python3.10/dist-packages/paddleocr/tools/infer/predict_system.py in __call__(self, img, cls, slice)
#     142             )
#     143
# --> 144         rec_res, elapse = self.text_recognizer(img_crop_list)
#     145         time_dict["rec"] = elapse
#     146         logger.debug("rec_res num  : {}, elapsed : {}".format(len(rec_res), elapse))
#
# /usr/local/lib/python3.10/dist-packages/paddleocr/tools/infer/predict_rec.py in __call__(self, img_list)
#     791                 else:
#     792                     self.input_tensor.copy_from_cpu(norm_img_batch)
# --> 793                     self.predictor.run()
#     794                     outputs = []
#     795                     for output_tensor in self.output_tensors:
#
# KeyboardInterrupt:

# %%
import os
import time
from paddleocr import PaddleOCR

# Initialize PaddleOCR with both English and French support
print("Initializing PaddleOCR...")
ocr = PaddleOCR(use_angle_cls=True, lang='french', use_gpu=False)
print("PaddleOCR initialized.")

def extract_text_from_image(image_path):
    try:
        result = ocr.ocr(image_path, cls=True)
        if result is None or len(result) == 0:
            return ""

        extracted_text = []
        for line in result:
            line_text = ' '.join([word_info[1][0] for word_info in line])
            extracted_text.append(line_text)
        return ' '.join(extracted_text)
    except Exception as e:
        print(f"Error in OCR processing: {str(e)}")
        return ""

def read_text_file(file_path):
    try:
        with open(file_path, 'r', encoding='utf-8') as file:
            return file.read()
    except UnicodeDecodeError:
        try:
            with open(file_path, 'r', encoding='latin-1') as file:
                return file.read()
        except Exception as e:
            print(f"Error reading file: {str(e)}")
            return ""

def calculate_metrics(extracted_text, reference_text):
    extracted_words = extracted_text.lower().split()
    reference_words = reference_text.lower().split()
    extracted_words_set = set(extracted_words)
    reference_words_set = set(reference_words)

    correct_words = len(extracted_words_set.intersection(reference_words_set))

    precision = correct_words / len(extracted_words) if extracted_words else 0.0
    recall = correct_words / len(reference_words) if reference_words else 0.0
    f1_score = calculate_f1(precision, recall)

    return {
        'precision': precision,
        'recall': recall,
        'f1_score': f1_score,
        'reference_count': len(reference_words),
        'extracted_count': len(extracted_words),
        'correct_count': correct_words
    }

def calculate_f1(precision, recall):
    if precision + recall == 0:
        return 0.0
    return 2 * (precision * recall) / (precision + recall)

def print_text_comparison(filename, reference_text, extracted_text):
    print("\n" + "="*50)
    print(f"DETAILED TEXT COMPARISON FOR: {filename}")
    print("="*50)

    print("\nREFERENCE TEXT (Ground Truth):")
    print("-"*30)
    print(reference_text)

    print("\nEXTRACTED TEXT (OCR Result):")
    print("-"*30)
    print(extracted_text)

    print("\nWORD COUNT COMPARISON:")
    print(f"Reference text word count: {len(reference_text.split())}")
    print(f"Extracted text word count: {len(extracted_text.split())}")

# Directories containing the images and text files
image_dir = r'/content/images_analyse'
text_dir = r'/content/ground_truth'

# Variables to track metrics
total_precision = 0.0
total_recall = 0.0
total_f1 = 0.0
num_files = 0
total_execution_time = 0.0

# List of supported image extensions
image_extensions = ('.jpg', '.jpeg', '.png')

# Store results for each file
results = []

# Store total word counts
total_reference_words = 0
total_extracted_words = 0
total_correct_words = 0

print("\nStarting OCR evaluation...")
print("="*50)

# Iterate over all files in the image directory
for image_filename in os.listdir(image_dir):
    if image_filename.lower().endswith(image_extensions):
        base_filename = os.path.splitext(image_filename)[0]
        image_path = os.path.join(image_dir, image_filename)
        text_file_path = os.path.join(text_dir, f"{base_filename}.txt")

        if os.path.exists(text_file_path):
            try:
                print(f"\nProcessing {image_filename}...")
                start_time = time.time()

                extracted_text = extract_text_from_image(image_path)
                reference_text = read_text_file(text_file_path)

                # Print full text comparison
                print_text_comparison(image_filename, reference_text, extracted_text)

                # Calculate metrics
                metrics = calculate_metrics(extracted_text, reference_text)

                # Update totals
                total_precision += metrics['precision']
                total_recall += metrics['recall']
                total_f1 += metrics['f1_score']
                total_reference_words += metrics['reference_count']
                total_extracted_words += metrics['extracted_count']
                total_correct_words += metrics['correct_count']
                num_files += 1

                execution_time = time.time() - start_time

                # Store results
                results.append({
                    'filename': image_filename,
                    'metrics': metrics,
                    'execution_time': execution_time
                })

                # Print individual file metrics
                print(f"\nMETRICS FOR: {image_filename}")
                print(f"Reference words: {metrics['reference_count']}")
                print(f"Extracted words: {metrics['extracted_count']}")
                print(f"Correct words: {metrics['correct_count']}")
                print(f"Precision: {metrics['precision']:.2f}")
                print(f"Recall: {metrics['recall']:.2f}")
                print(f"F1 Score: {metrics['f1_score']:.2f}")
                print(f"Execution Time: {execution_time:.2f} seconds")

            except Exception as e:
                print(f"Error processing {image_filename}: {str(e)}")
        else:
            print(f"Text file not found for image: {image_filename}")

# Calculate and output the averages
if num_files > 0:
    average_precision = total_precision / num_files
    average_recall = total_recall / num_files
    average_f1 = total_f1 / num_files
    average_execution_time = sum(r['execution_time'] for r in results) / num_files

    print("\n" + "="*50)
    print("FINAL SUMMARY STATISTICS:")
    print("="*50)
    print(f"Number of files processed: {num_files}")

    print("\nTotal Word Counts:")
    print(f"Total Reference Words: {total_reference_words}")
    print(f"Total Extracted Words: {total_extracted_words}")
    print(f"Total Correct Words: {total_correct_words}")

    print(f"\nAverage Metrics:")
    print(f"Average Precision: {average_precision:.2f}")
    print(f"Average Recall: {average_recall:.2f}")
    print(f"Average F1 Score: {average_f1:.2f}")
    print(f"Average Execution Time: {average_execution_time:.2f} seconds per file")

    # Find best and worst performing files
    best_f1 = max(results, key=lambda x: x['metrics']['f1_score'])
    worst_f1 = min(results, key=lambda x: x['metrics']['f1_score'])

    print("\nBest performing file:")
    print(f"Filename: {best_f1['filename']}")
    print(f"F1 Score: {best_f1['metrics']['f1_score']:.2f}")
    print(f"Reference words: {best_f1['metrics']['reference_count']}")
    print(f"Extracted words: {best_f1['metrics']['extracted_count']}")
    print(f"Correct words: {best_f1['metrics']['correct_count']}")

    print("\nWorst performing file:")
    print(f"Filename: {worst_f1['filename']}")
    print(f"F1 Score: {worst_f1['metrics']['f1_score']:.2f}")
    print(f"Reference words: {worst_f1['metrics']['reference_count']}")
    print(f"Extracted words: {worst_f1['metrics']['extracted_count']}")
    print(f"Correct words: {worst_f1['metrics']['correct_count']}")
else:
    print("No matching text files found for any images.")
# Out:
# Initializing PaddleOCR...
# [2024/10/31 06:48:22] ppocr DEBUG: Namespace(help='==SUPPRESS==', use_gpu=False, use_xpu=False, use_npu=False, use_mlu=False, ir_optim=True, use_tensorrt=False, min_subgraph_size=15, precision='fp32', gpu_mem=500, gpu_id=0, image_dir=None, page_num=0, det_algorithm='DB', det_model_dir='/root/.paddleocr/whl/det/en/en_PP-OCRv3_det_infer', det_limit_side_len=960, det_limit_type='max', det_box_type='quad', det_db_thresh=0.3, det_db_box_thresh=0.6, det_db_unclip_ratio=1.5, max_batch_size=10, use_dilation=False, det_db_score_mode='fast', det_east_score_thresh=0.8, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_sast_score_thresh=0.5, det_sast_nms_thresh=0.2, det_pse_thresh=0, det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, scales=[8, 16, 32], alpha=1.0, beta=1.0, fourier_degree=5, rec_algorithm='SVTR_LCNet', rec_model_dir='/root/.paddleocr/whl/rec/latin/latin_PP-OCRv3_rec_infer', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_batch_num=6, max_text_length=25, rec_char_dict_path='/usr/local/lib/python3.10/dist-packages/paddleocr/ppocr/utils/dict/latin_dict.txt', use_space_char=True, vis_font_path='./doc/fonts/simfang.ttf', drop_score=0.5, e2e_algorithm='PGNet', e2e_model_dir=None, e2e_limit_side_len=768, e2e_limit_type='max', e2e_pgnet_score_thresh=0.5, e2e_char_dict_path='./ppocr/utils/ic15_dict.txt', e2e_pgnet_valid_set='totaltext', e2e_pgnet_mode='fast', use_angle_cls=True, cls_model_dir='/root/.paddleocr/whl/cls/ch_ppocr_mobile_v2.0_cls_infer', cls_image_shape='3, 48, 192', label_list=['0', '180'], cls_batch_num=6, cls_thresh=0.9, enable_mkldnn=False, cpu_threads=10, use_pdserving=False, warmup=False, sr_model_dir=None, sr_image_shape='3, 32, 128', sr_batch_num=1, draw_img_save_dir='./inference_results', save_crop_res=False, crop_res_save_dir='./output', use_mp=False, total_process_num=1, process_id=0, benchmark=False, save_log_path='./log_output/', show_log=True, use_onnx=False, return_word_box=False, output='./output', table_max_len=488, table_algorithm='TableAttn', table_model_dir=None, merge_no_span_structure=True, table_char_dict_path=None, formula_algorithm='LaTeXOCR', formula_model_dir=None, formula_char_dict_path=None, formula_batch_num=1, layout_model_dir=None, layout_dict_path=None, layout_score_threshold=0.5, layout_nms_threshold=0.5, kie_algorithm='LayoutXLM', ser_model_dir=None, re_model_dir=None, use_visual_backbone=True, ser_dict_path='../train_data/XFUND/class_list_xfun.txt', ocr_order_method=None, mode='structure', image_orientation=False, layout=True, table=True, formula=False, ocr=True, recovery=False, recovery_to_markdown=False, use_pdf2docx_api=False, invert=False, binarize=False, alphacolor=(255, 255, 255), lang='french', det=True, rec=True, type='ocr', savefile=False, ocr_version='PP-OCRv4', structure_version='PP-StructureV2')
# PaddleOCR initialized.
#
# Starting OCR evaluation...
# ==================================================
#
# Processing 8.jpeg...
# [2024/10/31 06:48:24] ppocr DEBUG: dt_boxes num : 53, elapsed : 0.49106693267822266
# [2024/10/31 06:48:24] ppocr DEBUG: cls num  : 53, elapsed : 0.20406222343444824
# [2024/10/31 06:48:26] ppocr DEBUG: rec_res num  : 53, elapsed : 1.8818914890289307
#
# ==================================================
# DETAILED TEXT COMPARISON FOR: 8.jpeg
# ==================================================
#
# REFERENCE TEXT (Ground Truth):
# ------------------------------
# BIOCHIMIE SANGUINE
# Analyse                                      Résultat    Unité                    Valeurs de référence     Résultat antérieur    dat
# Sodium                                       137        mmol/l                   ( 135 - 145 )            133                   26/10/24
# Potentiométrie Indirecte (Alinity ci)
# Potassium                                    3,95       mmol/l                   ( 3,70 - 5,30 )          3,60                  27/10/24
# Potentiométrie Indirecte (Alinity ci)
# Chlorures                                    100        mmol/l                   ( 95 - 110 )             99                    26/10/24
# Potentiométrie Indirecte (Alinity ci)
# Réserve alcaline                            27         mmol/l                   ( 21 - 28 )              26                    26/10/24
# Enzymatique (Alinity ci)
# Trou anionique plasmatique                   14         mmol/l                   ( 12 - 20 )              11                    26/10/24
# (Calcul)
# Protéines Totales                            68         g/l                      ( 64 - 83 )              59                    26/10/24
# Biuret cinétique (Alinity ci)
# Calcium Total                                86         mg/l                     ( 80 - 105 )             78                    26/10/24
# Colorimétrie (Alinity ci)
# Soit                                     2,15       mmol/l                   ( 2,00 - 2,63 )          1,95                  26/10/24
#
# EXTRACTED TEXT (OCR Result):
# ------------------------------
# BIOCHIMIE SANGUINE Anaiyse Résultat Unite Va eference du: Sodium 137 mmol/l 135-145 133 26/10/24 Alinity c Potassium 3,95mmol/l 3,70-5,30 3,60 27/10/24 cte (Alinity ci) Chlorures 100 mmol/l 95-110 99 26/10/24 ométrie Indirecte (Alinity ci) Réserve alcaline 27mmol/l 21-28 26 26/10/24 Trou anionique plasmatique 14mmol/l 12-20 11 26/10/24 (Calcun) Protéines Totales 68g/l 64-83 59 26/10/24 Calcium Total 86mg/l 80-105 78 26/10/24 Soit 2.15mmoll 2.00-2.63 1.95 26/10/24
#
# WORD COUNT COMPARISON:
# Reference text word count: 119
# Extracted text word count: 65
#
# METRICS FOR: 8.jpeg
# Reference words: 119
# Extracted words: 65
# Correct words: 31
# Precision: 0.48
# Recall: 0.26
# F1 Score: 0.34
# Execution Time: 2.65 seconds
#
# Processing 17.jpeg...
# [2024/10/31 06:48:26] ppocr DEBUG: dt_boxes num : 50, elapsed : 0.2451798915863037
# [2024/10/31 06:48:27] ppocr DEBUG: cls num  : 50, elapsed : 0.20615434646606445
# [2024/10/31 06:48:29] ppocr DEBUG: rec_res num  : 50, elapsed : 2.6060290336608887
#
# ==================================================
# DETAILED TEXT COMPARISON FOR: 17.jpeg
# ==================================================
#
# REFERENCE TEXT (Ground Truth):
# ------------------------------
# BIOCHIMIE SANGUINE (suite)
# Analyse                                      Résultat    Unité                    Valeurs de référence     Résultat antérieur    dat
# DFG estimé par CKD-EPI                       70         ml/min/1,73m²                                     57                    23/10/24
# Classification de la maladie rénale chronique (MRC) en fonction du DFG (KDIGO 2011)
# >= 90 sans marqueur d' atteinte rénale         Pas d'atteinte rénale
# >= 90 avec marqueurs d' atteinte rénale*       G1  : MRC avec DFG normal ou augmenté
# 60 à 89 avec marqueurs d' atteinte rénale*     G2  : MRC avec DFG légèrement diminué
# 45 à 59                                        G3a : IRC légère à modérée
# 30 à 44                                        G3b : IRC modérée à sévère
# 15 à 29                                        G4  : IRC sévère
# < 15 ou dialyse                                G5  : IRC terminale
# (*) Albuminurie de faible débit, protéinurie clinique, hématurie, leucocyturie ou anomalies morphologiques ou histologiques persitantes
# plus de tois mois.
# Calcium Total                                93         mg/l                     ( 80 - 105 )             96                    23/10/24
# Colorimétrie (Alinity ci)
# Soit                                     2,33       mmol/l                   ( 2,00 - 2,63 )          2,40                  23/10/24
#
# EXTRACTED TEXT (OCR Result):
# ------------------------------
# BIOCHIMIE SANGUINE(suite Analyse Resultat Unité Valeurs_de référence Resultat.anterieur du: DFG estimé par CKD-EPI 70ml/min/1,73m2 Classification de la maladie renale chronique (MRC) en fonction du DFG (KDIGO 2011 57 23/10/24 90 sans marqueur d' atteinte renale Pas d'atteinte rénale 90 avec marqueurs d atteinte renale G1 MRC avec DFG normal ou augmenté G2 :MRC avec DFG légérement diminué 45 59 G3a:IRC 1égere a modérée 30 ta 44 15 29 G4 IRCsévere no dialyse G5 () Albuminurie de faible débit,protéinurie clinique,hematurie,leucocyturie ou anomalies morphologiqu IRC terminale plus de tois mois Calcium Total 93 mg/1 80-105 96 23/10/24 Colorimetrie (Alinity ci) Soit 2,33mmol/l 2,00-2.63 2,40 23/10/24
#
# WORD COUNT COMPARISON:
# Reference text word count: 149
# Extracted text word count: 103
#
# METRICS FOR: 17.jpeg
# Reference words: 149
# Extracted words: 103
# Correct words: 62
# Precision: 0.60
# Recall: 0.42
# F1 Score: 0.49
# Execution Time: 3.12 seconds
#
# Processing 7.jpeg...
# [2024/10/31 06:48:30] ppocr DEBUG: dt_boxes num : 66, elapsed : 0.3491806983947754
# [2024/10/31 06:48:30] ppocr DEBUG: cls num  : 66, elapsed : 0.21332168579101562
# [2024/10/31 06:48:33] ppocr DEBUG: rec_res num  : 66, elapsed : 3.340183734893799
#
# ==================================================
# DETAILED TEXT COMPARISON FOR: 7.jpeg
# ==================================================
#
# REFERENCE TEXT (Ground Truth):
# ------------------------------
# BIOCHIMIE SANGUINE
# Analyse                                      Résultat    Unité                    Valeurs de référence     Résultat antérieur    dat
# CRP                                          1,6        mg/l                     ( < 5,0 )                5,3                   25/12/18
# Turbidimétrie(Alinity ci)
# Ferritine                                    17,5       ng/ml                    ( 11,0 - 306,8 )         13,0                  18/07/24
# Chimiluminescence (Alinity ci)
# En cas de maladie rénale chronique, d'insuffisance cardiaque ou de maladie inflammatoire chronique de l'intestin :
#
# Carence martiale absolue si CST < 20% et ferritine < 100 μg/L.
# Carence martiale fonctionnelle si CST < 20% et ferritine >100 μg/L.
#
# Glucose                                      0,85       g/l                      ( 0,70 - 1,05 )          0,98                  05/04/24
# Enzymatique (Alinity ci)
# Soit                                     4,73       mmol/l                   ( 3,89 - 5,84 )          5,45                  05/04/24
# -Une Glycémie à jeûn > ou = 1.26 g/l (Soit 7 mmol/l) à 2 reprises est en faveur d'un diabète sucré (OMS)
# -Une Glycémie à jeûn chez la femme enceinte > ou = 0.92 g/l (Soit 5.06 mmol/l) est en faveur d'un diabète gestationnel
# HbA1c (NGSP)                                5,9        %                        ( < 5,6 )                 6,0                   18/07/24
# HPLC (Arkray)
# HbA1c (IFCC)                            41,0       mmol/mol                 ( < 38,0 )                42,0                  18/07/24
#
# Pré-diabète :         5.7 à 6.4%
# Diabète:             > ou = 6.5%
# Surveillance du diabète :
#
# < ou = 7%    :   Très bon équilibre glycémique
# 7.1 à 8%     :   Bon équilibre glycémique
#
#
# 8.1%       :   Mauvais équilibre glycémique
#
#
#
#
#
# Résultat à interpréter en dehors des contextes suivants : hémoglobinopathie, anémie , transfusion, insuffisance rénale et grossesse; un
# dosage des fructosamines plasmatiques est alors conseillé.
# Urée                                         0,14       g/l                      ( 0,15 - 0,38 )          0,23                  18/07/24
# Enzymatique (Alinity ci)
# Soit                                     2,3        mmol/l                   ( 2,5 - 6,4 )            3,8                   18/07/24
#
# EXTRACTED TEXT (OCR Result):
# ------------------------------
# BIOCHIMIESANGUINE Analyse Résultat Unité Valeurs de référence Résultat antérieur du: CRP 1,6mg/l <5,0 5,3 25/12/18 Turbidimetrie(Alinity ci) Ferritine 17.5ng/ml 11,0-306,8 13,0 18/07/24 Chimiluminescence (Alinity ci) En cas de maladie rénale chronique,d'insuffisance cardiaque ou de maladie inflammatoire chronique de rintestin: -Carencemartialeabsoluesi CsT<20%et ferritine<100g/L. -Carence martiale fonctionnelle si CsT<20% et ferritine>100g/L Glucose 0,85g/l 070-1,05 0,98 05/04/24 Enzymatique(Alinity ci) 4.73mmol/l 3.89-5.84 5.45 05/04/24 Soit -Une Glycemie a jean chez la femme enceinte > ou = 0.92 g/(Soit 5.06 mmovl) est en faveur d'un diabete gestationnel HbA1c(NGSP) 5,9% <5,6 6.0 18/07/24 HPLC(Arkray) 41,0mmol/mol <38,0 42,0 18/07/24 HbA1cIFCC -Pré-diabéte: 5.76.4% -Diabéte >ou=6.5% Surveillance du diabete <ou=7% Tres bon equilibre glycemique 7.18% Bon équilibre glycémique >8.1% Uree 0,15-0,38 0.23 18/07/24 0,14g/l Soit 2.5-6.4 3.8 18/07/24 2,3mmol/l
#
# WORD COUNT COMPARISON:
# Reference text word count: 246
# Extracted text word count: 120
#
# METRICS FOR: 7.jpeg
# Reference words: 246
# Extracted words: 120
# Correct words: 51
# Precision: 0.42
# Recall: 0.21
# F1 Score: 0.28
# Execution Time: 3.97 seconds
#
# Processing 11.jpeg...
# [2024/10/31 06:48:34] ppocr DEBUG: dt_boxes num : 68, elapsed : 0.2968924045562744
# [2024/10/31 06:48:34] ppocr DEBUG: cls num  : 68, elapsed : 0.3099799156188965
# [2024/10/31 06:48:38] ppocr DEBUG: rec_res num  : 68, elapsed : 4.295604467391968
#
# ==================================================
# DETAILED TEXT COMPARISON FOR: 11.jpeg
# ==================================================
#
# REFERENCE TEXT (Ground Truth):
# ------------------------------
# BIOCHIMIE SANGUINE
# Analyse                                            Résultat        Unité                     Valeurs de référence      Résultat antérieur    du:
# Glucose                                            2,14     g/l                              ( 0,70 - 1,05 )          1,96                  15/04/24
# Enzymatique (Alinity ci)
# Soit                                              11,90     mmol/l                           ( 3,89 - 5,84 )          10,90                 15/04/24
# -Une Glycémie à jeûn > ou = 1.26 g/l (Soit 7 mmol/l) à 2 reprises est en faveur d'un diabète sucré (OMS)
# HbA1c (NGSP)                                      7,7      %                                ( < 5,6 )                8,1                   15/04/24
# HPLC (Arkray)
# HbA1c (IFCC)                                      61,0     mmol/mol                         ( < 38,0 )               65,0                  15/04/24
#
# Pré-diabète :        5.7 à 6.4%
# Diabète:            > ou = 6.5%
# Surveillance du diabète :
#
# < ou = 7%    : Très bon équilibre glycémique
# 7.1 à 8%     : Bon équilibre glycémique
#
#
# 8.1%       : Mauvais équilibre glycémique
#
#
#
#
#
# Résultat à interpréter en dehors des contextes suivants : hémoglobinopathie, anémie , transfusion, insuffisance rénale et grossesse; un
# dosage des fructosamines plasmatiques est alors conseillé.
# Urée                                              0,31     g/l                              ( 0,15 - 0,38 )          0,45                  15/04/24
# Enzymatique (Alinity ci)
# Soit                                              5,2      mmol/l                           ( 2,5 - 6,4 )            7,5                   15/04/24
# Créatinine                                        8        mg/l                             ( 6 - 13 )               8                     15/04/24
# Jaffé cinétique (Alinity ci)
# Soit                                              70,80    µmol/l                           ( 53,00 - 115,00 )       70,80                 15/04/24
# DFG estimé par CKD-EPI                            95       ml/min/1,73m²                                            96                    15/04/24
#
# EXTRACTED TEXT (OCR Result):
# ------------------------------
# BIOCHIMIESANGUINE Analyse Résultat Unite Valeurs de référence Résultatanterieur du: Glucose 2,14g/l 0,70-1,05 Enzymatique(Alinity ci) 1,96 15/04/24 Soit 11,90mmol/l 3,89-5,84 10,90 15/04/24 -Une Glycémie a jeün>ou =1.26 g/l (Soit 7 mmoVI)a 2 reprises est en faveur d'un diabete sucré(OMS HbA1cNGSP 7,7% <5,6 HPLC(Arkray) 8,1 15/04/24 HbA1cIFCC 61,0mmol/mol <38,0 65,0 15/04/24 -Pré-diabéte: 5.76.4% -Diabete: >ou=6.5% Surveillance du diabéte: Trés bon équilibre glycémique -7.18% Bon équilibre glycémique ->8.1% Mauvais équilibre glycémique Résultat a interpreter en dehors des contextes suivants: hémoglobinopathie,anemie.transfusion, insuffisance renale et grossesse un dosage des fructosamines plasmatiques est alors conseillé. Urée 0.31g/l Enzymatique (Alinity cl) 0,15-0,38 0.45 15/04/24 Soit 5.2mmol/l 2.5-6.4 7.5 15/04/24 Créatinine 8mg/l Jaffe cinétique(Alinity ci) 6-13 8 15/04/24 Soit 70.80mol/l 53.00-115.00 70.80 15/04/24 DFG estimé par CKD-EPI 95ml/min/1.73m² 96 15/04/24
#
# WORD COUNT COMPARISON:
# Reference text word count: 193
# Extracted text word count: 122
#
# METRICS FOR: 11.jpeg
# Reference words: 193
# Extracted words: 122
# Correct words: 52
# Precision: 0.43
# Recall: 0.27
# F1 Score: 0.33
# Execution Time: 5.02 seconds
#
# Processing 10.jpeg...
# [2024/10/31 06:48:38] ppocr DEBUG: dt_boxes num : 69, elapsed : 0.21345281600952148
# [2024/10/31 06:48:39] ppocr DEBUG: cls num  : 69, elapsed : 0.24995875358581543
# [2024/10/31 06:48:42] ppocr DEBUG: rec_res num  : 69, elapsed : 3.310399293899536
#
# ==================================================
# DETAILED TEXT COMPARISON FOR: 10.jpeg
# ==================================================
#
# REFERENCE TEXT (Ground Truth):
# ------------------------------
# BIOCHIMIE SANGUINE
# Analyse                                              Résultat        Unité                    Valeurs de référence        Résultat antérieur    du:
# CRP
# Turbidimétrie(Alinity ci)                           32,4            mg/l                     ( < 5,0 )                   20,4                  16/03/23
# Ferritine
# Chimiluminescence (Alinity ci)                      55,0            ng/ml                    ( 11,0 - 306,8 )
# En cas de maladie rénale chronique, d'insuffisance cardiaque ou de maladie inflammatoire chronique de l'intestin :
#
# Carence martiale absolue si CST < 20% et ferritine < 100 μg/L.
# Carence martiale fonctionnelle si CST < 20% et ferritine >100 μg/L.
#
# Sodium
# Potentiométrie Indirecte (Alinity ci)              143             mmol/l                   ( 135 - 145 )               144                   25/06/24
# Potassium
# Potentiométrie Indirecte (Alinity ci)              3,98            mmol/l                   ( 3,70 - 5,30 )             3,96                  25/06/24
# Chlorures
# Potentiométrie Indirecte (Alinity ci)              110             mmol/l                   ( 95 - 110 )                111                   25/06/24
# Réserve alcaline
# Enzymatique (Alinity ci)                           25              mmol/l                   ( 21 - 28 )                 23                    25/06/24
# Trou anionique plasmatique
# (Calcul)                                           12              mmol/l                   ( 12 - 20 )                 14                    25/06/24
# Protéines Totales
# Biuret cinétique (Alinity ci)                      76              g/l                      ( 64 - 83 )                 71                    25/06/24
# Glucose
# Enzymatique (Alinity ci)                           0,94            g/l                      ( 0,70 - 1,05 )             0,73                  25/06/24
# Soit                                       5,23            mmol/l                   ( 3,89 - 5,84 )             4,06                  25/06/24
# -Une Glycémie à jeun > ou = 1.26 g/l (Soit 7 mmol/l) à 2 reprises est en faveur d'un diabète sucré (OMS)
# -Une Glycémie à jeun chez la femme enceinte > ou = 0.92 g/l (Soit 5.06 mmol/l) est en faveur d'un diabète gestationnel
#
# EXTRACTED TEXT (OCR Result):
# ------------------------------
# BIOCHIMIESANGUINE Analyse Résultat Unite Valeurs de référence Résultatantérieur du: CRP 32,4mg/l Turbidimetrie(Alinity ci) <5,0 20,4 16/03/23 Ferritine 55,0ng/ml Chimiluminescence (Alinity ci) 11,0-306,8 En cas de maladie rénale chronique,d'insuffisance cardiaque ou de maladie inflammatoire chronique de Pintestin: Sodium 143mmol/l 135-145 144 Potentiométrie Indirecte (Alinity ci) 25/06/24 Potassium 3,98mmol/l 3,70-5,30 Potentiometrie Indirecte (Alinity ci) 3.96 25/06/24 Chlorures 110mmol/l 95-110 111 25/06/24 Potentiométrie Indirecte (Alinity cl) Reserve alcaline 25mmol/l 21-28 23 25/06/24 Enzymatique Alinity ci) Trou anionique plasmatique 12mmol/l (Calcul) 12-20 14 25/06/24 Protéines Totales 76g/1 64-83 Biuret cinetiaue(Alinity ci 11 25/06/24 Glucose 0.94g/l 0,70-1,05 Enzymatique (Alinity ci 0.73 25/06/24 Soit 5.23mmol/l 3.89-5.84 4,06 25/06/24 -Une Glycémie ajeün>ou =1.26 g/l(Soit 7mmolla 2 reprises est en faveur d'un diabete sucre(OMS -Une Glycemie a jeün chez la femme enceinte>ou =0.92 g/lSoit 5.06 mmo/l est en faveur d'un diabete gestationnel
#
# WORD COUNT COMPARISON:
# Reference text word count: 223
# Extracted text word count: 134
#
# METRICS FOR: 10.jpeg
# Reference words: 223
# Extracted words: 134
# Correct words: 55
# Precision: 0.41
# Recall: 0.25
# F1 Score: 0.31
# Execution Time: 3.85 seconds
#
# Processing 2.jpeg...
# [2024/10/31 06:48:43] ppocr DEBUG: dt_boxes num : 109, elapsed : 0.4605543613433838
# [2024/10/31 06:48:43] ppocr DEBUG: cls num  : 109, elapsed : 0.37063169479370117
# [2024/10/31 06:48:47] ppocr DEBUG: rec_res num  : 109, elapsed : 4.4528279304504395
#
# ==================================================
# DETAILED TEXT COMPARISON FOR: 2.jpeg
# ==================================================
#
# REFERENCE TEXT (Ground Truth):
# ------------------------------
# BIOCHIMIE SANGUINE (suite)
# Analyse                                      Résultat    Unité                    Valeurs de référence     Résultat antérieur    dat
# Classification de la maladie rénale chronique (MRC) en fonction du DFG (KDIGO 2011)
# >= 90 sans marqueur d' atteinte rénale         Pas d'atteinte rénale
# >= 90 avec marqueurs d' atteinte rénale*       G1  : MRC avec DFG normal ou augmenté
# 60 à 89 avec marqueurs d' atteinte rénale*     G2  : MRC avec DFG légèrement diminué
# 45 à 59                                        G3a : IRC légère à modérée
# 30 à 44                                        G3b : IRC modérée à sévère
# 15 à 29                                        G4  : IRC sévère
# < 15 ou dialyse                                G5  : IRC terminale
# (*) Albuminurie de faible débit, protéinurie clinique, hématurie, leucocyturie ou anomalies morphologiques ou histologiques persitantes
# plus de tois mois.
# ASAT (GOT)                                   14         UI/l                     ( < 35 )                 16                    25/07/24
# UV sans P5P(Alinity ci)
# ALAT (GPT)                                   13         UI/l                     ( < 40 )                 10                    25/07/24
# UV sans P5P(Alinity ci)
# Créatine kinase                              45         UI/l                     ( 24 - 195 )             46                    01/03/24
# Enzymatique (Alinity ci)
# BILAN LIPIDIQUE
# Analyse                                      Résultat    Unité                    Valeurs de référence     Résultat antérieur    dat
# Aspect                                                   LIMPIDE
# Triglycérides                                0,65       g/l                      ( 0,60 - 1,50 )          0,78                  25/07/24
# Enzymatique (Alinity ci)
# Soit                                     0,74       mmol/l                   ( 0,68 - 1,71 )          0,89                  25/07/24
# Cholestérol HDL                              0,38       g/l                      ( 0,40 - 0,60 )          0,41                  25/07/24
# Enzymatique (Alinity ci)
# Soit                                     0,98       mmol/l                   ( 1,03 - 1,54 )          1,06                  25/07/24
# Cholestérol LDL                              0,93       g/l                      ( < 1,55 )               0,85                  25/07/24
# (Calcul)
# Soit                                     2,40       mmol/l                   ( < 4,00 )               2,19                  25/07/24
# Cholestérol                                  1,44       g/l                      ( 1,50 - 2,00 )          1,42                  25/07/24
# Enzymatique (Alinity ci)
# Soit                                     3,72       mmol/l                   ( 3,87 - 5,16 )          3,66                  25/07/24
# Cholesterol non HDL                          1,06       g/l                                              1,01                  25/07/24
# (Calcul)
# Soit                                     2,73       mmol/l                                           2,61                  25/07/24
# Les objectifs pour un patient dans le cadre d'une prise en charge initiale (ESC 2021) :
# -Haut risque cardiovasculaire          : LDL-c < 1,00 g/L (2,6 mmol/L) et non-HDLc < 1,30 g/L (3,4 mmol/L).
# -Très Haut risque cardiovasculaire     : LDL-c < 0,70 g/L (1,8 mmol/L) et non-HDLc < 1,00 g/L (2,6 mmol/L).
# Les objectifs pour un patient dans le cadre d'une intensification thérapeutique (ESC 2021) :
# -Haut risque cardiovasculaire          : LDL-c < 0,70 g/L (1,8 mmol/L) associé à baisse de 50% et non-HDLc < 1,00 g/L (2,6 mmol/L).
# -Très Haut risque cardiovasculaire     : LDL-c < 0,55 g/L (1,4 mmol/L) associé à baisse de 50% et non-HDLc < 0,85 g/L (2,2 mmol/L).
#
# EXTRACTED TEXT (OCR Result):
# ------------------------------
# 30/10/2410:11 BIOCHIMIE SANGUINE(suite Analyse Classification de la maladie rénale chronique (MRC en fonction du DFG (KDIGO 2011) Résultat Unite Valeurs de référence Résultat antérieur >=90sans marqueur d'atteinte rénale du: >=90 avec marqueursdatteinte rénale* Pas d'atteinte rénale 60a 89 avec marqueursdatteinte rénale* G1MRC avecDFG normal ou augmenté 4559 G2MRC avec DFG légerement diminué 3044 G3aIRC légérea modérée 1529 G3b:IRCmodéréeasévere <15ou dialyse G4IRC sévere (Albuminurie de faible débit protéinurie clinique hmaturieleucocyturie ou anomalies morphologiques ou histologiques persitantes G5IRC terminale plus de tois mois ASAT(GOT) 14UI/ UV sans P5P(Alinity ci <35 16 25/07/24 ALAT(GPT) 13U/I UV sans P5P(Alinity ci (<40) 10 25/07/24 Créatine kinase 45UI/ 24-195 Enzymatique (Alinity ci) 46 01/03/24 BILAN LIPIDIQUE Analyse Résultat Unité Valeurs de référence Résultat antérieur du: Aspect LIMPIDE Triglycérides 0,65g/l 0,60-1,50 0,78 25/07/24 Enzymatique (Alinity ci) Soit 0.74mmol/l 0.68-1.71 0,89 25/07/24 Cholestérol HDL 0,38g/l 0,40-0,60 0,41 25/07/24 EnzymatiqueAlinity ci) Soit 0,98mmol/l 1.03-1.54 1,06 25/07/24 Cholestérol LDL 0,93g/l 1.55 0.85 25/07/24 (Calcul) Soit 2,40mmol/l <4,00 2,19 25/07/24 Cholestérol 1,44g/l 1,50-2,00 1.42 25/07/24 Enzymatique Alinity ci) Soit 3.72mmol/l 3.87-5.16 3.66 25/07/24 Cholesterol non HDL 1,06g/l 1.01 25/07/24 (Calcul) Soit 2.73mmol/ 2,61 25/07/24 Les objectifs pour un patient dans le cadre dune prise en charge initiale ESC 2021: -Haut risque cardiovasculaire LDL-c<1.00g/L2.6mmoVLet non-HDLc<1.30g/L3.4mmoVL -Haut risque cardiovasculaire
#
# WORD COUNT COMPARISON:
# Reference text word count: 385
# Extracted text word count: 206
#
# METRICS FOR: 2.jpeg
# Reference words: 385
# Extracted words: 206
# Correct words: 85
# Precision: 0.41
# Recall: 0.22
# F1 Score: 0.29
# Execution Time: 5.36 seconds
#
# Processing 13.jpeg...
# [2024/10/31 06:48:48] ppocr DEBUG: dt_boxes num : 68, elapsed : 0.5213875770568848
# [2024/10/31 06:48:48] ppocr DEBUG: cls num  : 68, elapsed : 0.3320767879486084
# [2024/10/31 06:48:52] ppocr DEBUG: rec_res num  : 68, elapsed : 3.6992857456207275
#
# ==================================================
# DETAILED TEXT COMPARISON FOR: 13.jpeg
# ==================================================
#
# REFERENCE TEXT (Ground Truth):
# ------------------------------
# BIOCHIMIE SANGUINE
# Analyse                                      Résultat    Unité                    Valeurs de référence     Résultat antérieur    dat
# Glucose                                      2,05       g/l                      ( 0,70 - 1,05 )          1.51                  25/07/24
# Enzymatique (Alinity ci)
# Soit                                     11,40      mmol/l                   ( 3,89 - 5,84 )          8.40                  25/07/24
# -Une Glycémie à jeûn > ou = 1.26 g/l (Soit 7 mmol/l) à 2 reprises est en faveur d'un diabète sucré (OMS)
# HbA1c (NGSP)                                9,6        %                        ( < 5,6 )                 9.9                   25/07/24
# HPLC (Arkray)
# HbA1c (IFCC)                            82,0       mmol/mol                 ( < 38,0 )                85.0                  25/07/24
#
# Pré-diabète :         5.7 à 6.4%
# Diabète:             > ou = 6.5%
# Surveillance du diabète :
#
# < ou = 7%    :   Très bon équilibre glycémique
# 7.1 à 8%     :   Bon équilibre glycémique
#
#
# 8.1%       :   Mauvais équilibre glycémique
#
#
#
#
#
# Résultat à interpréter en dehors des contextes suivants : hémoglobinopathie, anémie , transfusion, insuffisance rénale et grossesse; un
# dosage des fructosamines plasmatiques est alors conseillé.
# Urée                                         0,22       g/l                      ( 0,15 - 0,38 )          0.25                  25/07/24
# Enzymatique (Alinity ci)
# Soit                                     3,7        mmol/l                   ( 2,5 - 6,4 )            4.2                   25/07/24
# Créatinine                                   8          mg/l                     ( 6 - 13 )               8                     25/07/24
# Jaffé cinétique (Alinity ci)
# Soit                                     70,80      μmol/l                   ( 53,00 - 115,00 )       70.80                 25/07/24
# DFG estimé par CKD-EPI                       103        ml/min/1,73m²                                     103                   25/07/24
#
# EXTRACTED TEXT (OCR Result):
# ------------------------------
# BIOCHIMIE SANGUINE Analyse Résultat Unite Valeurs de référence Résultat antérieur due Glucose 2,05g/l 0,70-1,05 Enzymatique (Alinity ci) 1.51 25/07/24 Soit 11,40mmol/l 3.89-5.84 8,40 25/07/24 -Une Glycémie ajeün>ou =1.26 g/l(Soit 7mmoVla 2 reprises est en faveur d'un diabete sucré(OMS) HbA1cNGSP) 9,6% <5,6 9.9 HPLC(Arkray) 25/07/24 HbA1cIFCC 82,0mmol/mol 38,0 85.0 25/07/24 -Pré-diabete: 5.76.4% -Diabéte: >ou=6.5% -Surveillance du diabéte: <ou=7% :Trés bonéquilibre glycémique 7.18% Bon éguilibre glycémigue >8.1% Mauvais équilibre glycémique dosage des fructosamines plasmatiques est alors conseillé. Urée 0,22g/l Enzymatique(Alinity ci) 0,15-0,38 0.25 25/07/24 Soit 3.7mmol/l 2.5-6.4 4.2 25/07/24 Creatinine 8mg/l 6-13 Jaffe cinetique (Alinity ci) 8 25/07/24 Soit 70.80mol/l 53.00-115,00 70.80 25/07/24 DFG estimé par CKD-EPI 103ml/min/1,73m² 103 25/07/24
#
# WORD COUNT COMPARISON:
# Reference text word count: 193
# Extracted text word count: 108
#
# METRICS FOR: 13.jpeg
# Reference words: 193
# Extracted words: 108
# Correct words: 47
# Precision: 0.44
# Recall: 0.24
# F1 Score: 0.31
# Execution Time: 4.65 seconds
#
# Processing 1.jpeg...
# [2024/10/31 06:48:52] ppocr DEBUG: dt_boxes num : 71, elapsed : 0.31987476348876953
# [2024/10/31 06:48:53] ppocr DEBUG: cls num  : 71, elapsed : 0.22501611709594727
# [2024/10/31 06:48:56] ppocr DEBUG: rec_res num  : 71, elapsed : 3.4183337688446045
#
# ==================================================
# DETAILED TEXT COMPARISON FOR: 1.jpeg
# ==================================================
#
# REFERENCE TEXT (Ground Truth):
# ------------------------------
# BIOCHIMIE SANGUINE
# Analyse                                    Résultat      Unité            Valeurs de référence     Résultat antérieur     du:
# CRP                                          3,7         mg/l             ( < 5,0 )                7,2                    25/07/24
# Turbidimétrie (Alinity ci)
# Glucose                                      1,24        g/l              ( 0,70 - 1,05 )          1,52                   25/07/24
# Enzymatique (Alinity ci)
# Soit                                 6,89        mmol/l           ( 3,89 - 5,84 )          8,45                   25/07/24
# -Une Glycémie à jeun > ou = 1.26 g/l (Soit 7 mmol/l) à 2 reprises est en faveur d'un diabète sucré (OMS)
# -Une Glycémie à jeun chez la femme enceinte > ou = 0.92 g/l (Soit 5.06 mmol/l) est en faveur d'un diabète gestationnel
# HbA1c (NGSP)                                8,0         %                ( < 5,6 )                 8,8                    25/07/24
# HPLC (Array)
# HbA1c (IFCC)                        64,0        mmol/mol         ( < 38,0 )                73,0                   25/07/24
#
# Pré-diabète :        5.7 à 6.4%
# Diabète:            > ou = 6.5%
# Surveillance du diabète :
# - < ou = 7%   : Très bon équilibre glycémique
# - 7.1 à 8%    : Bon équilibre glycémique
# - > 8.1%      : Mauvais équilibre glycémique
#
# Résultat à interpréter en dehors des contextes suivants : hémoglobinopathie, anémie, transfusion, insuffisance rénale et grossesse; un dosage des fructosamines plasmatiques est alors conseillé.
# Urée                                        0,19        g/l              ( 0,15 - 0,38 )          0,22                   25/07/24
# Enzymatique (Alinity ci)
# Soit                                3,2         mmol/l           ( 2,5 - 6,4 )            3,7                    25/07/24
# Créatinine                                  7           mg/l             ( 6 - 13 )               7                      25/07/24
# µame cinétique (Alinity ci)
# Soit                                61,95       µmol/l           ( 53,00 - 115,00 )       61,95                  25/07/24
#
# EXTRACTED TEXT (OCR Result):
# ------------------------------
# BIOCHIMIE SANGUINE Analyse Resultat Unite Valeurs de reference Resultat.antérieur du: CRP 3,7mg/l <5,0 7.2 25/07/24 Turbidimetrie(Alinity ci) 1,24g/l 0,70-1,05 1,52 Glucose 25/07/24 Enzymatique(Alinity ci) 6,89mmol/l 3,89-5.84 8.45 Soit 25/07/24 -Une Glycemie ajean> ou =1.26 g/lSoit 7mmoVI a 2 reprises est en faveur d'un diabete sucre(OMS -Une Glycémie a jean chez la femme enceinte>ou =0.92 g/l(Soit 5.06 mmoll) est en faveur d'un diabete gestationnel 8,0% <5,6 8.8 25/07/24 HbA1cNGSP) HPLC(Arkray) 64,0 mmol/mol <38.0 73.0 25/07/24 HbA1cIFCC -Pré-diabete: 5.76.4% -Diabéte: >ou=6.5% -Surveillancedudiabéte: <ou=7% Tres bon equilibreglycemique 7.1a8% Bon éguilibre glycemique >8.1% Mauvais équilibre glycemique sesseun 0.22 25/07/24 0.15-0.38 0,19g/l Urée 3.7 25/07/24 Enzymatique (Alinity ci) 2.5-6.4 3.2mmol/l Soit 7 25/07/24 6-13 7mg/l Creatinine 61.95 25/07/24 Jatle cinetique (Alinity ci) 61.95mol/l 53.00-115.00 Soit
#
# WORD COUNT COMPARISON:
# Reference text word count: 222
# Extracted text word count: 120
#
# METRICS FOR: 1.jpeg
# Reference words: 222
# Extracted words: 120
# Correct words: 35
# Precision: 0.29
# Recall: 0.16
# F1 Score: 0.20
# Execution Time: 4.05 seconds
#
# Processing 20.jpeg...
# [2024/10/31 06:48:57] ppocr DEBUG: dt_boxes num : 103, elapsed : 0.5529451370239258
# [2024/10/31 06:48:57] ppocr DEBUG: cls num  : 103, elapsed : 0.34494495391845703
# [2024/10/31 06:49:02] ppocr DEBUG: rec_res num  : 103, elapsed : 4.507425546646118
#
# ==================================================
# DETAILED TEXT COMPARISON FOR: 20.jpeg
# ==================================================
#
# REFERENCE TEXT (Ground Truth):
# ------------------------------
# BIOCHIMIE SANGUINE (suite)
# Analyse                                      Résultat    Unité                    Valeurs de référence     Résultat antérieur    dat
#
# Pré-diabète :         5.7 à 6.4%
# Diabète:             > ou = 6.5%
# Surveillance du diabète :
#
# < ou = 7%    :   Très bon équilibre glycémique
# 7.1 à 8%     :   Bon équilibre glycémique
#
#
# 8.1%       :   Mauvais équilibre glycémique
#
#
#
#
#
# Résultat à interpréter en dehors des contextes suivants : hémoglobinopathie, anémie , transfusion, insuffisance rénale et grossesse; un
# dosage des fructosamines plasmatiques est alors conseillé.
# Urée                                         0,28       g/l                      ( 0,15 - 0,38 )          0,31                  13/05/22
# Enzymatique (Alinity ci)
# Soit                                     4,7        mmol/l                   ( 2,5 - 6,4 )            5,2                   13/05/22
# Osmolarité Calculée                          292        mOsmol/l                 ( 280 - 305 )
# Créatinine                                   10         mg/l                     ( 6 - 13 )               8                     13/05/22
# Jaffé cinétique (Alinity ci)
# Soit                                     88,50      μmol/l                   ( 53,00 - 115,00 )       70,80                 13/05/22
# DFG estimé par CKD-EPI                       68         ml/min/1,73m²                                     91                    13/05/22
# Classification de la maladie rénale chronique (MRC) en fonction du DFG (KDIGO 2011)
# >= 90 sans marqueur d' atteinte rénale         Pas d'atteinte rénale
# >= 90 avec marqueurs d' atteinte rénale*       G1  : MRC avec DFG normal ou augmenté
# 60 à 89 avec marqueurs d' atteinte rénale*     G2  : MRC avec DFG légèrement diminué
# 45 à 59                                        G3a : IRC légère à modérée
# 30 à 44                                        G3b : IRC modérée à sévère
# 15 à 29                                        G4  : IRC sévère
# < 15 ou dialyse                                G5  : IRC terminale
# (*) Albuminurie de faible débit, protéinurie clinique, hématurie, leucocyturie ou anomalies morphologiques ou histologiques persitantes
# plus de tois mois.
# Calcium Total                                97         mg/l                     ( 80 - 105 )             98                    13/05/22
# Colorimétrie (Alinity ci)
# Soit                                     2,43       mmol/l                   ( 2,00 - 2,63 )          2,45                  13/05/22
# Magnésium Sérique                            2,42       mg/dl                    ( 1,60 - 2,60 )          2,19                  13/05/22
# Colorimétrie (Alinity ci)
# Soit                                     0,99       mmol/l                   ( 0,66 - 1,07 )          0,90                  13/05/22
# ASAT (GOT)                                   24         UI/l                     ( < 35 )                 20                    13/05/22
# UV sans P5P(Alinity ci)
# ALAT (GPT)                                   42         UI/l                     ( < 40 )                 24                    13/05/22
# UV sans P5P(Alinity ci)
# Phosphatase alcaline                         63         U/l                      ( 40 - 150 )
# Colorimétrie
#
# EXTRACTED TEXT (OCR Result):
# ------------------------------
# BIOCHIMIE SANGUINE(suite Analyse Résultat Unite Valeurs de référence Résultat antérieur du: -Pré-diabéte: 5.76.4% -Diabéte >ou=6.5% Surveillance du diabéte: -<ou=7%Trés bon équilibre glycémique -7.18% Bon équilibre glycémique ->8.1% Mauvaiséquilibre glycémique Résultat á interpréter en dehors des contextes suivants : hémoglobinopathie. anémie. transfusion, insuffisance rénale et grossesse un dosage des fructosamines plasmatiques est alors conseillé Urée 0,28gl 0,15-0,38 0,31 13/05/22 Enzymatique (Alinity ci Soit 4,7mmol/l 2.5-6.4 5,2 13/05/22 Osmolarité Calculée 292 mOsmol/l 280-305 Créatinine 10mg/l 6-13 8 13/05/22 Jaffe cinétique (Alinity ci) Soit 88.50mol/l 53,00-115,00 70,80 13/05/22 DFG estimé par CKD-EPI 68ml/min/1,73m2 91 13/05/22 Classification de la maladie rénale chronique MRCen fonction du DFG (KDIGO 2011) >=90 sans marqueur d'atteinte rénale Pas d'atteinte rénale >=90avec margueursd'atteinte rénale* G1MRCavecDFG normalou augmenté 60a 89 avec marqueurs datteinte rénale* G2MRCavecDFGlégerement diminué 4559 G3a:IRC légére a modérée 3044 G3b:IRCmodéréeasévere 1529 G4IRCsévere <15ou dialyse G5IRC terminale plus de tois mois. Calcium Total 97 mg/l 80-105 98 13/05/22 Colonmetre Alinity ci Soit 2.43mmol/l 2.00-2.63 2,45 13/05/22 Magnésium Sérique 2,42mg/dl 1,60-2,60 2,19 13/05/22 Colonmetrie Alinity ci) Soit 0.99mmoll 0.66-1.07 0,90 13/05/22 ASAT(GOT) 24UI/1 <35 20 13/05/22 UV sans P5P(Alinity ci) ALAT(GPT) 42UI/1 40 24 13/05/22 UV sans P5PAlinityc Phosphatase alcaline 63U/l 40-150
#
# WORD COUNT COMPARISON:
# Reference text word count: 327
# Extracted text word count: 193
#
# METRICS FOR: 20.jpeg
# Reference words: 327
# Extracted words: 193
# Correct words: 90
# Precision: 0.47
# Recall: 0.28
# F1 Score: 0.35
# Execution Time: 5.50 seconds
#
# Processing 18.jpeg...
# [2024/10/31 06:49:02] ppocr DEBUG: dt_boxes num : 67, elapsed : 0.4517781734466553
# [2024/10/31 06:49:03] ppocr DEBUG: cls num  : 67, elapsed : 0.33358049392700195
# [2024/10/31 06:49:08] ppocr DEBUG: rec_res num  : 67, elapsed : 4.968947649002075
#
# ==================================================
# DETAILED TEXT COMPARISON FOR: 18.jpeg
# ==================================================
#
# REFERENCE TEXT (Ground Truth):
# ------------------------------
# BIOCHIMIE SANGUINE (suite)
# Analyse                                      Résultat    Unité                    Valeurs de référence     Résultat antérieur    dat
# Classification de la maladie rénale chronique (MRC) en fonction du DFG (KDIGO 2011)
# >= 90 sans marqueur d' atteinte rénale         Pas d'atteinte rénale
# >= 90 avec marqueurs d' atteinte rénale*       G1  : MRC avec DFG normal ou augmenté
# 60 à 89 avec marqueurs d' atteinte rénale*     G2  : MRC avec DFG légèrement diminué
# 45 à 59                                        G3a : IRC légère à modérée
# 30 à 44                                        G3b : IRC modérée à sévère
# 15 à 29                                        G4  : IRC sévère
# < 15 ou dialyse                                G5  : IRC terminale
# (*) Albuminurie de faible débit, protéinurie clinique, hématurie, leucocyturie ou anomalies morphologiques ou histologiques persitantes
# plus de tois mois.
# Calcium Total                                101        mg/l                     ( 80 - 105 )             100                   18/09/24
# Colorimétrie (Alinity ci)
# Soit                                     2,53       mmol/l                   ( 2,00 - 2,63 )          2,50                  18/09/24
# ASAT (GOT)                                   46         UI/l                     ( < 35 )
# UV sans P5P(Alinity ci)
# ALAT (GPT)                                   37         UI/l                     ( < 40 )
# UV sans P5P(Alinity ci)
# Phosphatase alcaline                         93         U/l                      ( 40 - 150 )
# Colorimétrie (Alinity ci)
# GGT                                          27         U/l                      ( < 50 )
# Colorimétrie (Alinity ci)
# Bilirubine Totale                           6          mg/l                     ( 3 - 10 )
# Jendrassik (Alinity ci)
# Soit                                     10,2       μmol/l                   ( 5,1 - 17,1 )
#
# EXTRACTED TEXT (OCR Result):
# ------------------------------
# BlOCHIMIE SANGUINE (suite) Analvse Resultat Unite Valeu de référence Resultat anterieur du: go sans marqueur datteinte rénale go avec marqueurs d' atteinte rénale* Pas d'atteinte rénale 60 89 G1MRC avec DFG normal ou augmenté avec marqueurs datteinte renale 45 59 G2 44 30 G3a:IRClégere a moderée 15a29 G3b:IRC modérée a severe G4 15 IRCsévere ou dialyse (Albuminurie de faible débit, protéinurie clinique, hématurie, leucocyturie ou anomalies morphologiques ou histologiques persitantes G5 :IRC terminale plus de tois mois Calcium Total 101mg/l Colorimetrie (Alinity ci) 80-105 100 18/09/24 Soit 2.53mmol/l 2,00-2,63 2,50 18/09/24 ASAT(GOT) 46UI/l UV sans P5P(Alinity cl) <35 ALAT(GPT) 37UI/1 <40 UV sans P5P(Alinity ci) Phosphatase alcaline 93U/l Colorimetrie (Alinity ci) 40-150 GGT 27U/1 <50 Colorimétrie (Alinity ci) Bilirubine Totale 6mg/l 3-10 Jendrassik Alinity ci Soit 10.2 pmol/l
#
# WORD COUNT COMPARISON:
# Reference text word count: 207
# Extracted text word count: 128
#
# METRICS FOR: 18.jpeg
# Reference words: 207
# Extracted words: 128
# Correct words: 60
# Precision: 0.47
# Recall: 0.29
# F1 Score: 0.36
# Execution Time: 5.88 seconds
#
# Processing 19.jpeg...
# [2024/10/31 06:49:08] ppocr DEBUG: dt_boxes num : 69, elapsed : 0.548349142074585
# [2024/10/31 06:49:09] ppocr DEBUG: cls num  : 69, elapsed : 0.35962700843811035
# [2024/10/31 06:49:12] ppocr DEBUG: rec_res num  : 69, elapsed : 3.0526974201202393
#
# ==================================================
# DETAILED TEXT COMPARISON FOR: 19.jpeg
# ==================================================
#
# REFERENCE TEXT (Ground Truth):
# ------------------------------
# BIOCHIMIE SANGUINE
# Analyse                                      Résultat    Unité                    Valeurs de référence     Résultat antérieur    dat
# Glucose                                      1,16       g/l                      ( 0,70 - 1,05 )          1,08                  02/05/24
# Enzymatique (Alinity ci)
# Soit                                     6,45       mmol/l                   ( 3,89 - 5,84 )          6,00                  02/05/24
# -Une Glycémie à jeûn > ou = 1.26 g/l (Soit 7 mmol/l) à 2 reprises est en faveur d'un diabète sucré (OMS)
# HbA1c (NGSP)                                5,7        %                        ( < 5,6 )                 6,7                   02/05/24
# HPLC (Arkray)
# HbA1c (IFCC)                            38,0       mmol/mol                 ( < 38,0 )                50,0                  02/05/24
#
# Pré-diabète :         5.7 à 6.4%
# Diabète:             > ou = 6.5%
# Surveillance du diabète :
#
# < ou = 7%    :   Très bon équilibre glycémique
# 7.1 à 8%     :   Bon équilibre glycémique
#
#
# 8.1%       :   Mauvais équilibre glycémique
#
#
#
#
#
# Résultat à interpréter en dehors des contextes suivants : hémoglobinopathie, anémie , transfusion, insuffisance rénale et grossesse; un
# dosage des fructosamines plasmatiques est alors conseillé.
# Urée                                         0,44       g/l                      ( 0,15 - 0,38 )          0,51                  02/05/24
# Enzymatique (Alinity ci)
# Soit                                     7,3        mmol/l                   ( 2,5 - 6,4 )            8,5                   02/05/24
# Créatinine                                   11         mg/l                     ( 6 - 13 )               12                    02/05/24
# Jaffé cinétique (Alinity ci)
# Soit                                     97,35      μmol/l                   ( 53,00 - 115,00 )       106,20                02/05/24
# DFG estimé par CKD-EPI                       67         ml/min/1,73m²                                     61                    02/05/24
#
# EXTRACTED TEXT (OCR Result):
# ------------------------------
# BIOCHIMIE SANGUINE Analyse Resultat Unite Valeurs de référence Résultatantérieur du: Glucose 1,16g/l 0,70-1,05 Enzymatique (Alinity ci) 1,08 02/05/24 Soit 6,45mmol/l 3,89-5,84 6,00 02/05/24 -Une Glycémie a jeün>ou =1.26 g/l (Soit 7 mmo/I)a 2 reprises est en faveur d'un diabete sucré (OMS HbA1cNGSP) 5,7% <5,6 6,7 HPLC(Arkray) 02/05/24 HbA1cIFCC) 38,0mmol/mol 38.0 50,0 02/05/24 -Pré-diabéte: 5.76.4% -Diabéte: >ou=6.5% -Surveillance du diabéte: -<ou=7% Trés bon équilibre glycémique -7.18% Bon équilibre glycémique >8.1% Mauvais équilibre glycémique Resultat a interpreter en dehors des contextes suivants:hémoglobinopathie,anémie,transfusion.insuffisance rénale et grossesseun dosage des fructosamines plasmatiques est alors conseillé. Urée 0,44g/1 0,15-0,38 0.51 02/05/24 Enzymatique (Alinity ci) Soit 7,3mmol/l 2.5-6.4 8.5 02/05/24 Créatinine 11mg/l 6-13 12 02/05/24 (uanbrgur uer Soit 97.35mol/l 53,00-115,00 106.20 02/05/24 DFG estime par CKD-EPI 67ml/min/1,73m2 61 02/05/24
#
# WORD COUNT COMPARISON:
# Reference text word count: 193
# Extracted text word count: 122
#
# METRICS FOR: 19.jpeg
# Reference words: 193
# Extracted words: 122
# Correct words: 50
# Precision: 0.41
# Recall: 0.26
# F1 Score: 0.32
# Execution Time: 4.07 seconds
#
# Processing 9.jpeg...
# [2024/10/31 06:49:12] ppocr DEBUG: dt_boxes num : 74, elapsed : 0.47890758514404297
# [2024/10/31 06:49:12] ppocr DEBUG: cls num  : 74, elapsed : 0.27842092514038086
# [2024/10/31 06:49:16] ppocr DEBUG: rec_res num  : 74, elapsed : 3.076896905899048
#
# ==================================================
# DETAILED TEXT COMPARISON FOR: 9.jpeg
# ==================================================
#
# REFERENCE TEXT (Ground Truth):
# ------------------------------
# BIOCHIMIE SANGUINE (suite)
# Analyse                                      Résultat    Unité                    Valeurs de référence     Résultat antérieur    dat
# Classification de la maladie rénale chronique (MRC) en fonction du DFG (KDIGO 2011)
# >= 90 sans marqueur d' atteinte rénale         Pas d'atteinte rénale
# >= 90 avec marqueurs d' atteinte rénale*       G1  : MRC avec DFG normal ou augmenté
# 60 à 89 avec marqueurs d' atteinte rénale*     G2  : MRC avec DFG légèrement diminué
# 45 à 59                                        G3a : IRC légère à modérée
# 30 à 44                                        G3b : IRC modérée à sévère
# 15 à 29                                        G4  : IRC sévère
# < 15 ou dialyse                                G5  : IRC terminale
# ...
# Cholestérol HDL                              0,36       g/l                      ( 0,40 - 0,60 )          0,41                  13/05/22
# Enzymatique (Alinity ci)
# Soit                                     0,93       mmol/l                   ( 1,03 - 1,54 )          1,06                  13/05/22
# Cholestérol LDL                              0,96       g/l                      ( < 1,55 )
# (Calcul)
# Soit                                     2,48       mmol/l                   ( < 4,00 )
# Cholestérol                                  1,64       g/l                      ( 1,50 - 2,00 )          1,44                  13/05/22
# Enzymatique (Alinity ci)
# Soit                                     4,23       mmol/l                   ( 3,87 - 5,16 )          3,72                  13/05/22
# Cholesterol non HDL                          1,28       g/l
# (Calcul)
# Soit                                     3,30       mmol/l
# Les objectifs pour un patient dans le cadre d'une prise en charge initiale (ESC 2021) :
# -Haut risque cardiovasculaire          : LDL-c < 1,00 g/L (2,6 mmol/L) et non-HDLc < 1,30 g/L (3,4 mmol/L).
# -Très Haut risque cardiovasculaire     : LDL-c < 0,70 g/L (1,8 mmol/L) et non-HDLc < 1,00 g/L (2,6 mmol/L).
# Les objectifs pour un patient dans le cadre d'une intensification thérapeutique (ESC 2021) :
# -Haut risque cardiovasculaire          : LDL-c < 0,70 g/L (1,8 mmol/L) associé à baisse de 50% et non-HDLc < 1,00 g/L (2,6 mmol/L).
# -Très Haut risque cardiovasculaire     : LDL-c < 0,55 g/L (1,4 mmol/L) associé à baisse de 50% et non-HDLc < 0,85 g/L (2,2 mmol/L).
# HORMONOLOGIE
# Analyse                                      Résultat    Unité                    Valeurs de référence     Résultat antérieur    dat
# TSH Ultrasensible                            1,59       μU/ml                    ( 0,40 - 4,00 )          0,76                  13/05/22
# Chimiluminescence (Alinity ci)
# T4 Libre                                     0,99       ng/dl                    ( 0,70 - 1,48 )
# Chimiluminescence (Alinity ci)
# Soit                                     13         pmol/l                   ( 9 - 19 )
# T3 Libre                                     3,79       pg/ml                    ( 1,71 - 3,71 )
# Chimiluminescence (Alinity ci)
# Soit                                     5,84       pmol/l                   ( 2,63 - 5,71 )
# MARQUEURS TUMORAUX
# Analyse                                      Résultat    Unité                    Valeurs de référence     Résultat antérieur    dat
# PSA Total                                    0,70       ng/ml
# Chimiluminescence (Alinity ci)
#
# EXTRACTED TEXT (OCR Result):
# ------------------------------
# BILAN LIPIDIQUE(suite Analyse Résultat Unité Valeurs de référence Résultat antérieur du: Aspect LIMPIDE 1,61g/l 0,60-1,50 0.83 13/05/22 Triglycérides Enzymatique(Alinity ci) 0,68-1.71 0,95 13/05/22 1,84mmol/l Soit 0,40-0,60 0,41 13/05/22 0,36g/l Cholestérol HDL Enzymatique(Alinity ci) 1,03-1,54 1,06 13/05/22 0,93mmol/l Soit 1,55 0,96g/l Cholestérol LDL (Calcul) <4.00 2,48mmol/l Soit 1,50-2,00 1,44 13/05/22 1,64g/l Cholestérol 3.87-5.16 3,72 13/05/22 Enzymatique (Alinity ci) 4.23mmol/l Ct Soit Poti 1,28g/l Cholesterol non HDL Ri (Calcul) 3,30mmol/l Enz Soit Les objectifs pour un patient dans le cadre d'une prise en charge initiale(ESC 2021): LDL-c<1,00g/L2,6mmoVLet non-HDLc<1.30g/L3.4mmoVL Tr -Hautrisque cardiovasculaire (02 LDL-c<0.70 g/L1.8mmoVLassociéa baisse de 50%et non-HDLc<1.00g/L2.6mmo/L PI -Haut risque cardiovasculaire Biu C Co HORMONOLOGIE Valeurs.de référence Résultat anterieur du: Résultat Unite Analyse 0,40-4,00 0.76 13/05/22 Vi 1,59U/ml TSH Ultrasensible Chimiluminescence (Alinity ci Ip/6u 66'0 0,70-1,48 T4Libre Chimiluminescence (Alinity ci 13pmol/l 9.19 Soit 1.71-3.71 3,79pg/ml T3Libre Chimitumina cence(Alinity ci 2.63-5.71 5,84pmoll Soit MARQUEURS TUMORAUX Valeurs.de reférence Résultat.anterieur du: P Resultat Unite C Analyse PSA Total 0.70ng/ml P
#
# WORD COUNT COMPARISON:
# Reference text word count: 301
# Extracted text word count: 156
#
# METRICS FOR: 14.jpeg
# Reference words: 301
# Extracted words: 156
# Correct words: 52
# Precision: 0.33
# Recall: 0.17
# F1 Score: 0.23
# Execution Time: 4.93 seconds
#
# Processing 15.jpeg...
# [2024/10/31 06:49:40] ppocr DEBUG: dt_boxes num : 50, elapsed : 0.3183870315551758
# [2024/10/31 06:49:40] ppocr DEBUG: cls num  : 50, elapsed : 0.18281292915344238
# [2024/10/31 06:49:43] ppocr DEBUG: rec_res num  : 50, elapsed : 3.256956100463867
#
# ==================================================
# DETAILED TEXT COMPARISON FOR: 15.jpeg
# ==================================================
#
# REFERENCE TEXT (Ground Truth):
# ------------------------------
# BIOCHIMIE SANGUINE
# Analyse                                      Résultat    Unité                    Valeurs de référence     Résultat antérieur    dat
# Glucose                                      1,04       g/l                      ( 0,70 - 1,05 )
# Enzymatique (Alinity ci)
# Soit                                     5,78       mmol/l                   ( 3,89 - 5,84 )
# -Une Glycémie à jeûn > ou = 1.26 g/l (Soit 7 mmol/l) à 2 reprises est en faveur d'un diabète sucré (OMS)
# -Une Glycémie à jeûn chez la femme enceinte > ou = 0.92 g/l (Soit 5.06 mmol/l) est en faveur d'un diabète gestationnel
# HbA1c (NGSP)                                5,7        %                        ( < 5,6 )
# HPLC (Arkray)
# HbA1c (IFCC)                            39,0       mmol/mol                 ( < 38,0 )
#
# Pré-diabète :         5.7 à 6.4%
# Diabète:             > ou = 6.5%
# Surveillance du diabète :
#
# < ou = 7%    :   Très bon équilibre glycémique
# 7.1 à 8%     :   Bon équilibre glycémique
#
#
# 8.1%       :   Mauvais équilibre glycémique
#
#
#
#
#
# Résultat à interpréter en dehors des contextes suivants : hémoglobinopathie, anémie , transfusion, insuffisance rénale et grossesse; un
# dosage des fructosamines plasmatiques est alors conseillé.
# Urée                                         0,20       g/l                      ( 0,15 - 0,38 )
# Enzymatique (Alinity ci)
# Soit                                     3,3        mmol/l                   ( 2,5 - 6,4 )
# Créatinine                                   8          mg/l                     ( 6 - 13 )
# Jaffé cinétique (Alinity ci)
# Soit                                     70,80      μmol/l                   ( 53,00 - 115,00 )
# DFG estimé par CKD-EPI                       86         ml/min/1,73m²
#
# EXTRACTED TEXT (OCR Result):
# ------------------------------
# BIOCHIMIESANGUINE Analyse Resultat Unite Valeurs.de.reférence Resultatanterieur du: Glucose 1.04g/l 0,70-1,05 Enzymatique Alinity ci Soit 5.78mmol/l 3.89-5.84 -Une Glycemie a jeün chez la femme enceinte>ou = 0.92 g/l(Soit 5.06 mmol/l est en faveur d'un diabete gestationnel HbA1cNGSP) 5,7% <5.6 HPLC(Arkray) HbA1cIFCC) 39,0mmol/mol <38.0 -Pre-diabete: 5.76.4% -Diabéte: >ou=6.5% Surveillance du diabete: .Trés bon équilibre glycémique 7.18% Bonéquilibre glycémique ->8.1% Mauvais équilibre glycémique Résultat a interpreter en dehors des contextes suivants:hemoglobinopathie,anemie.transfusion.insuffisance renale et grossesseun dosage des fructosamines plasmatiques est alors conseille. Urée 0,20g/l 0,15-0,38 Soit 3.3mmol/l 25-6.4 Créatinine 8mg/l Jafte cinetique Alinity ci 6-13 Soit 70.80mol 53.00-115.00 DFG estimé par CKD-EPI 86ml/min/1.73m²
#
# WORD COUNT COMPARISON:
# Reference text word count: 197
# Extracted text word count: 99
#
# METRICS FOR: 15.jpeg
# Reference words: 197
# Extracted words: 99
# Correct words: 38
# Precision: 0.38
# Recall: 0.19
# F1 Score: 0.26
# Execution Time: 3.85 seconds
#
# Processing 5.jpeg...
# [2024/10/31 06:49:44] ppocr DEBUG: dt_boxes num : 19, elapsed : 0.27075982093811035
# [2024/10/31 06:49:44] ppocr DEBUG: cls num  : 19, elapsed : 0.12762951850891113
# [2024/10/31 06:49:45] ppocr DEBUG: rec_res num  : 19, elapsed : 1.252927541732788
#
# ==================================================
# DETAILED TEXT COMPARISON FOR: 5.jpeg
# ==================================================
#
# REFERENCE TEXT (Ground Truth):
# ------------------------------
# BIOCHIMIE SANGUINE
# Analyse                                      Résultat    Unité                    Valeurs de référence     Résultat antérieur    dat
# ASAT (GOT)                                   23         UI/l                     ( < 35 )                 21                    19/01/24
# UV sans P5P(Alinity ci)
# ALAT (GPT)                                   13         UI/l                     ( < 40 )                 10                    19/01/24
# UV sans P5P(Alinity ci)
#
# EXTRACTED TEXT (OCR Result):
# ------------------------------
# BIOCHIMIE SANGUINE Analyse Resultat Unite Valeurs de reférence Resultat.anterieur du: ASAT(GOT) 23UI/1 <35 21 UV sans P5P(Alinity cl) 19/01/24 ALAT(GPT) 13UI/l <40 10 UVsansP5P(Alinity ci 19/01/24
#
# WORD COUNT COMPARISON:
# Reference text word count: 39
# Extracted text word count: 26
#
# METRICS FOR: 5.jpeg
# Reference words: 39
# Extracted words: 26
# Correct words: 11
# Precision: 0.42
# Recall: 0.28
# F1 Score: 0.34
# Execution Time: 1.70 seconds
#
# Processing 4.jpeg...
# [2024/10/31 06:49:46] ppocr DEBUG: dt_boxes num : 113, elapsed : 0.7792532444000244
# [2024/10/31 06:49:47] ppocr DEBUG: cls num  : 113, elapsed : 0.5668456554412842
# [2024/10/31 06:49:52] ppocr DEBUG: rec_res num  : 113, elapsed : 5.2225022315979
#
# ==================================================
# DETAILED TEXT COMPARISON FOR: 4.jpeg
# ==================================================
#
# REFERENCE TEXT (Ground Truth):
# ------------------------------
# BIOCHIMIE SANGUINE (suite)
# Analyse                                      Résultat    Unité                    Valeurs de référence     Résultat antérieur    dat
# Classification de la maladie rénale chronique (MRC) en fonction du DFG (KDIGO 2011)
# >= 90 sans marqueur d' atteinte rénale         Pas d'atteinte rénale
# >= 90 avec marqueurs d' atteinte rénale*       G1  : MRC avec DFG normal ou augmenté
# 60 à 89 avec marqueurs d' atteinte rénale*     G2  : MRC avec DFG légèrement diminué
# 45 à 59                                        G3a : IRC légère à modérée
# 30 à 44                                        G3b : IRC modérée à sévère
# 15 à 29                                        G4  : IRC sévère
# < 15 ou dialyse                                G5  : IRC terminale
# (*) Albuminurie de faible débit, protéinurie clinique, hématurie, leucocyturie ou anomalies morphologiques ou histologiques persitantes
# plus de tois mois.
# ASAT (GOT)                                   15         UI/l                     ( < 35 )                 16                    15/04/24
# UV sans P5P(Alinity ci)
# ALAT (GPT)                                   14         UI/l                     ( < 40 )                 14                    15/04/24
# UV sans P5P(Alinity ci)
# Créatine kinase                              117        UI/l                     ( 24 - 195 )             84                    15/04/24
# Enzymatique (Alinity ci)
# BILAN LIPIDIQUE
# Analyse                                      Résultat    Unité                    Valeurs de référence     Résultat antérieur    dat
# Aspect                                                   LIMPIDE
# Triglycérides                                0,63       g/l                      ( 0,60 - 1,50 )          1,26                  15/04/24
# Enzymatique (Alinity ci)
# Soit                                     0,72       mmol/l                   ( 0,68 - 1,71 )          1,44                  15/04/24
# Cholestérol HDL                              0,37       g/l                      ( 0,40 - 0,60 )          0,44                  15/04/24
# Enzymatique (Alinity ci)
# Soit                                     0,95       mmol/l                   ( 1,03 - 1,54 )          1,14                  15/04/24
# Cholestérol LDL                              1,03       g/l                      ( < 1,55 )               1,15                  15/04/24
# (Calcul)
# Soit                                     2,66       mmol/l                   ( < 4,00 )               2,97                  15/04/24
# Cholestérol                                  1,53       g/l                      ( 1,50 - 2,00 )          1,84                  15/04/24
# Enzymatique (Alinity ci)
# Soit                                     3,95       mmol/l                   ( 3,87 - 5,16 )          4,75                  15/04/24
# Cholesterol non HDL                          1,16       g/l                                              1,40                  15/04/24
# (Calcul)
# Soit                                     2,99       mmol/l                                           3,61                  15/04/24
# Les objectifs pour un patient dans le cadre d'une prise en charge initiale (ESC 2021) :
# -Haut risque cardiovasculaire          : LDL-c < 1,00 g/L (2,6 mmol/L) et non-HDLc < 1,30 g/L (3,4 mmol/L).
# -Très Haut risque cardiovasculaire     : LDL-c < 0,70 g/L (1,8 mmol/L) et non-HDLc < 1,00 g/L (2,6 mmol/L).
# Les objectifs pour un patient dans le cadre d'une intensification thérapeutique (ESC 2021) :
# -Haut risque cardiovasculaire          : LDL-c < 0,70 g/L (1,8 mmol/L) associé à baisse de 50% et non-HDLc < 1,00 g/L (2,6 mmol/L).
# -Très Haut risque cardiovasculaire     : LDL-c < 0,55 g/L (1,4 mmol/L) associé à baisse de 50% et non-HDLc < 0,85 g/L (2,2 mmol/L).
#
# EXTRACTED TEXT (OCR Result):
# ------------------------------
# BIOCHIMIE SANGUINE(suite Analyse Résultat Classification de la maladie rénale chronique MRCen fonction du DFG(KDIGO 2011) Unité Valeurs de référence Résultat antérieur du: >=90 sans marqueur d'atteinte rénale >=90 avec marqueursd'atteinte rénale* Pas d'atteinte rénale 60a 89 avec marqueursd'atteinte rénale* G1MRCavec DFG normal ou augmenté G2MRCavec DFGlégérement diminué 4559 3044 G3aIRC légéreamodérée G3bIRCmodéréea sévére 1529 G4IRCsévere <15ou dialyse () Albuminurie de faible débit. protéinurie clinique, hématurie, leucocyturie ou anomalies morphologiques ou histologiques persitantes G5IRC terminale plus de tois mois ASAT(GOT) 15UI/I <35) UV sans P5P(Alinity ci) 16 15/04/24 ALAT(GPT) 14UI/1 (<40) 14 15/04/24 UV sans P5P(Alinity ci) Créatine kinase 117UI/l 24-195 84 15/04/24 Enzymatique (Alinity ci) BILAN LIPIDIQUE Analyse Résultat Unité Valeurs de référence Résultat antérieur du: Aspect LIMPIDE Triglycérides 0,63g/l 0,60-1,50 1,26 15/04/24 Enzymatique(Alinity ci) Soit 0,72mmol/l 0.68-1,71 1,44 15/04/24 Cholestérol HDL 0,37g/l 0,40-0,60 0,44 15/04/24 EnzymatiqueAlinity ci Soit 0,95mmol/l 1.03-1.54 1.14 15/04/24 Cholestérol LDL 1,03g/l <1,55 1,15 15/04/24 (Calcul) Soit 2,66mmol/ <4.00 2,97 15/04/24 Cholestérol 1,53g/l 1,50-2,00 1.84 15/04/24 EnzymatiqueAlinity a Soit 3.95mmol/l 3,87-5,16 4.75 15/04/24 Cholesterol non HDL 1,16g/l 1.40 15/04/24 (Calcul) Soit 2.99mmol/l 3.61 15/04/24 Les objectifs pour un patient dans le cadre dune prise en charge initialeESC 2021: -Haut risque cardiovasculaire.. LDL-c<1.00g/L2.6mmoVLet non-HDLc<1.30g/L3.4mmoVL -Trés Haut risque cardiovasculaire:LDL-c<0.70 g/L1.8mmoVL)et non-HDLc<1.00g/L2.6mmoVL Les objectifs pour un patient dans le cadre dune intensification thérapeutique (ESC 2021): -Haut risgue cardiovasculaire LDL-c0.70g/L1.8mmoVLassocieabaisse de50%et non-HDLc<1.00g/L2.6mmoVL -Tres Haut risque cardiovasculaire.LDL-c<0.55 g/L1.4mmoVLassocie a baisse de 50%et non-HDLc<0.85g/L2,2mmoVL. ge 1sur1
#
# WORD COUNT COMPARISON:
# Reference text word count: 385
# Extracted text word count: 234
#
# METRICS FOR: 4.jpeg
# Reference words: 385
# Extracted words: 234
# Correct words: 89
# Precision: 0.38
# Recall: 0.23
# F1 Score: 0.29
# Execution Time: 6.69 seconds
#
# ==================================================
# FINAL SUMMARY STATISTICS:
# ==================================================
# Number of files processed: 20
#
# Total Word Counts:
# Total Reference Words: 4555
# Total Extracted Words: 2622
# Total Correct Words: 1117
#
# Average Metrics:
# Average Precision: 0.43
# Average Recall: 0.25
# Average F1 Score: 0.32
# Average Execution Time: 4.41 seconds per file
#
# Best performing file:
# Filename: 17.jpeg
# F1 Score: 0.49
# Reference words: 149
# Extracted words: 103
# Correct words: 62
#
# Worst performing file:
# Filename: 1.jpeg
# F1 Score: 0.20
# Reference words: 222
# Extracted words: 120
# Correct words: 35

# %% [markdown]
# **Prétraitement**

# %%
import os
import time
import cv2
import numpy as np
from paddleocr import PaddleOCR

def preprocess_image(image):
    if len(image.shape) == 3:
        gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    else:
        gray = image.copy()

    # Réduction de bruit plus légère
    denoised = cv2.fastNlMeansDenoising(gray, h=10)

    # CLAHE avec paramètres doux
    clahe = cv2.createCLAHE(clipLimit=1.5, tileGridSize=(4,4))
    enhanced = clahe.apply(denoised)

    # Seuillage global
    _, binary = cv2.threshold(enhanced, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)

    # Redimensionnement conservateur
    min_height = 1200
    if image.shape[0] < min_height:
        ratio = min_height / image.shape[0]
        new_width = int(image.shape[1] * ratio)
        resized = cv2.resize(binary, (new_width, min_height),
                           interpolation=cv2.INTER_LINEAR)
    else:
        resized = binary

    # Amélioration des bords
    kernel = np.ones((2,2),np.uint8)
    final = cv2.morphologyEx(resized, cv2.MORPH_CLOSE, kernel)

    return final

print("Initializing PaddleOCR...")
ocr = PaddleOCR(
    use_angle_cls=True,
    lang='french',
    det_db_thresh=0.25,
    det_db_box_thresh=0.5,
    det_limit_side_len=1200,
    rec_batch_num=1,
    use_gpu=False,
    enable_mkldnn=True,
    cls_thresh=0.8,
    rec_image_shape='3, 48, 320'
)
print("PaddleOCR initialized.")

def extract_text_from_image(image_path):
    try:
        # Lire et prétraiter l'image
        image = cv2.imread(image_path)
        preprocessed = preprocess_image(image)

        # Sauvegarder temporairement l'image prétraitée
        temp_path = "temp_preprocessed.png"
        cv2.imwrite(temp_path, preprocessed)

        # OCR sur l'image prétraitée
        result = ocr.ocr(temp_path, cls=True)

        # Supprimer le fichier temporaire
        if os.path.exists(temp_path):
            os.remove(temp_path)

        if result is None or len(result) == 0:
            return ""

        extracted_text = []
        for line in result:
            line_text = ' '.join([word_info[1][0] for word_info in line])
            extracted_text.append(line_text)
        return ' '.join(extracted_text)
    except Exception as e:
        print(f"Error in OCR processing: {str(e)}")
        return ""

def read_text_file(file_path):
    try:
        with open(file_path, 'r', encoding='utf-8') as file:
            return file.read()
    except UnicodeDecodeError:
        try:
            with open(file_path, 'r', encoding='latin-1') as file:
                return file.read()
        except Exception as e:
            print(f"Error reading file: {str(e)}")
            return ""

def calculate_metrics(extracted_text, reference_text):
    extracted_words = extracted_text.lower().split()
    reference_words = reference_text.lower().split()
    extracted_words_set = set(extracted_words)
    reference_words_set = set(reference_words)

    correct_words = len(extracted_words_set.intersection(reference_words_set))

    precision = correct_words / len(extracted_words) if extracted_words else 0.0
    recall = correct_words / len(reference_words) if reference_words else 0.0
    f1_score = calculate_f1(precision, recall)

    return {
        'precision': precision,
        'recall': recall,
        'f1_score': f1_score,
        'reference_count': len(reference_words),
        'extracted_count': len(extracted_words),
        'correct_count': correct_words
    }

def calculate_f1(precision, recall):
    if precision + recall == 0:
        return 0.0
    return 2 * (precision * recall) / (precision + recall)

def print_text_comparison(filename, reference_text, extracted_text):
    print("\n" + "="*50)
    print(f"DETAILED TEXT COMPARISON FOR: {filename}")
    print("="*50)

    print("\nREFERENCE TEXT (Ground Truth):")
    print("-"*30)
    print(reference_text)

    print("\nEXTRACTED TEXT (OCR Result):")
    print("-"*30)
    print(extracted_text)

    print("\nWORD COUNT COMPARISON:")
    print(f"Reference text word count: {len(reference_text.split())}")
    print(f"Extracted text word count: {len(extracted_text.split())}")

# Directories containing the images and text files
image_dir = r'/content/images_analyse'
text_dir = r'/content/ground_truth'

# Variables to track metrics
total_precision = 0.0
total_recall = 0.0
total_f1 = 0.0
num_files = 0
total_execution_time = 0.0

# List of supported image extensions
image_extensions = ('.jpg', '.jpeg', '.png')

# Store results for each file
results = []

# Store total word counts
total_reference_words = 0
total_extracted_words = 0
total_correct_words = 0

print("\nStarting OCR evaluation...")
print("="*50)

# Iterate over all files in the image directory
for image_filename in os.listdir(image_dir):
    if image_filename.lower().endswith(image_extensions):
        base_filename = os.path.splitext(image_filename)[0]
        image_path = os.path.join(image_dir, image_filename)
        text_file_path = os.path.join(text_dir, f"{base_filename}.txt")

        if os.path.exists(text_file_path):
            try:
                print(f"\nProcessing {image_filename}...")
                start_time = time.time()

                extracted_text = extract_text_from_image(image_path)
                reference_text = read_text_file(text_file_path)

                # Print full text comparison
                print_text_comparison(image_filename, reference_text, extracted_text)

                # Calculate metrics
                metrics = calculate_metrics(extracted_text, reference_text)

                # Update totals
                total_precision += metrics['precision']
                total_recall += metrics['recall']
                total_f1 += metrics['f1_score']
                total_reference_words += metrics['reference_count']
                total_extracted_words += metrics['extracted_count']
                total_correct_words += metrics['correct_count']
                num_files += 1

                execution_time = time.time() - start_time

                # Store results
                results.append({
                    'filename': image_filename,
                    'metrics': metrics,
                    'execution_time': execution_time
                })

                # Print individual file metrics
                print(f"\nMETRICS FOR: {image_filename}")
                print(f"Reference words: {metrics['reference_count']}")
                print(f"Extracted words: {metrics['extracted_count']}")
                print(f"Correct words: {metrics['correct_count']}")
                print(f"Precision: {metrics['precision']:.2f}")
                print(f"Recall: {metrics['recall']:.2f}")
                print(f"F1 Score: {metrics['f1_score']:.2f}")
                print(f"Execution Time: {execution_time:.2f} seconds")

            except Exception as e:
                print(f"Error processing {image_filename}: {str(e)}")
        else:
            print(f"Text file not found for image: {image_filename}")

# Calculate and output the averages
if num_files > 0:
    average_precision = total_precision / num_files
    average_recall = total_recall / num_files
    average_f1 = total_f1 / num_files
    average_execution_time = sum(r['execution_time'] for r in results) / num_files

    print("\n" + "="*50)
    print("FINAL SUMMARY STATISTICS:")
    print("="*50)
    print(f"Number of files processed: {num_files}")

    print("\nTotal Word Counts:")
    print(f"Total Reference Words: {total_reference_words}")
    print(f"Total Extracted Words: {total_extracted_words}")
    print(f"Total Correct Words: {total_correct_words}")

    print(f"\nAverage Metrics:")
    print(f"Average Precision: {average_precision:.2f}")
    print(f"Average Recall: {average_recall:.2f}")
    print(f"Average F1 Score: {average_f1:.2f}")
    print(f"Average Execution Time: {average_execution_time:.2f} seconds per file")

    # Find best and worst performing files
    best_f1 = max(results, key=lambda x: x['metrics']['f1_score'])
    worst_f1 = min(results, key=lambda x: x['metrics']['f1_score'])

    print("\nBest performing file:")
    print(f"Filename: {best_f1['filename']}")
    print(f"F1 Score: {best_f1['metrics']['f1_score']:.2f}")
    print(f"Reference words: {best_f1['metrics']['reference_count']}")
    print(f"Extracted words: {best_f1['metrics']['extracted_count']}")
    print(f"Correct words: {best_f1['metrics']['correct_count']}")

    print("\nWorst performing file:")
    print(f"Filename: {worst_f1['filename']}")
    print(f"F1 Score: {worst_f1['metrics']['f1_score']:.2f}")
    print(f"Reference words: {worst_f1['metrics']['reference_count']}")
    print(f"Extracted words: {worst_f1['metrics']['extracted_count']}")
    print(f"Correct words: {worst_f1['metrics']['correct_count']}")
else:
    print("No matching text files found for any images.")
# Out:
# Initializing PaddleOCR...
# [2024/10/31 06:23:12] ppocr DEBUG: Namespace(help='==SUPPRESS==', use_gpu=False, use_xpu=False, use_npu=False, use_mlu=False, ir_optim=True, use_tensorrt=False, min_subgraph_size=15, precision='fp32', gpu_mem=500, gpu_id=0, image_dir=None, page_num=0, det_algorithm='DB', det_model_dir='/root/.paddleocr/whl/det/en/en_PP-OCRv3_det_infer', det_limit_side_len=1200, det_limit_type='max', det_box_type='quad', det_db_thresh=0.25, det_db_box_thresh=0.5, det_db_unclip_ratio=1.5, max_batch_size=10, use_dilation=False, det_db_score_mode='fast', det_east_score_thresh=0.8, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_sast_score_thresh=0.5, det_sast_nms_thresh=0.2, det_pse_thresh=0, det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, scales=[8, 16, 32], alpha=1.0, beta=1.0, fourier_degree=5, rec_algorithm='SVTR_LCNet', rec_model_dir='/root/.paddleocr/whl/rec/latin/latin_PP-OCRv3_rec_infer', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_batch_num=1, max_text_length=25, rec_char_dict_path='/usr/local/lib/python3.10/dist-packages/paddleocr/ppocr/utils/dict/latin_dict.txt', use_space_char=True, vis_font_path='./doc/fonts/simfang.ttf', drop_score=0.5, e2e_algorithm='PGNet', e2e_model_dir=None, e2e_limit_side_len=768, e2e_limit_type='max', e2e_pgnet_score_thresh=0.5, e2e_char_dict_path='./ppocr/utils/ic15_dict.txt', e2e_pgnet_valid_set='totaltext', e2e_pgnet_mode='fast', use_angle_cls=True, cls_model_dir='/root/.paddleocr/whl/cls/ch_ppocr_mobile_v2.0_cls_infer', cls_image_shape='3, 48, 192', label_list=['0', '180'], cls_batch_num=6, cls_thresh=0.8, enable_mkldnn=True, cpu_threads=10, use_pdserving=False, warmup=False, sr_model_dir=None, sr_image_shape='3, 32, 128', sr_batch_num=1, draw_img_save_dir='./inference_results', save_crop_res=False, crop_res_save_dir='./output', use_mp=False, total_process_num=1, process_id=0, benchmark=False, save_log_path='./log_output/', show_log=True, use_onnx=False, return_word_box=False, output='./output', table_max_len=488, table_algorithm='TableAttn', table_model_dir=None, merge_no_span_structure=True, table_char_dict_path=None, formula_algorithm='LaTeXOCR', formula_model_dir=None, formula_char_dict_path=None, formula_batch_num=1, layout_model_dir=None, layout_dict_path=None, layout_score_threshold=0.5, layout_nms_threshold=0.5, kie_algorithm='LayoutXLM', ser_model_dir=None, re_model_dir=None, use_visual_backbone=True, ser_dict_path='../train_data/XFUND/class_list_xfun.txt', ocr_order_method=None, mode='structure', image_orientation=False, layout=True, table=True, formula=False, ocr=True, recovery=False, recovery_to_markdown=False, use_pdf2docx_api=False, invert=False, binarize=False, alphacolor=(255, 255, 255), lang='french', det=True, rec=True, type='ocr', savefile=False, ocr_version='PP-OCRv4', structure_version='PP-StructureV2')
# PaddleOCR initialized.
#
# Starting OCR evaluation...
# ==================================================
#
# Processing 8.jpeg...
# [2024/10/31 06:23:19] ppocr DEBUG: dt_boxes num : 46, elapsed : 1.3631856441497803
# [2024/10/31 06:23:21] ppocr DEBUG: cls num  : 46, elapsed : 1.5257623195648193
# [2024/10/31 06:23:31] ppocr DEBUG: rec_res num  : 46, elapsed : 10.177034139633179
#
# ==================================================
# DETAILED TEXT COMPARISON FOR: 8.jpeg
# ==================================================
#
# REFERENCE TEXT (Ground Truth):
# ------------------------------
# BIOCHIMIE SANGUINE
# Analyse                                      Résultat    Unité                    Valeurs de référence     Résultat antérieur    dat
# Sodium                                       137        mmol/l                   ( 135 - 145 )            133                   26/10/24
# Potentiométrie Indirecte (Alinity ci)
# Potassium                                    3,95       mmol/l                   ( 3,70 - 5,30 )          3,60                  27/10/24
# Potentiométrie Indirecte (Alinity ci)
# Chlorures                                    100        mmol/l                   ( 95 - 110 )             99                    26/10/24
# Potentiométrie Indirecte (Alinity ci)
# Réserve alcaline                            27         mmol/l                   ( 21 - 28 )              26                    26/10/24
# Enzymatique (Alinity ci)
# Trou anionique plasmatique                   14         mmol/l                   ( 12 - 20 )              11                    26/10/24
# (Calcul)
# Protéines Totales                            68         g/l                      ( 64 - 83 )              59                    26/10/24
# Biuret cinétique (Alinity ci)
# Calcium Total                                86         mg/l                     ( 80 - 105 )             78                    26/10/24
# Colorimétrie (Alinity ci)
# Soit                                     2,15       mmol/l                   ( 2,00 - 2,63 )          1,95                  26/10/24
#
# EXTRACTED TEXT (OCR Result):
# ------------------------------
# Unia Valaue de at6rnce Sodfyt 137 mmov ( 135 - 145 ) 733 26/T0/24 noVl ( 3.70 - 5,30 ) 3.60 27/1024 ) ( 95 - 110 ) 66 251024 (21 -28 ) 26 251024 ( 12 -20 ) 17 23/1024 E3 . (64 - 83 ) 59 251024 ( 80 - 105 ) 64 T.E 21024 (2.00 - 2.03) 1.95
#
# WORD COUNT COMPARISON:
# Reference text word count: 119
# Extracted text word count: 61
#
# METRICS FOR: 8.jpeg
# Reference words: 119
# Extracted words: 61
# Correct words: 17
# Precision: 0.28
# Recall: 0.14
# F1 Score: 0.19
# Execution Time: 16.31 seconds
#
# Processing 17.jpeg...
# [2024/10/31 06:23:35] ppocr DEBUG: dt_boxes num : 54, elapsed : 1.139061689376831
# [2024/10/31 06:23:36] ppocr DEBUG: cls num  : 54, elapsed : 0.8997848033905029
# [2024/10/31 06:23:57] ppocr DEBUG: rec_res num  : 54, elapsed : 21.19162082672119
#
# ==================================================
# DETAILED TEXT COMPARISON FOR: 17.jpeg
# ==================================================
#
# REFERENCE TEXT (Ground Truth):
# ------------------------------
# BIOCHIMIE SANGUINE (suite)
# Analyse                                      Résultat    Unité                    Valeurs de référence     Résultat antérieur    dat
# DFG estimé par CKD-EPI                       70         ml/min/1,73m²                                     57                    23/10/24
# Classification de la maladie rénale chronique (MRC) en fonction du DFG (KDIGO 2011)
# >= 90 sans marqueur d' atteinte rénale         Pas d'atteinte rénale
# >= 90 avec marqueurs d' atteinte rénale*       G1  : MRC avec DFG normal ou augmenté
# 60 à 89 avec marqueurs d' atteinte rénale*     G2  : MRC avec DFG légèrement diminué
# 45 à 59                                        G3a : IRC légère à modérée
# 30 à 44                                        G3b : IRC modérée à sévère
# 15 à 29                                        G4  : IRC sévère
# < 15 ou dialyse                                G5  : IRC terminale
# (*) Albuminurie de faible débit, protéinurie clinique, hématurie, leucocyturie ou anomalies morphologiques ou histologiques persitantes
# plus de tois mois.
# Calcium Total                                93         mg/l                     ( 80 - 105 )             96                    23/10/24
# Colorimétrie (Alinity ci)
# Soit                                     2,33       mmol/l                   ( 2,00 - 2,63 )          2,40                  23/10/24
#
# EXTRACTED TEXT (OCR Result):
# ------------------------------
# BIOCHIMIE SANGUINE (suite) Analvse Résultat Unite Yaleura de r&férance du DFG estim6 par CKD-EP1 70 ml/min/1,73m2 Classification de la maladie rénale chronique (MRC) en fonction du DFG (KDiGO 2011) 57 23/1024  9o sans marqueur d' atteinte renale Pas d'atteinte rénale  9o avec marqueurs d atteinte rénale*  : MRC avec DFG normai ou augmenté G 1 60  a 89  avec rmarqueurs d atteinte rénale- g2 : MRC avec DFG iegerement diminue 45 a 59 G3a : iRc légcre a moderée 30 a 44 G3b : IRC modéree a sévere 15 a 29 G4 : 1RC severe  15 ou dialyse G5 : IRC terminale () Aibuminurie de faible débit, proteinurie clinique, hématurie, leucocyturie ou anomalies morphotogique histologigues persitantes plus de tois mois. Calciurm Total 93 mg/l ( 80 - 105 ) 96 23/10/24 Colorimétrie (Alinity ci) Soit 2.33 ( 2.00 - 2.63 ) Ot'Z 23/1024
#
# WORD COUNT COMPARISON:
# Reference text word count: 149
# Extracted text word count: 143
#
# METRICS FOR: 17.jpeg
# Reference words: 149
# Extracted words: 143
# Correct words: 73
# Precision: 0.51
# Recall: 0.49
# F1 Score: 0.50
# Execution Time: 26.02 seconds
#
# Processing 7.jpeg...
# [2024/10/31 06:24:02] ppocr DEBUG: dt_boxes num : 73, elapsed : 1.7120065689086914
# [2024/10/31 06:24:04] ppocr DEBUG: cls num  : 73, elapsed : 1.7023518085479736
# [2024/10/31 06:24:27] ppocr DEBUG: rec_res num  : 73, elapsed : 22.92773723602295
#
# ==================================================
# DETAILED TEXT COMPARISON FOR: 7.jpeg
# ==================================================
#
# REFERENCE TEXT (Ground Truth):
# ------------------------------
# BIOCHIMIE SANGUINE
# Analyse                                      Résultat    Unité                    Valeurs de référence     Résultat antérieur    dat
# CRP                                          1,6        mg/l                     ( < 5,0 )                5,3                   25/12/18
# Turbidimétrie(Alinity ci)
# Ferritine                                    17,5       ng/ml                    ( 11,0 - 306,8 )         13,0                  18/07/24
# Chimiluminescence (Alinity ci)
# En cas de maladie rénale chronique, d'insuffisance cardiaque ou de maladie inflammatoire chronique de l'intestin :
#
# Carence martiale absolue si CST < 20% et ferritine < 100 μg/L.
# Carence martiale fonctionnelle si CST < 20% et ferritine >100 μg/L.
#
# Glucose                                      0,85       g/l                      ( 0,70 - 1,05 )          0,98                  05/04/24
# Enzymatique (Alinity ci)
# Soit                                     4,73       mmol/l                   ( 3,89 - 5,84 )          5,45                  05/04/24
# -Une Glycémie à jeûn > ou = 1.26 g/l (Soit 7 mmol/l) à 2 reprises est en faveur d'un diabète sucré (OMS)
# -Une Glycémie à jeûn chez la femme enceinte > ou = 0.92 g/l (Soit 5.06 mmol/l) est en faveur d'un diabète gestationnel
# HbA1c (NGSP)                                5,9        %                        ( < 5,6 )                 6,0                   18/07/24
# HPLC (Arkray)
# HbA1c (IFCC)                            41,0       mmol/mol                 ( < 38,0 )                42,0                  18/07/24
#
# Pré-diabète :         5.7 à 6.4%
# Diabète:             > ou = 6.5%
# Surveillance du diabète :
#
# < ou = 7%    :   Très bon équilibre glycémique
# 7.1 à 8%     :   Bon équilibre glycémique
#
#
# 8.1%       :   Mauvais équilibre glycémique
#
#
#
#
#
# Résultat à interpréter en dehors des contextes suivants : hémoglobinopathie, anémie , transfusion, insuffisance rénale et grossesse; un
# dosage des fructosamines plasmatiques est alors conseillé.
# Urée                                         0,14       g/l                      ( 0,15 - 0,38 )          0,23                  18/07/24
# Enzymatique (Alinity ci)
# Soit                                     2,3        mmol/l                   ( 2,5 - 6,4 )            3,8                   18/07/24
#
# EXTRACTED TEXT (OCR Result):
# ------------------------------
# BIOCHIMIE SANGUINE Analyse Resuitat Ynité Yaleurs de reférence Resultat antdricur su: CRP 1,6 rng/l (5,0) 5.3 25/12/18 Turbidimetrie(Alinity ci) 17,5 ng/ml ( 11,0 - 306,8 ) 13,0 18/07/24 Ferritine Chumiuminescence (Alinity ci) En cas de maladie rénale chronique, d'insuffisance cardiaque ou de maladic inflammatoire chronique de rintestin : - Carence martiale absolue si CsT  20% et ferritine - 100 pg/L. - Carence martiale fonctionnelle si CsT < 20% et ferritine >100 g/L. 0.85 g/1 ( 0,70 - 1,05 ) 0.98 Glucose 05/042 Enzymatique (Ahnity a) 4,73 mmol/l ( 3.89 - 5,84 ) 5.45 05/04/24 Soit -Une Glycémie a jeun > ou = 1.26 g/l (Soit 7 mmoVi) a 2 reprises est en faveur d'un diabete sucré (OMS) -Une Glycémie a jean chez la femme enceinte > ou = 0.92 g/l (Soit 5.06 mmo/l) est en faveur dun diabete gestationnel % (5,6) 6.0 5,9 18/07/24 HbA1c (NGSP) HPLC (Arkr8y)  mmol/mol (38,0) 42.0 18/07/24 HbA1c (lFCC) 41,0 - Pré-diabéte 5.7 a 6.4% - Diabete  ou = 6.5%  Survaillance du diabéte :  ou  7% Tres bon equilibre glycemique - 7 1 a 8% Bon équilibre glycemique  8 1% Mauvais équllibre glycémique Resuitat a interpréter en denors des contextes suivants :.hémoglabinopathle. anömie . transfusion. insuffisance rénale et grossesse: un  dosage des fructosarnines plasmatiques cst alors consallé. Uree (0.15 - 0.38) 0.23 18/07/24 0.14 g/l Enzymahqut (Ahraty C) Soit ( 2.5- 6.4) 3.8 1807/24 2,3 mmol/l
#
# WORD COUNT COMPARISON:
# Reference text word count: 246
# Extracted text word count: 231
#
# METRICS FOR: 7.jpeg
# Reference words: 246
# Extracted words: 231
# Correct words: 99
# Precision: 0.43
# Recall: 0.40
# F1 Score: 0.42
# Execution Time: 29.75 seconds
#
# Processing 11.jpeg...
# [2024/10/31 06:24:32] ppocr DEBUG: dt_boxes num : 80, elapsed : 1.6233348846435547
# [2024/10/31 06:24:34] ppocr DEBUG: cls num  : 80, elapsed : 1.9577481746673584
# [2024/10/31 06:24:59] ppocr DEBUG: rec_res num  : 80, elapsed : 24.313934087753296
#
# ==================================================
# DETAILED TEXT COMPARISON FOR: 11.jpeg
# ==================================================
#
# REFERENCE TEXT (Ground Truth):
# ------------------------------
# BIOCHIMIE SANGUINE
# Analyse                                            Résultat        Unité                     Valeurs de référence      Résultat antérieur    du:
# Glucose                                            2,14     g/l                              ( 0,70 - 1,05 )          1,96                  15/04/24
# Enzymatique (Alinity ci)
# Soit                                              11,90     mmol/l                           ( 3,89 - 5,84 )          10,90                 15/04/24
# -Une Glycémie à jeûn > ou = 1.26 g/l (Soit 7 mmol/l) à 2 reprises est en faveur d'un diabète sucré (OMS)
# HbA1c (NGSP)                                      7,7      %                                ( < 5,6 )                8,1                   15/04/24
# HPLC (Arkray)
# HbA1c (IFCC)                                      61,0     mmol/mol                         ( < 38,0 )               65,0                  15/04/24
#
# Pré-diabète :        5.7 à 6.4%
# Diabète:            > ou = 6.5%
# Surveillance du diabète :
#
# < ou = 7%    : Très bon équilibre glycémique
# 7.1 à 8%     : Bon équilibre glycémique
#
#
# 8.1%       : Mauvais équilibre glycémique
#
#
#
#
#
# Résultat à interpréter en dehors des contextes suivants : hémoglobinopathie, anémie , transfusion, insuffisance rénale et grossesse; un
# dosage des fructosamines plasmatiques est alors conseillé.
# Urée                                              0,31     g/l                              ( 0,15 - 0,38 )          0,45                  15/04/24
# Enzymatique (Alinity ci)
# Soit                                              5,2      mmol/l                           ( 2,5 - 6,4 )            7,5                   15/04/24
# Créatinine                                        8        mg/l                             ( 6 - 13 )               8                     15/04/24
# Jaffé cinétique (Alinity ci)
# Soit                                              70,80    µmol/l                           ( 53,00 - 115,00 )       70,80                 15/04/24
# DFG estimé par CKD-EPI                            95       ml/min/1,73m²                                            96                    15/04/24
#
# EXTRACTED TEXT (OCR Result):
# ------------------------------
# BIOCHIMIE SANGUINE * Analyse Résultat Unit& Yaleura de róf&rence Rasultat antarieut sdur Glucose 2,14 g/1 ( 0,70 - 1,05 ) Enzymatique (Aliniy ci) 1.96 15/04/24 Soit 11,90 mmol/i ( 3.89 - 5.84 ) 10.90 15/04/24 -Une Glycémie a jeün > ou = 1.26 g/l (Soit 7 mmoVI) a 2 reprises est en faveur d'un diabete sucré (OMS) HbA1c (NGSP) 7,7 % HPLC (Arkray) (<5.6) 8.1 15/04/24 HbA1c (lFCC) 61,0  mmol/mot (< 38.0) 65.0 15/04/24 - Pré-diabéte 5.7 a 6.4% - Diabéte:  ou = 6.5% - Surveillance du diabete : ou = 7%  Trés bon équilibre glycémique - 7.1 a 8% Bon équilibre glycémique  8.1%  Mauvais équilibre glycemique Résultat a interpréter en dehors des contextes suivants : .hémogiobinopathie, anémie . transfusion, insuffisance rénale et grossesse: un dosage des fructosamines plasmatiques est aiors conseillé. Uree 0.31 Enzymatiquo (Alinity ci) I/6 (0,15- 0.38) 0.45 15/04/24 Soit 5.2 mmoi/l ( 2.5 - 6,4 ) 7.5 15/04/24 Créatinine jatte cmbtiqve (Alinity ci) 8 mg/l (6-13) 8 15/04/24 Soit 70.80 pmol/l ( 53.00 - 115.00 ) 70.80 15/04/24 DFG estimé par CKD-EPI  96 ml/min/1,73m2 96 15/04/24
#
# WORD COUNT COMPARISON:
# Reference text word count: 193
# Extracted text word count: 180
#
# METRICS FOR: 11.jpeg
# Reference words: 193
# Extracted words: 180
# Correct words: 80
# Precision: 0.44
# Recall: 0.41
# F1 Score: 0.43
# Execution Time: 31.52 seconds
#
# Processing 10.jpeg...
# [2024/10/31 06:25:03] ppocr DEBUG: dt_boxes num : 79, elapsed : 1.4830358028411865
# [2024/10/31 06:25:07] ppocr DEBUG: cls num  : 79, elapsed : 3.5871176719665527
# [2024/10/31 06:25:28] ppocr DEBUG: rec_res num  : 79, elapsed : 20.935343742370605
#
# ==================================================
# DETAILED TEXT COMPARISON FOR: 10.jpeg
# ==================================================
#
# REFERENCE TEXT (Ground Truth):
# ------------------------------
# BIOCHIMIE SANGUINE
# Analyse                                              Résultat        Unité                    Valeurs de référence        Résultat antérieur    du:
# CRP
# Turbidimétrie(Alinity ci)                           32,4            mg/l                     ( < 5,0 )                   20,4                  16/03/23
# Ferritine
# Chimiluminescence (Alinity ci)                      55,0            ng/ml                    ( 11,0 - 306,8 )
# En cas de maladie rénale chronique, d'insuffisance cardiaque ou de maladie inflammatoire chronique de l'intestin :
#
# Carence martiale absolue si CST < 20% et ferritine < 100 μg/L.
# Carence martiale fonctionnelle si CST < 20% et ferritine >100 μg/L.
#
# Sodium
# Potentiométrie Indirecte (Alinity ci)              143             mmol/l                   ( 135 - 145 )               144                   25/06/24
# Potassium
# Potentiométrie Indirecte (Alinity ci)              3,98            mmol/l                   ( 3,70 - 5,30 )             3,96                  25/06/24
# Chlorures
# Potentiométrie Indirecte (Alinity ci)              110             mmol/l                   ( 95 - 110 )                111                   25/06/24
# Réserve alcaline
# Enzymatique (Alinity ci)                           25              mmol/l                   ( 21 - 28 )                 23                    25/06/24
# Trou anionique plasmatique
# (Calcul)                                           12              mmol/l                   ( 12 - 20 )                 14                    25/06/24
# Protéines Totales
# Biuret cinétique (Alinity ci)                      76              g/l                      ( 64 - 83 )                 71                    25/06/24
# Glucose
# Enzymatique (Alinity ci)                           0,94            g/l                      ( 0,70 - 1,05 )             0,73                  25/06/24
# Soit                                       5,23            mmol/l                   ( 3,89 - 5,84 )             4,06                  25/06/24
# -Une Glycémie à jeun > ou = 1.26 g/l (Soit 7 mmol/l) à 2 reprises est en faveur d'un diabète sucré (OMS)
# -Une Glycémie à jeun chez la femme enceinte > ou = 0.92 g/l (Soit 5.06 mmol/l) est en faveur d'un diabète gestationnel
#
# EXTRACTED TEXT (OCR Result):
# ------------------------------
# BIOCHIMIE SANGUINE Analvse Resultat Unlte Yaleura de róférence Résultat anterieur CRP 32,4 Turbrdimatne(Alnity ci) rmg/l (<5,0) 20,4 16/03/23 Ferritine 55,0 ng/ml Chumiluminescence (Alnity ci) ( 11,0 - 306,8 ) En cas de maladie rénale chronique, d'insuffisance cardiaque ou de maladie inflammatoire chronique de Fintestin : - Carence martiale absolue si CsT < 20% et ferritine < 1o0 yg/L. - Carence martiale fonctionnelle si CsT - 20% et ferritine >100 g/L. Sodium 143  mmol/l ( 135 - 145 ) Potontiometne indirecte (Alinity ci) 144 25/06/24 Potassium 3,98 mmol/l ( 3,70 - 5,30 ) Potentiometne Indtrecte (Ainity a) 3.96 25/06/24 Chlorures 110 mmol/l ( 95 - 110 ) Potantrométne Indirecte (Alinity a) 177 25/06/24 Reserve alcaline 25 mmo/l (21 -28) 23 Enzymatique (Ainily a) 25/06/24 Trou anionique plasmatique 12 mmo!/l (12-20) (Calcul) 14 25/06/24 Protéines Totales 76 g/l Butat canttique (Alinrty ci) (64-83) 71 25/06/24 Glucose Enzymatiquo (Ahnity a) 0.94 g/l ( 0.70 - 1.05 ) 0.73 25/06/24 Soit 5.23 rnmol/l ( 3,89 - 5.84 ) 4.06 25/06/24 -Une Glycérnie a jeún > ou = 1.26 g/l (Soit 7 mmoVl) a 2 reprises est en faveur d'un diabte sucré (OMS) -Une Glycémie a jeün chez la femme enceinte > ou = 0.92 g/l (Soit 5.06 mmo/l) est en faveur dun diabete gostationnei
#
# WORD COUNT COMPARISON:
# Reference text word count: 223
# Extracted text word count: 210
#
# METRICS FOR: 10.jpeg
# Reference words: 223
# Extracted words: 210
# Correct words: 92
# Precision: 0.44
# Recall: 0.41
# F1 Score: 0.42
# Execution Time: 29.52 seconds
#
# Processing 2.jpeg...
# [2024/10/31 06:25:34] ppocr DEBUG: dt_boxes num : 113, elapsed : 3.082882881164551
# [2024/10/31 06:25:38] ppocr DEBUG: cls num  : 113, elapsed : 3.792534589767456
# [2024/10/31 06:26:07] ppocr DEBUG: rec_res num  : 113, elapsed : 29.348721981048584
#
# ==================================================
# DETAILED TEXT COMPARISON FOR: 2.jpeg
# ==================================================
#
# REFERENCE TEXT (Ground Truth):
# ------------------------------
# BIOCHIMIE SANGUINE (suite)
# Analyse                                      Résultat    Unité                    Valeurs de référence     Résultat antérieur    dat
# Classification de la maladie rénale chronique (MRC) en fonction du DFG (KDIGO 2011)
# >= 90 sans marqueur d' atteinte rénale         Pas d'atteinte rénale
# >= 90 avec marqueurs d' atteinte rénale*       G1  : MRC avec DFG normal ou augmenté
# 60 à 89 avec marqueurs d' atteinte rénale*     G2  : MRC avec DFG légèrement diminué
# 45 à 59                                        G3a : IRC légère à modérée
# 30 à 44                                        G3b : IRC modérée à sévère
# 15 à 29                                        G4  : IRC sévère
# < 15 ou dialyse                                G5  : IRC terminale
# (*) Albuminurie de faible débit, protéinurie clinique, hématurie, leucocyturie ou anomalies morphologiques ou histologiques persitantes
# plus de tois mois.
# ASAT (GOT)                                   14         UI/l                     ( < 35 )                 16                    25/07/24
# UV sans P5P(Alinity ci)
# ALAT (GPT)                                   13         UI/l                     ( < 40 )                 10                    25/07/24
# UV sans P5P(Alinity ci)
# Créatine kinase                              45         UI/l                     ( 24 - 195 )             46                    01/03/24
# Enzymatique (Alinity ci)
# BILAN LIPIDIQUE
# Analyse                                      Résultat    Unité                    Valeurs de référence     Résultat antérieur    dat
# Aspect                                                   LIMPIDE
# Triglycérides                                0,65       g/l                      ( 0,60 - 1,50 )          0,78                  25/07/24
# Enzymatique (Alinity ci)
# Soit                                     0,74       mmol/l                   ( 0,68 - 1,71 )          0,89                  25/07/24
# Cholestérol HDL                              0,38       g/l                      ( 0,40 - 0,60 )          0,41                  25/07/24
# Enzymatique (Alinity ci)
# Soit                                     0,98       mmol/l                   ( 1,03 - 1,54 )          1,06                  25/07/24
# Cholestérol LDL                              0,93       g/l                      ( < 1,55 )               0,85                  25/07/24
# (Calcul)
# Soit                                     2,40       mmol/l                   ( < 4,00 )               2,19                  25/07/24
# Cholestérol                                  1,44       g/l                      ( 1,50 - 2,00 )          1,42                  25/07/24
# Enzymatique (Alinity ci)
# Soit                                     3,72       mmol/l                   ( 3,87 - 5,16 )          3,66                  25/07/24
# Cholesterol non HDL                          1,06       g/l                                              1,01                  25/07/24
# (Calcul)
# Soit                                     2,73       mmol/l                                           2,61                  25/07/24
# Les objectifs pour un patient dans le cadre d'une prise en charge initiale (ESC 2021) :
# -Haut risque cardiovasculaire          : LDL-c < 1,00 g/L (2,6 mmol/L) et non-HDLc < 1,30 g/L (3,4 mmol/L).
# -Très Haut risque cardiovasculaire     : LDL-c < 0,70 g/L (1,8 mmol/L) et non-HDLc < 1,00 g/L (2,6 mmol/L).
# Les objectifs pour un patient dans le cadre d'une intensification thérapeutique (ESC 2021) :
# -Haut risque cardiovasculaire          : LDL-c < 0,70 g/L (1,8 mmol/L) associé à baisse de 50% et non-HDLc < 1,00 g/L (2,6 mmol/L).
# -Très Haut risque cardiovasculaire     : LDL-c < 0,55 g/L (1,4 mmol/L) associé à baisse de 50% et non-HDLc < 0,85 g/L (2,2 mmol/L).
#
# EXTRACTED TEXT (OCR Result):
# ------------------------------
# -- 30710/24 10:11 BIOCHIMIE SANGUINE (suite) Analyse Classification de la naladie rénale chronique (MRC) en fonction du DFG (KDiGO 2011) Reaultat Unite Yaieura de.référence Resultt anterdeur >= 90 sans marqueur d atteinte rénale cur >= 90 avec marqueurs d atteinte rénale* Pas datteinte rénale 60 a 89 avec marqueurs d atteinte rénale' G1 : MRC avec DFG normal ou augrente 45 a 59 G2 : MRC avec DFG legerement diminue 30 a 44 G3a : IRC légere a modérée 15 a 29 G3b : IRC modéree a severe < 15 ou dialyse G4 : IRC sévere () Albuminurie de faible débit. protéinurie clinique, hématurie, leucocyturie ou anonalres morphologiques ou histologiques persitantes G5 : IRC terminale plus de tois mois. ASAT (GOT) 14 Ul/l UV sans P5P(Ahnnty a) (<35) 16 25/07/24 ALAT (GPT) 13 UII UV sans P5P{Aknsty c} (<40) 10 25/07/24 Créatine kinase 45 UI Enzymabque (Anty a} (24 - 195) 46 01/03/24 BILAN LIPIDIQUE Analyse Resultat Uatte Yeleurs de réfärence Rasultat antériaur dur Aspect LIMPIDE Triglycérides 0,65 g/I ( 0,60 - 1,50) 0.78 25/07/24 Enzymalique (Afinrty a) Soit 0,74 mmol/l (0,68 -1,71) 0.89 25/07/24 Cholestérol HDL 0,38 g/l (0.40 - 0.60) 0.41 25/07/24 Enzymatqus (Abnty c} Soit 0,98 mmo/l ( 1.03 - 1.54 ) 1,06 25/07/24 Cholestérol LDL 0,93 g/I (<1,55) 0.85 25/07/24 (Calcul) Soit 2.40  mmal/l (<4,00) 2.19 25/07/24 Cholestérol 1,44 g/I ( 1.50 - 2.00) 1.42 25/07/24 Enzymatquo (Afuuty c) Soit 3,72 mmoM ( 3,87 - 5.16 ) 3.66 25/07/24 Cholesterol non HDL 1,06 g/i 1.01 25/07/24 (Cacu) Sori 2,73 mmo/l 2.61 25/07/24 Les cbjectifs pour un patient dans le cedre dune prise on charge Initlale (ESC 2021} . -Haut risque cardiovasculalre LDL -c < 1,00 g/L (2,6 mmaVL) ot non-HDLc < 1,30 g/L (3,4 mmoVL) -Trés Haut rsque cardiovasculaireLOL -c < 0.70 a/L (1.8 mmov) et non-HlC  1.00 /L (2.6 mmorL) Les objectfs pour un pationt dane le cadre dune Intensification thrapeutique (ESC 2021) L-.70 g/1.8 mmovassocieabals8'de 50%et non-HDLc 1,00 g/L (2.6 mmo -Haut risque cardlovasculatre
#
# WORD COUNT COMPARISON:
# Reference text word count: 385
# Extracted text word count: 330
#
# METRICS FOR: 2.jpeg
# Reference words: 385
# Extracted words: 330
# Correct words: 123
# Precision: 0.37
# Recall: 0.32
# F1 Score: 0.34
# Execution Time: 39.21 seconds
#
# Processing 13.jpeg...
# [2024/10/31 06:26:13] ppocr DEBUG: dt_boxes num : 78, elapsed : 1.8522603511810303
# [2024/10/31 06:26:14] ppocr DEBUG: cls num  : 78, elapsed : 1.7698686122894287
# [2024/10/31 06:26:36] ppocr DEBUG: rec_res num  : 78, elapsed : 21.606388330459595
#
# ==================================================
# DETAILED TEXT COMPARISON FOR: 13.jpeg
# ==================================================
#
# REFERENCE TEXT (Ground Truth):
# ------------------------------
# BIOCHIMIE SANGUINE
# Analyse                                      Résultat    Unité                    Valeurs de référence     Résultat antérieur    dat
# Glucose                                      2,05       g/l                      ( 0,70 - 1,05 )          1.51                  25/07/24
# Enzymatique (Alinity ci)
# Soit                                     11,40      mmol/l                   ( 3,89 - 5,84 )          8.40                  25/07/24
# -Une Glycémie à jeûn > ou = 1.26 g/l (Soit 7 mmol/l) à 2 reprises est en faveur d'un diabète sucré (OMS)
# HbA1c (NGSP)                                9,6        %                        ( < 5,6 )                 9.9                   25/07/24
# HPLC (Arkray)
# HbA1c (IFCC)                            82,0       mmol/mol                 ( < 38,0 )                85.0                  25/07/24
#
# Pré-diabète :         5.7 à 6.4%
# Diabète:             > ou = 6.5%
# Surveillance du diabète :
#
# < ou = 7%    :   Très bon équilibre glycémique
# 7.1 à 8%     :   Bon équilibre glycémique
#
#
# 8.1%       :   Mauvais équilibre glycémique
#
#
#
#
#
# Résultat à interpréter en dehors des contextes suivants : hémoglobinopathie, anémie , transfusion, insuffisance rénale et grossesse; un
# dosage des fructosamines plasmatiques est alors conseillé.
# Urée                                         0,22       g/l                      ( 0,15 - 0,38 )          0.25                  25/07/24
# Enzymatique (Alinity ci)
# Soit                                     3,7        mmol/l                   ( 2,5 - 6,4 )            4.2                   25/07/24
# Créatinine                                   8          mg/l                     ( 6 - 13 )               8                     25/07/24
# Jaffé cinétique (Alinity ci)
# Soit                                     70,80      μmol/l                   ( 53,00 - 115,00 )       70.80                 25/07/24
# DFG estimé par CKD-EPI                       103        ml/min/1,73m²                                     103                   25/07/24
#
# EXTRACTED TEXT (OCR Result):
# ------------------------------
# BIOCHIMIE SANGUINE Analyse Resultat Unite Valeurs de référence Resultat anterieuc du: Glucose 2,05  g/l ( 0.70 - 1.05 ) Enzymatique (Alnity ci) 1.51 25/07/24 Soit 11,40 mmol/l ( 3.89 - 5.84 ) 8,40 25/07/24 (swo) gons aaaqe!p unp unaaey ua isa sas!da z r (loaa  1!os) l/n gzt = no < una!e a!aaoig aun- HbA1c (NGSP) 9.6 % ( <5.6) HPLC (Arkray) 9.9 25/07/24 HbA1c (IFCC) 82,0  mmol/mol (  38,0) 85.0 25/07/24 - Pré-diabéte : 5.7 a 6.4% - Diabéte: > ou = 6.5% - Surveillance du diabete : + ou = 7%  : Trés bon équilibre glycemique - 7.1 a 8% :  Bon équilibre glycémique -  8.1% : Mauvais équilibre glycémique Résultat a interpréter en dehors des contextes suivants :.hémogiobinopathie. anémie . transfusion, insuffisance rénale et grossesse: un dosage des fructosamines plasmatiques est alors conseillé. Urée 0.22 g/l Enzymatxaua (Ainaty a) ( 0.15 - 0.38) 0.25 25/07/24 Soit 3,7 mmol/l (2.5- 6.4) 4.2 25/07/24 Créatinine (p kjtusv) onbrpun pusr 8 mg/l (6-13) 8 25/07/24 Soit 70.80 pmol/! ( 53.00 - 115.00 ) 70.80 25/07/24 DFG estimé par CKD-EPI 103 ml/min/1.73m2 103 25/07/24
#
# WORD COUNT COMPARISON:
# Reference text word count: 193
# Extracted text word count: 183
#
# METRICS FOR: 13.jpeg
# Reference words: 193
# Extracted words: 183
# Correct words: 79
# Precision: 0.43
# Recall: 0.41
# F1 Score: 0.42
# Execution Time: 28.71 seconds
#
# Processing 1.jpeg...
# [2024/10/31 06:26:41] ppocr DEBUG: dt_boxes num : 82, elapsed : 1.4706909656524658
# [2024/10/31 06:26:44] ppocr DEBUG: cls num  : 82, elapsed : 2.802840232849121
# [2024/10/31 06:27:08] ppocr DEBUG: rec_res num  : 82, elapsed : 23.487449645996094
#
# ==================================================
# DETAILED TEXT COMPARISON FOR: 1.jpeg
# ==================================================
#
# REFERENCE TEXT (Ground Truth):
# ------------------------------
# BIOCHIMIE SANGUINE
# Analyse                                    Résultat      Unité            Valeurs de référence     Résultat antérieur     du:
# CRP                                          3,7         mg/l             ( < 5,0 )                7,2                    25/07/24
# Turbidimétrie (Alinity ci)
# Glucose                                      1,24        g/l              ( 0,70 - 1,05 )          1,52                   25/07/24
# Enzymatique (Alinity ci)
# Soit                                 6,89        mmol/l           ( 3,89 - 5,84 )          8,45                   25/07/24
# -Une Glycémie à jeun > ou = 1.26 g/l (Soit 7 mmol/l) à 2 reprises est en faveur d'un diabète sucré (OMS)
# -Une Glycémie à jeun chez la femme enceinte > ou = 0.92 g/l (Soit 5.06 mmol/l) est en faveur d'un diabète gestationnel
# HbA1c (NGSP)                                8,0         %                ( < 5,6 )                 8,8                    25/07/24
# HPLC (Array)
# HbA1c (IFCC)                        64,0        mmol/mol         ( < 38,0 )                73,0                   25/07/24
#
# Pré-diabète :        5.7 à 6.4%
# Diabète:            > ou = 6.5%
# Surveillance du diabète :
# - < ou = 7%   : Très bon équilibre glycémique
# - 7.1 à 8%    : Bon équilibre glycémique
# - > 8.1%      : Mauvais équilibre glycémique
#
# Résultat à interpréter en dehors des contextes suivants : hémoglobinopathie, anémie, transfusion, insuffisance rénale et grossesse; un dosage des fructosamines plasmatiques est alors conseillé.
# Urée                                        0,19        g/l              ( 0,15 - 0,38 )          0,22                   25/07/24
# Enzymatique (Alinity ci)
# Soit                                3,2         mmol/l           ( 2,5 - 6,4 )            3,7                    25/07/24
# Créatinine                                  7           mg/l             ( 6 - 13 )               7                      25/07/24
# µame cinétique (Alinity ci)
# Soit                                61,95       µmol/l           ( 53,00 - 115,00 )       61,95                  25/07/24
#
# EXTRACTED TEXT (OCR Result):
# ------------------------------
# BIOCHIMIE SANGUINE Anaiyae Resultat Unite Yaleurs da reference Rdsultat ansarieuc du: CRP 3.7 mg/l ( x5,0) 7.2 25/07/24 Turbidimotno(Alinity cl) Glucose 1,24 g/l ( 0,70 - 1.05 ) 1,52 25/07/24 Enxymatquo (Alinity ci) Solt 6.89 mmol/l ( 3.89 - 5.84 ) 8.45 25/07/24 -Une Glyc6mle a jean  ou = 1.26 g/I (Soit 7 mmoVI)  a 2 reprises est en faveur d'un diabete sucr6 (OMs) -Uno Glycémie a jeún chez la femme enceinte > ou = 0.92 g/l (Solt 5.06 mmo/l) est en faveur d'un diabte gestationnel 8,0 % ( 5.6) 8.8 25/07/24 HbA1c (NGSP) HPLC (Arkroy) 64.0 (  38.0 ) 73.0 25/07/24 HbA1c (IFCC) mmol/mol - Pre-diabéte : 5.7 a 6.4% - Diabete: > ou = 6.5% - Surveillanco du diabete :  ou = 7% Trés bon eauilibre glycémique - 7.1 a 8% Bon éauilibre glycémique -  8.1% Mauvais equilibra glycemique Rosultat a Interpretor en dehora des contextes suivants : hemoglobinopathie, anemie . transfusion, insutfisance renale et grossasse: un 0.22 25/07/24 ( 0,15 - 0,38) 0.19 I/6 Uree 3.7 25/07/24 Enymahquo (Ahnity ci) (2,5-6.4) 3.2  mmol/l Soit 2 25/07/24 (6-13) 7 mg/l Creatinine 61.95 25/07/24 JemM cnquc (Afny o) moi/l ( 53.00 - 115.00 ) 61.95 Soit
#
# WORD COUNT COMPARISON:
# Reference text word count: 222
# Extracted text word count: 197
#
# METRICS FOR: 1.jpeg
# Reference words: 222
# Extracted words: 197
# Correct words: 66
# Precision: 0.34
# Recall: 0.30
# F1 Score: 0.32
# Execution Time: 31.65 seconds
#
# Processing 20.jpeg...
# [2024/10/31 06:27:15] ppocr DEBUG: dt_boxes num : 110, elapsed : 3.917371988296509
# [2024/10/31 06:27:18] ppocr DEBUG: cls num  : 110, elapsed : 2.727461576461792
# [2024/10/31 06:27:46] ppocr DEBUG: rec_res num  : 110, elapsed : 28.171740770339966
#
# ==================================================
# DETAILED TEXT COMPARISON FOR: 20.jpeg
# ==================================================
#
# REFERENCE TEXT (Ground Truth):
# ------------------------------
# BIOCHIMIE SANGUINE (suite)
# Analyse                                      Résultat    Unité                    Valeurs de référence     Résultat antérieur    dat
#
# Pré-diabète :         5.7 à 6.4%
# Diabète:             > ou = 6.5%
# Surveillance du diabète :
#
# < ou = 7%    :   Très bon équilibre glycémique
# 7.1 à 8%     :   Bon équilibre glycémique
#
#
# 8.1%       :   Mauvais équilibre glycémique
#
#
#
#
#
# Résultat à interpréter en dehors des contextes suivants : hémoglobinopathie, anémie , transfusion, insuffisance rénale et grossesse; un
# dosage des fructosamines plasmatiques est alors conseillé.
# Urée                                         0,28       g/l                      ( 0,15 - 0,38 )          0,31                  13/05/22
# Enzymatique (Alinity ci)
# Soit                                     4,7        mmol/l                   ( 2,5 - 6,4 )            5,2                   13/05/22
# Osmolarité Calculée                          292        mOsmol/l                 ( 280 - 305 )
# Créatinine                                   10         mg/l                     ( 6 - 13 )               8                     13/05/22
# Jaffé cinétique (Alinity ci)
# Soit                                     88,50      μmol/l                   ( 53,00 - 115,00 )       70,80                 13/05/22
# DFG estimé par CKD-EPI                       68         ml/min/1,73m²                                     91                    13/05/22
# Classification de la maladie rénale chronique (MRC) en fonction du DFG (KDIGO 2011)
# >= 90 sans marqueur d' atteinte rénale         Pas d'atteinte rénale
# >= 90 avec marqueurs d' atteinte rénale*       G1  : MRC avec DFG normal ou augmenté
# 60 à 89 avec marqueurs d' atteinte rénale*     G2  : MRC avec DFG légèrement diminué
# 45 à 59                                        G3a : IRC légère à modérée
# 30 à 44                                        G3b : IRC modérée à sévère
# 15 à 29                                        G4  : IRC sévère
# < 15 ou dialyse                                G5  : IRC terminale
# (*) Albuminurie de faible débit, protéinurie clinique, hématurie, leucocyturie ou anomalies morphologiques ou histologiques persitantes
# plus de tois mois.
# Calcium Total                                97         mg/l                     ( 80 - 105 )             98                    13/05/22
# Colorimétrie (Alinity ci)
# Soit                                     2,43       mmol/l                   ( 2,00 - 2,63 )          2,45                  13/05/22
# Magnésium Sérique                            2,42       mg/dl                    ( 1,60 - 2,60 )          2,19                  13/05/22
# Colorimétrie (Alinity ci)
# Soit                                     0,99       mmol/l                   ( 0,66 - 1,07 )          0,90                  13/05/22
# ASAT (GOT)                                   24         UI/l                     ( < 35 )                 20                    13/05/22
# UV sans P5P(Alinity ci)
# ALAT (GPT)                                   42         UI/l                     ( < 40 )                 24                    13/05/22
# UV sans P5P(Alinity ci)
# Phosphatase alcaline                         63         U/l                      ( 40 - 150 )
# Colorimétrie
#
# EXTRACTED TEXT (OCR Result):
# ------------------------------
# cHIMIE SANGUINE (suite) Analyae Résuitat Ynlté Vaieurs de référence Resultat antérieur du: - Pré-diabéte : 5.7  6.4% - Diabéte: > ou = 6.5% - Surveillance du diabéte : -  ou = 7% : Tres bon équilibre glycemique - 7.1 a 8% : Bon équilibre glycémique - > 8.1% : Mauvais équilibre glycemique Résultat a interpréter en dehors des contextes suivants : hémoglobinopathie. anémie . transfusion. insuffisance rénale et grossesse: un dosage des fructosamines plasmatiques est alors conseillé Uree 0,28  g/l ( 0,15- 0,38) 0.31 13/05/22 Enzymahque (Alinity a) Soit 4,7 mmol/ (2.5- 6.4) 5.2 13/05/22 Osmolarité Calculée 292 mOsmol/l ( 280 - 305) Créatinine 10 mg/l (6-13) 8 13/05/22 Jaffe anétique (Alinty cl) Soit 88.50 mol/l ( 53,00 - 115.00 ) 70.80 13/05/22 DFG estimé par CKD-EPI 68 ml/min/1.73m2 91 13/05/22 Classification de la maladie rénale chronique (MRC) en fonction du DFG (KDIGO 2011) >= 90 sans marqueur d atteinte rénale Pas datteinte rénale >= 90 avec margueurs d' attelnte rénale" G1 : MRC avec DFG normal ou augmenté 60 a 89 avec margueurs d atteinte rénale' G2 : MRC avec DFG légérement diminué 45 a 59 G3a : IRC légere a modérée 30 a 44 G3b : IRC modérée a sévere 15  29 G4 :IRC sévere < 15 ou dialyse G5 : IRC terminale () Aibuminurie de faible debit, protéinurie clinique. hématurie, leucocyturie ou anomalies morphologiques ou histologiques persitantes plus de tois mois Calcium Total 97 mg/l ( 80 - 105) 86 13/05/22 Cotonminis (Annty r) Solt 2.43  rnmol/t ( 2.00 - 2.63 ) 2.45 13/05/22 Magnésium Sérique 2,42 mg/dI ( 1.60 - 2.60 ) 2.19 13/05/22 Colormeine (Ahntty c) Soh 66'0 mmol/l (0.66-1.07) 0.90 13/05/22 ASAT (GOT) 24 UI/l (<35) 20 13/05/22 UV san P5P(ANnny o) ALAT (GPT) 42 UI/I (<40) 24 13/05/22 UV aans P5P{Ahnuly t} Phosphatase alcaline 63  U/I ( 40-150) Coorinatne
#
# WORD COUNT COMPARISON:
# Reference text word count: 327
# Extracted text word count: 306
#
# METRICS FOR: 20.jpeg
# Reference words: 327
# Extracted words: 306
# Correct words: 133
# Precision: 0.43
# Recall: 0.41
# F1 Score: 0.42
# Execution Time: 38.11 seconds
#
# Processing 18.jpeg...
# [2024/10/31 06:27:51] ppocr DEBUG: dt_boxes num : 71, elapsed : 1.4429817199707031
# [2024/10/31 06:27:53] ppocr DEBUG: cls num  : 71, elapsed : 1.7744171619415283
# [2024/10/31 06:28:17] ppocr DEBUG: rec_res num  : 71, elapsed : 24.18143320083618
#
# ==================================================
# DETAILED TEXT COMPARISON FOR: 18.jpeg
# ==================================================
#
# REFERENCE TEXT (Ground Truth):
# ------------------------------
# BIOCHIMIE SANGUINE (suite)
# Analyse                                      Résultat    Unité                    Valeurs de référence     Résultat antérieur    dat
# Classification de la maladie rénale chronique (MRC) en fonction du DFG (KDIGO 2011)
# >= 90 sans marqueur d' atteinte rénale         Pas d'atteinte rénale
# >= 90 avec marqueurs d' atteinte rénale*       G1  : MRC avec DFG normal ou augmenté
# 60 à 89 avec marqueurs d' atteinte rénale*     G2  : MRC avec DFG légèrement diminué
# 45 à 59                                        G3a : IRC légère à modérée
# 30 à 44                                        G3b : IRC modérée à sévère
# 15 à 29                                        G4  : IRC sévère
# < 15 ou dialyse                                G5  : IRC terminale
# (*) Albuminurie de faible débit, protéinurie clinique, hématurie, leucocyturie ou anomalies morphologiques ou histologiques persitantes
# plus de tois mois.
# Calcium Total                                101        mg/l                     ( 80 - 105 )             100                   18/09/24
# Colorimétrie (Alinity ci)
# Soit                                     2,53       mmol/l                   ( 2,00 - 2,63 )          2,50                  18/09/24
# ASAT (GOT)                                   46         UI/l                     ( < 35 )
# UV sans P5P(Alinity ci)
# ALAT (GPT)                                   37         UI/l                     ( < 40 )
# UV sans P5P(Alinity ci)
# Phosphatase alcaline                         93         U/l                      ( 40 - 150 )
# Colorimétrie (Alinity ci)
# GGT                                          27         U/l                      ( < 50 )
# Colorimétrie (Alinity ci)
# Bilirubine Totale                           6          mg/l                     ( 3 - 10 )
# Jendrassik (Alinity ci)
# Soit                                     10,2       μmol/l                   ( 5,1 - 17,1 )
#
# EXTRACTED TEXT (OCR Result):
# ------------------------------
# BIOCHIMIE SANGUINE (suite) Anaiyse Resultat Ciassification de la maladie rénale chronique (MRC) Unite Valeurs de réf&rence Résultat antérieur ) en fonction du DFG (KDiGO 2011) dur >= go sans marqueur d atteinte rénale  go avec marqueurs d atteinte rénale* Pas d'atteinte rénale 60 a s9 avec marqueurs d atteinte renale G1 : MRC avec DFG normal ou augmente 45  G2 : MRC avec DFG Iégerement diminue a s9 G3a : IRC iégere a modérée 3O a 44 15 a 29 G3b : iRC moderée a sévere c 15 ou dialyse G4 : IRC sévere () Albuminurie de faible débit. protéinurie clinique, hématurie, leucocyturie ou anomalies morphologiques ou histologiques persitantes G5 : IRC terminale plus de tois mois. Calcium Total 101 Cotorimctrie (Alinity ci) mg/l ( 80 - 105 ) 100 18/09/24 Soit 2.53 mmol/i ( 2.00 - 2.63 ) 2.50 18/09/24 ASAT (GOT) 46 UI/I UV sans P5P(Alnity ci) (35) ALAT (GPT) 37 U1/1 UV sans P5P(Alnity ci) (40) Phosphatase alcaline 93 U/I ( 40 - 150 ) Cotonm&tne (Alinity ci) GGT 27 U/1 Colonmótna (Ainity ci) ( 50 ) Bilirubine Totale 6 t/6w Jendraassk (Alniy ci) (3-10) Soit 10.2 umol/!
#
# WORD COUNT COMPARISON:
# Reference text word count: 207
# Extracted text word count: 191
#
# METRICS FOR: 18.jpeg
# Reference words: 207
# Extracted words: 191
# Correct words: 91
# Precision: 0.48
# Recall: 0.44
# F1 Score: 0.46
# Execution Time: 31.26 seconds
#
# Processing 19.jpeg...
# [2024/10/31 06:28:22] ppocr DEBUG: dt_boxes num : 78, elapsed : 1.7292706966400146
# [2024/10/31 06:28:26] ppocr DEBUG: cls num  : 78, elapsed : 4.031496286392212
# [2024/10/31 06:28:46] ppocr DEBUG: rec_res num  : 78, elapsed : 19.425530672073364
#
# ==================================================
# DETAILED TEXT COMPARISON FOR: 19.jpeg
# ==================================================
#
# REFERENCE TEXT (Ground Truth):
# ------------------------------
# BIOCHIMIE SANGUINE
# Analyse                                      Résultat    Unité                    Valeurs de référence     Résultat antérieur    dat
# Glucose                                      1,16       g/l                      ( 0,70 - 1,05 )          1,08                  02/05/24
# Enzymatique (Alinity ci)
# Soit                                     6,45       mmol/l                   ( 3,89 - 5,84 )          6,00                  02/05/24
# -Une Glycémie à jeûn > ou = 1.26 g/l (Soit 7 mmol/l) à 2 reprises est en faveur d'un diabète sucré (OMS)
# HbA1c (NGSP)                                5,7        %                        ( < 5,6 )                 6,7                   02/05/24
# HPLC (Arkray)
# HbA1c (IFCC)                            38,0       mmol/mol                 ( < 38,0 )                50,0                  02/05/24
#
# Pré-diabète :         5.7 à 6.4%
# Diabète:             > ou = 6.5%
# Surveillance du diabète :
#
# < ou = 7%    :   Très bon équilibre glycémique
# 7.1 à 8%     :   Bon équilibre glycémique
#
#
# 8.1%       :   Mauvais équilibre glycémique
#
#
#
#
#
# Résultat à interpréter en dehors des contextes suivants : hémoglobinopathie, anémie , transfusion, insuffisance rénale et grossesse; un
# dosage des fructosamines plasmatiques est alors conseillé.
# Urée                                         0,44       g/l                      ( 0,15 - 0,38 )          0,51                  02/05/24
# Enzymatique (Alinity ci)
# Soit                                     7,3        mmol/l                   ( 2,5 - 6,4 )            8,5                   02/05/24
# Créatinine                                   11         mg/l                     ( 6 - 13 )               12                    02/05/24
# Jaffé cinétique (Alinity ci)
# Soit                                     97,35      μmol/l                   ( 53,00 - 115,00 )       106,20                02/05/24
# DFG estimé par CKD-EPI                       67         ml/min/1,73m²                                     61                    02/05/24
#
# EXTRACTED TEXT (OCR Result):
# ------------------------------
# ...
# Enzymatique (Alinity ci)
# Soit                                     4,23       mmol/l                   ( 3,87 - 5,16 )          3,72                  13/05/22
# Cholesterol non HDL                          1,28       g/l
# (Calcul)
# Soit                                     3,30       mmol/l
# Les objectifs pour un patient dans le cadre d'une prise en charge initiale (ESC 2021) :
# -Haut risque cardiovasculaire          : LDL-c < 1,00 g/L (2,6 mmol/L) et non-HDLc < 1,30 g/L (3,4 mmol/L).
# -Très Haut risque cardiovasculaire     : LDL-c < 0,70 g/L (1,8 mmol/L) et non-HDLc < 1,00 g/L (2,6 mmol/L).
# Les objectifs pour un patient dans le cadre d'une intensification thérapeutique (ESC 2021) :
# -Haut risque cardiovasculaire          : LDL-c < 0,70 g/L (1,8 mmol/L) associé à baisse de 50% et non-HDLc < 1,00 g/L (2,6 mmol/L).
# -Très Haut risque cardiovasculaire     : LDL-c < 0,55 g/L (1,4 mmol/L) associé à baisse de 50% et non-HDLc < 0,85 g/L (2,2 mmol/L).
# HORMONOLOGIE
# Analyse                                      Résultat    Unité                    Valeurs de référence     Résultat antérieur    dat
# TSH Ultrasensible                            1,59       μU/ml                    ( 0,40 - 4,00 )          0,76                  13/05/22
# Chimiluminescence (Alinity ci)
# T4 Libre                                     0,99       ng/dl                    ( 0,70 - 1,48 )
# Chimiluminescence (Alinity ci)
# Soit                                     13         pmol/l                   ( 9 - 19 )
# T3 Libre                                     3,79       pg/ml                    ( 1,71 - 3,71 )
# Chimiluminescence (Alinity ci)
# Soit                                     5,84       pmol/l                   ( 2,63 - 5,71 )
# MARQUEURS TUMORAUX
# Analyse                                      Résultat    Unité                    Valeurs de référence     Résultat antérieur    dat
# PSA Total                                    0,70       ng/ml
# Chimiluminescence (Alinity ci)
#
# EXTRACTED TEXT (OCR Result):
# ------------------------------
# BlLAN LIPIDIQUE (suite) Analyse Resultat Unité Valeurs de reférence Résultatantérieur du: Aspect LIMPIDE 1,61 g/l ( 0,60 - 1,50 ) 0.83 130522 Triglycérides Enzymatque (Anity a) ( 0.68 - 1.71 ) 0.95 13/05/22 Soit 1,84 mmoll ( 0.40 - 0.60 ) 0.41 13/0522 0,36 g/l Cholestérol HDL Enzymaque (Anrty a) ( 1.03 - 1.54) 1.06 130522 0,93 mmol/l Soit 0,96 g/l <1,55 Cholestérol LDL. (Calcul) nmol/i (<4.00) 2.48 Soit ( 1.50-2.00) 1.44 13/05/22 1,64  g/l Cholestérol Enzymatrque (Alinity a) ( 3.87 - 5.16 ) 3.72 13/05/22 4,23  mmol/l Soit 1,28 l/6 Cholesterol non HDL &5 (Calcu 3,30 mmol/l Soit : LDL -c < 1,00 g/L (2,6 rnmoVL) et non-HDLc <1,30 g/L (3.4 mmoVL). -Haut risgue cardiovasculaire -Trés Haut risque cardiovasculaire: LDL -c< 0,70 g/L(1.8 mmoVL) et non-HDLc < 1.00 g/L(2.6 mmovL). tCa Les objectifs pour un patient dans le cadre dune intenslficatian thérapeutique (ESC 2021) : : LDL -c < 0,70 g/L (1,8 mmolL) associé & baisse de 50%_et non-HDLc < 1.00 g/L (2.6 mmoIL) ia -Haut risque cardiovasculaire (2oww ZZ) 6 s8'0>27OH-uou 1a %09 ep ass1sq  2oosse (71owa t'L) V6 Gg'0 > -707 :e!enoseA0ip1e snbsuaneH s911 O=& HORMONOLOGIE Yalaur.da.référence Baut tnttri Resultat Unfte Aralyae 0.76 13/05/22 1,59 U/ml (0,40-4,00) TSH Ultrasensible (0.70 - 1,48) lP/6u 66'0 T4 Libre Chrwrte wnca (A6ndy a) pmal/l (9.19) 13 I Solt pg/ml ( 1,71- 3.71) 3,79 T3 Libre nc (mfy a) ( 2.93 - 5.71 ) 5,84 pmol1 Sott MARQUEURS TUMORAUX d Yalnur Ldn r f nnce Besulta! Unfta c Amlvae PSA Total 0,70 ng/m1 1 yo
#
# WORD COUNT COMPARISON:
# Reference text word count: 301
# Extracted text word count: 254
#
# METRICS FOR: 14.jpeg
# Reference words: 301
# Extracted words: 254
# Correct words: 74
# Precision: 0.29
# Recall: 0.25
# F1 Score: 0.27
# Execution Time: 38.12 seconds
#
# Processing 15.jpeg...
# [2024/10/31 06:32:06] ppocr DEBUG: dt_boxes num : 59, elapsed : 1.7301008701324463
# [2024/10/31 06:32:08] ppocr DEBUG: cls num  : 59, elapsed : 1.7181899547576904
# [2024/10/31 06:32:30] ppocr DEBUG: rec_res num  : 59, elapsed : 21.59849262237549
#
# ==================================================
# DETAILED TEXT COMPARISON FOR: 15.jpeg
# ==================================================
#
# REFERENCE TEXT (Ground Truth):
# ------------------------------
# BIOCHIMIE SANGUINE
# Analyse                                      Résultat    Unité                    Valeurs de référence     Résultat antérieur    dat
# Glucose                                      1,04       g/l                      ( 0,70 - 1,05 )
# Enzymatique (Alinity ci)
# Soit                                     5,78       mmol/l                   ( 3,89 - 5,84 )
# -Une Glycémie à jeûn > ou = 1.26 g/l (Soit 7 mmol/l) à 2 reprises est en faveur d'un diabète sucré (OMS)
# -Une Glycémie à jeûn chez la femme enceinte > ou = 0.92 g/l (Soit 5.06 mmol/l) est en faveur d'un diabète gestationnel
# HbA1c (NGSP)                                5,7        %                        ( < 5,6 )
# HPLC (Arkray)
# HbA1c (IFCC)                            39,0       mmol/mol                 ( < 38,0 )
#
# Pré-diabète :         5.7 à 6.4%
# Diabète:             > ou = 6.5%
# Surveillance du diabète :
#
# < ou = 7%    :   Très bon équilibre glycémique
# 7.1 à 8%     :   Bon équilibre glycémique
#
#
# 8.1%       :   Mauvais équilibre glycémique
#
#
#
#
#
# Résultat à interpréter en dehors des contextes suivants : hémoglobinopathie, anémie , transfusion, insuffisance rénale et grossesse; un
# dosage des fructosamines plasmatiques est alors conseillé.
# Urée                                         0,20       g/l                      ( 0,15 - 0,38 )
# Enzymatique (Alinity ci)
# Soit                                     3,3        mmol/l                   ( 2,5 - 6,4 )
# Créatinine                                   8          mg/l                     ( 6 - 13 )
# Jaffé cinétique (Alinity ci)
# Soit                                     70,80      μmol/l                   ( 53,00 - 115,00 )
# DFG estimé par CKD-EPI                       86         ml/min/1,73m²
#
# EXTRACTED TEXT (OCR Result):
# ------------------------------
# BIOCHIMIE SANGUINE Analyse Rasultat Ynit& Yaleurs da réf&ranca Rasulstaotdrieur dus: Glucose 1.04 g/I ( 0,70 - 1,05 ) Enzymatique (Alinity c) Soit 5.78  mmoi/l (3.89-5.84 ) -Une Glyc&mie a je0n > ou = 1.26 g/l (Soit 7 mmoVI) a 2 reprises est en faveur d'un diabete sucre (OMS) -Une Glycernie a jean chez la femme enceinte > ou = 0.92 g/l (Soit 5.06 mmovi) est en faveur dun diabete gestationnel HbA1c (NGSP) 5,7 % (<5.6) HPLC (Arkray) HbA1c (IFCC) mmol/mol (38.0) - Pre-diabéte : 5.7 a 6.4% - Diabéte  ou = 6.5% - Surveillance du diabete :  ou = 7%  Trés bon équilibre glycémique - 7.1 a 8% Bon équilibre glycémique - > 8.1%  Mauvais équilibre glycémique Résultat a interpréter en dehors des contextes suivants :.hémogiobinopathie, an&mie . transfusion. insuffisance renalo et grossesse. un Uree 0.20 g/l ( 0.15 - 0.38) Enzymaquo (Alnny cl) Solt 3.3  mmol/l ( 2.5 - 6.4) Créatinine (D AzutV) onbpup oar 8 I/6w (6-13) Solt 70.80 mol/l ( 53.00 - 115.00) DFG estime par CKD-EPI 86 ml/min/1.73m2
#
# WORD COUNT COMPARISON:
# Reference text word count: 197
# Extracted text word count: 172
#
# METRICS FOR: 15.jpeg
# Reference words: 197
# Extracted words: 172
# Correct words: 72
# Precision: 0.42
# Recall: 0.37
# F1 Score: 0.39
# Execution Time: 28.75 seconds
#
# Processing 5.jpeg...
# [2024/10/31 06:32:33] ppocr DEBUG: dt_boxes num : 22, elapsed : 1.172163724899292
# [2024/10/31 06:32:34] ppocr DEBUG: cls num  : 22, elapsed : 1.1740267276763916
# [2024/10/31 06:32:40] ppocr DEBUG: rec_res num  : 22, elapsed : 6.382176160812378
#
# ==================================================
# DETAILED TEXT COMPARISON FOR: 5.jpeg
# ==================================================
#
# REFERENCE TEXT (Ground Truth):
# ------------------------------
# BIOCHIMIE SANGUINE
# Analyse                                      Résultat    Unité                    Valeurs de référence     Résultat antérieur    dat
# ASAT (GOT)                                   23         UI/l                     ( < 35 )                 21                    19/01/24
# UV sans P5P(Alinity ci)
# ALAT (GPT)                                   13         UI/l                     ( < 40 )                 10                    19/01/24
# UV sans P5P(Alinity ci)
#
# EXTRACTED TEXT (OCR Result):
# ------------------------------
# BIOCHIMIE SANGUINE Anaiyaa Resultat Unlte Yalours de r6f6renca Resultat anterieuc clur ASAT (GOT) UI/1 23 ( ε 35 ) 21 19/01/24 UV sans P6P(Allnity cl) ALAT (GPT) 13 UI/I (-40) 10 19/01/24 A UV sn P5P(Alintty ci)
#
# WORD COUNT COMPARISON:
# Reference text word count: 39
# Extracted text word count: 37
#
# METRICS FOR: 5.jpeg
# Reference words: 39
# Extracted words: 37
# Correct words: 18
# Precision: 0.49
# Recall: 0.46
# F1 Score: 0.47
# Execution Time: 10.48 seconds
#
# Processing 4.jpeg...
# [2024/10/31 06:32:46] ppocr DEBUG: dt_boxes num : 120, elapsed : 1.8227407932281494
# [2024/10/31 06:32:48] ppocr DEBUG: cls num  : 120, elapsed : 2.174412488937378
# [2024/10/31 06:33:23] ppocr DEBUG: rec_res num  : 120, elapsed : 34.42503786087036
#
# ==================================================
# DETAILED TEXT COMPARISON FOR: 4.jpeg
# ==================================================
#
# REFERENCE TEXT (Ground Truth):
# ------------------------------
# BIOCHIMIE SANGUINE (suite)
# Analyse                                      Résultat    Unité                    Valeurs de référence     Résultat antérieur    dat
# Classification de la maladie rénale chronique (MRC) en fonction du DFG (KDIGO 2011)
# >= 90 sans marqueur d' atteinte rénale         Pas d'atteinte rénale
# >= 90 avec marqueurs d' atteinte rénale*       G1  : MRC avec DFG normal ou augmenté
# 60 à 89 avec marqueurs d' atteinte rénale*     G2  : MRC avec DFG légèrement diminué
# 45 à 59                                        G3a : IRC légère à modérée
# 30 à 44                                        G3b : IRC modérée à sévère
# 15 à 29                                        G4  : IRC sévère
# < 15 ou dialyse                                G5  : IRC terminale
# (*) Albuminurie de faible débit, protéinurie clinique, hématurie, leucocyturie ou anomalies morphologiques ou histologiques persitantes
# plus de tois mois.
# ASAT (GOT)                                   15         UI/l                     ( < 35 )                 16                    15/04/24
# UV sans P5P(Alinity ci)
# ALAT (GPT)                                   14         UI/l                     ( < 40 )                 14                    15/04/24
# UV sans P5P(Alinity ci)
# Créatine kinase                              117        UI/l                     ( 24 - 195 )             84                    15/04/24
# Enzymatique (Alinity ci)
# BILAN LIPIDIQUE
# Analyse                                      Résultat    Unité                    Valeurs de référence     Résultat antérieur    dat
# Aspect                                                   LIMPIDE
# Triglycérides                                0,63       g/l                      ( 0,60 - 1,50 )          1,26                  15/04/24
# Enzymatique (Alinity ci)
# Soit                                     0,72       mmol/l                   ( 0,68 - 1,71 )          1,44                  15/04/24
# Cholestérol HDL                              0,37       g/l                      ( 0,40 - 0,60 )          0,44                  15/04/24
# Enzymatique (Alinity ci)
# Soit                                     0,95       mmol/l                   ( 1,03 - 1,54 )          1,14                  15/04/24
# Cholestérol LDL                              1,03       g/l                      ( < 1,55 )               1,15                  15/04/24
# (Calcul)
# Soit                                     2,66       mmol/l                   ( < 4,00 )               2,97                  15/04/24
# Cholestérol                                  1,53       g/l                      ( 1,50 - 2,00 )          1,84                  15/04/24
# Enzymatique (Alinity ci)
# Soit                                     3,95       mmol/l                   ( 3,87 - 5,16 )          4,75                  15/04/24
# Cholesterol non HDL                          1,16       g/l                                              1,40                  15/04/24
# (Calcul)
# Soit                                     2,99       mmol/l                                           3,61                  15/04/24
# Les objectifs pour un patient dans le cadre d'une prise en charge initiale (ESC 2021) :
# -Haut risque cardiovasculaire          : LDL-c < 1,00 g/L (2,6 mmol/L) et non-HDLc < 1,30 g/L (3,4 mmol/L).
# -Très Haut risque cardiovasculaire     : LDL-c < 0,70 g/L (1,8 mmol/L) et non-HDLc < 1,00 g/L (2,6 mmol/L).
# Les objectifs pour un patient dans le cadre d'une intensification thérapeutique (ESC 2021) :
# -Haut risque cardiovasculaire          : LDL-c < 0,70 g/L (1,8 mmol/L) associé à baisse de 50% et non-HDLc < 1,00 g/L (2,6 mmol/L).
# -Très Haut risque cardiovasculaire     : LDL-c < 0,55 g/L (1,4 mmol/L) associé à baisse de 50% et non-HDLc < 0,85 g/L (2,2 mmol/L).
#
# EXTRACTED TEXT (OCR Result):
# ------------------------------
# 3lOCHIMIE SANGUINE (suite) Analyse Résultat Classification de la maladie rénale chronique (MRC) en fonction du DFG (KDIGO 2011) Unité Valeurs de réference Resultat anterieur du: >= 90 sans marqueur d atteinte rénale >= 90 avec marqueurs d atteinte rénale* Pas datteinte rénale 60 a 89 avec marqueurs d atteinte rénale* G1_: MRC avec DFG normal ou augmente 45 a 59 G2 : MRC avec DFG iégérernent diminué 30 a 44 G3a : IRC légere a modérée 15 a 29 G3b : IRC modérée a sévére G4 :IRC sévere < 15 ou dialyse () Albuminurie de faible debit, protéinurie clinique. hématurie. leucocyturie ou anomalies morphologiques ou histologiques persitantes G5 : IRC terminale plus de tois mois. ASAT (GOT) 15 UI/I (<35) 16 UV sans P5P(Alnny c) 15/04/24 ALAT (GPT) 14  UI/I (< 40) 14 15/04/24 UV sans P5P(Alnrty a) Créatine kinase 117 UIi ( 24- 195) 84 15/04/24 Enzymatique (Annrty a) BILAN LIPIDIQUE Analyse Resuitat Urité Yaleurs de réferenca Résultat anterieur Aspect LIMPIDE Triglycérides 0,63 g/l (0.60 - 1.50) 1.26 15/04/24 Enzymatque (Ainity a) Soit 0.72 mmol (0.68 - 1.71) 1.44 15/04/24 Cholestéro1 HDL 0,37 g/l ( 0,40 - 0,60) 0.44 15/04/24 Enzymatque (Aknsty cr) Soit 0.95 mmol/l ( 1.03 - 1.54) 1.14 15/04/24 Cholesterol LDi 1,03 g/I (<1,55) 1.15 15/04/24 (Calcul Sort 2.66 mmol/l (<4.00) 2.97 15/04/24 Cholestérol 1.53 I/8 ( 1,50-2,00) 1.84 15/04/24 Enzymauquo (Abrly a) Sort 3.95 mmol/l ( 3.87 - 5.16 ) 4.75 15/04/24  g/I 1.40 15/04/24 Cholesterol non HDL 1.16 {Calcu} Soit 2,99 mmol/l 3.61 15/04/24 (izoz osa) aeon e6oeyd ue asud ounp wpes o) suap 1ualad un Jnod soaefqo so7 -Haul rlsque cardiovaeculalre LDL -c < 1.00 g/L (2.6 mmoVL) ot non-HDLc < 1,30 g/L (3.4 mmoVL) -Tres Haut risquo cardiovasculaire LDL -c < 0.70 g/L (1.8 mmoVL) ot non-HDLc < 1.00 g/L (2.6 mmoVL) Les objectifs pour un patient dans la cadre dune Intanelflcation thärapoutique (EsC 2021) -Haut risque cardlovascuiaire LDL -c < 0,70 g/L (1,8 mmoVL) as8acl@ a baiase de 50% at non-HDLc < 1.00 g/L (2.6 mmoIL) -Tres Haut risaue cardlovasculalre LDL -c < 0.55 g/L (1.4 mmoVL) aa90cie a bals8e de 50% et non-HDLc < 0.85 g/L (2.2 mmovLj ge 1 sur 1
#
# WORD COUNT COMPARISON:
# Reference text word count: 385
# Extracted text word count: 362
#
# METRICS FOR: 4.jpeg
# Reference words: 385
# Extracted words: 362
# Correct words: 115
# Precision: 0.32
# Recall: 0.30
# F1 Score: 0.31
# Execution Time: 42.47 seconds
#
# ==================================================
# FINAL SUMMARY STATISTICS:
# ==================================================
# Number of files processed: 20
#
# Total Word Counts:
# Total Reference Words: 4555
# Total Extracted Words: 4038
# Total Correct Words: 1634
#
# Average Metrics:
# Average Precision: 0.41
# Average Recall: 0.37
# Average F1 Score: 0.39
# Average Execution Time: 30.39 seconds per file
#
# Best performing file:
# Filename: 17.jpeg
# F1 Score: 0.50
# Reference words: 149
# Extracted words: 143
# Correct words: 73
#
# Worst performing file:
# Filename: 8.jpeg
# F1 Score: 0.19
# Reference words: 119
# Extracted words: 61
# Correct words: 17
